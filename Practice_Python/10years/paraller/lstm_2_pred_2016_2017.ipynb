# %%
import json
import numpy as np
import pandas as pd

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import regex as re
from nltk.corpus import stopwords

from nltk.sentiment.vader import SentimentIntensityAnalyzer
import datetime

import yfinance as yf
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.layers import Embedding, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import optimizers
from keras import backend as K
import matplotlib.pyplot as plt

import datetime
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error 
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error

from multiprocessing import Pool

# %%
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
# 데이터 생성, 처리
def time_conversion(time):
    time = pd.Timestamp(time)
    return time

def date_cut_day(dataframe_date_timestamp):
    dataframe_date_timestamp = datetime.datetime.strftime(dataframe_date_timestamp, "%Y-%m-%d")
    return dataframe_date_timestamp

def train_test_result(dir, stock, variable, window_size):
    #score data 뽑기
    score = pd.read_csv(dir)
    score.columns = ["Date", "Score"]
    
    #price data 뽑기
    price_data = yf.download([stock],start = '2012-01-01', end = "2022-05-01")
    
    opening = price_data.index.copy()
    opening = pd.DataFrame(opening)
    opening["opening_date"] = 1
    opening.Date = opening.Date.apply(lambda x: date_cut_day(x))
    
    Date = pd.date_range(start='20111230', end='20220430')
    Date = pd.DataFrame({"Date" : Date.values})
    Date.Date = Date.Date.apply(lambda x: date_cut_day(x))

    
    set_news_data_date = pd.merge(Date, opening, how ="left",left_on='Date', right_on = "Date") 
    set_news_data_date = set_news_data_date.where(pd.notnull(set_news_data_date), 0) 
    set_news_data_date.Date = set_news_data_date.Date.apply(lambda x: pd.to_datetime(x, errors="ignore"))

    standard=set_news_data_date.Date.iloc[len(set_news_data_date)-1] + datetime.timedelta(days=1)
    set_news_data_date["price_date"]=0
    for i in range(len(set_news_data_date)-1,-1,-1):
        if i==(len(set_news_data_date)-1):
            standard = set_news_data_date.Date[i]
            set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
        elif (set_news_data_date.opening_date[i]==1)&(set_news_data_date.opening_date[i+1]==1):
            standard = set_news_data_date.Date[i]
            set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
        elif (i!=0):
            if((set_news_data_date.opening_date[i]==1)&(set_news_data_date.opening_date[i+1]==0)&(set_news_data_date.opening_date[i-1]==0)):
                set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
                standard = set_news_data_date.Date[i]
            else:
                set_news_data_date.price_date[i]=standard
        else:
            set_news_data_date.price_date[i]=standard
    
    set_news_data_date.Date = set_news_data_date.Date.apply(lambda x: date_cut_day(x))
    
    score = pd.merge(set_news_data_date,score, how ="left",on = "Date")
    
    score = score[['Date','Score', "price_date"]]
    score = score.groupby('price_date').mean({"Score"})
    score = score[score.index<="2022-04-29"]

    first_data = yf.download([stock],start = '2011-12-30', end = '2012-01-01')
    
    price_data = price_data.reset_index()
    score = score.reset_index()
    score.columns = ["Date", "Score"]
    
    price_data = price_data[(price_data["Date"]<"2018-01-01")&("2016-01-01"<=price_data["Date"])]
    
    #price data와 score data 결합
    price_data = pd.merge(price_data, score, how ="left",left_on='Date', right_on = "Date")[["Close","Open","Score"]]

    #뉴스가 없는 날은 즉, score가 없는 날은 중립의 의미로 0으로 처리
    price_data.Score[price_data.Score.isnull()]=0

    #전날 종가의 영향을 받으므로 전날 종가 변수를 생성
    price_data["before_close"] = 0
    price_data = price_data.reset_index(drop=True)
    for i in range(len(price_data)-1):
        price_data.before_close[i+1] = price_data.Close[i]
    
    price_data.before_close[0] = first_data["Close"][0]

    # minmaxscaler 사용
    price_data.columns = ["Close","Open","Score","before_close"]
    
    x = price_data[variable]
    y = price_data[["Close"]]
    scaler_x = MinMaxScaler()
    scaler_y = MinMaxScaler()

    x = pd.DataFrame(scaler_x.fit_transform(x))
    y = pd.DataFrame(scaler_y.fit_transform(y))
    
    x.columns = variable
    y.columns = ["Close"]

    train_index = int(len(x)*0.7)

    train_x = x.iloc[0:train_index]
    test_x = x.iloc[train_index:len(x)]

    train_y = y.iloc[0:train_index]
    test_y = y.iloc[train_index:len(y)]

    train_x = train_x.to_numpy().reshape(train_x.shape[0],1,train_x.shape[1])
    train_y = train_y.to_numpy().reshape(train_y.shape[0],train_y.shape[1])
    test_x = test_x.to_numpy().reshape(test_x.shape[0],1,test_x.shape[1])
    test_y = test_y.to_numpy().reshape(test_y.shape[0],test_y.shape[1])
    
    #window size에 맞게 데이터 설정
    x = np.zeros(shape=(train_x.shape[0]-window_size+1,window_size,x.shape[1]))
    for i in range(train_x.shape[0]-window_size+1):
        x[i]=np.vstack((train_x[i:i+window_size]))

    y = train_y[window_size-1:train_x.shape[0]]

    x_t = np.zeros(shape=(test_x.shape[0]-window_size+1,window_size,x.shape[2]))
    for i in range(test_x.shape[0]-window_size+1):
        x_t[i]=np.vstack((test_x[i:i+window_size]))
    
    y_t = test_y[window_size-1:test_x.shape[0]]
    
    return scaler_x, scaler_y, x, y, x_t, y_t

# %%
# %%time
dir = "/home/whfhrs3260/csv_data/price_data_score_10years.csv"
stock = "^DJI"
variable = ["before_close","Score"]
window_size = 1

scaler_x, scaler_y, x, y, x_t, y_t = train_test_result(dir, stock, variable, window_size)


lstm_2_pred = []
model_input = 0
len_x = x.shape[0]
len_y = y.shape[0]


for i in range(len(x_t)):
    lstm_2_model = Sequential()
    lstm_2_model.add(LSTM(50, input_shape = (x.shape[1],x.shape[2]),return_sequences=True))
    lstm_2_model.add((LSTM(50)))
    lstm_2_model.add(Dense(1,activation="tanh"))
    def root_mean_squared_error(y_true, y_pred):
            return K.sqrt(K.mean(K.square(y_pred - y_true))) 
    lstm_2_model.compile(optimizer="adam", loss = root_mean_squared_error, metrics=['mse',"mae"])
    lstm_2_model.fit(x, y, epochs=40, batch_size=128, validation_split=0.2)
    
    model_input = x_t[i].reshape(1, window_size, len(variable))
    lstm_2_pred = np.append(lstm_2_pred,lstm_2_model.predict(model_input)[0])

    x = np.append(x,x_t[i])
    y = np.append(y,y_t[i])
    len_x += 1
    len_y += 1
    x = x.reshape(len_x,window_size,len(variable))
    y = y.reshape(len_y,1)
    print(i)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f82b2843820> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f82b2843820>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 305ms/step - loss: 0.2903 - mse: 0.0844 - mae: 0.2655 - val_loss: 0.5427 - val_mse: 0.2945 - val_mae: 0.5424
# Epoch 2/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2775 - mse: 0.0771 - mae: 0.2518 - val_loss: 0.5272 - val_mse: 0.2779 - val_mae: 0.5269
# Epoch 3/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2645 - mse: 0.0700 - mae: 0.2378 - val_loss: 0.5109 - val_mse: 0.2611 - val_mae: 0.5106
# Epoch 4/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2509 - mse: 0.0630 - mae: 0.2238 - val_loss: 0.4936 - val_mse: 0.2436 - val_mae: 0.4932
# Epoch 5/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2364 - mse: 0.0560 - mae: 0.2092 - val_loss: 0.4747 - val_mse: 0.2253 - val_mae: 0.4743
# Epoch 6/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.2213 - mse: 0.0490 - mae: 0.1942 - val_loss: 0.4539 - val_mse: 0.2060 - val_mae: 0.4535
# Epoch 7/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2045 - mse: 0.0419 - mae: 0.1784 - val_loss: 0.4308 - val_mse: 0.1856 - val_mae: 0.4305
# Epoch 8/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1871 - mse: 0.0350 - mae: 0.1622 - val_loss: 0.4053 - val_mse: 0.1643 - val_mae: 0.4049
# Epoch 9/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1682 - mse: 0.0284 - mae: 0.1447 - val_loss: 0.3770 - val_mse: 0.1421 - val_mae: 0.3765
# Epoch 10/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1489 - mse: 0.0223 - mae: 0.1267 - val_loss: 0.3458 - val_mse: 0.1196 - val_mae: 0.3453
# Epoch 11/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1308 - mse: 0.0172 - mae: 0.1080 - val_loss: 0.3123 - val_mse: 0.0976 - val_mae: 0.3118
# Epoch 12/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1161 - mse: 0.0135 - mae: 0.0909 - val_loss: 0.2783 - val_mse: 0.0775 - val_mae: 0.2776
# Epoch 13/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1073 - mse: 0.0116 - mae: 0.0812 - val_loss: 0.2470 - val_mse: 0.0610 - val_mae: 0.2461
# Epoch 14/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1061 - mse: 0.0113 - mae: 0.0812 - val_loss: 0.2244 - val_mse: 0.0504 - val_mae: 0.2234
# Epoch 15/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1083 - mse: 0.0118 - mae: 0.0835 - val_loss: 0.2146 - val_mse: 0.0460 - val_mae: 0.2135
# Epoch 16/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1099 - mse: 0.0121 - mae: 0.0855 - val_loss: 0.2143 - val_mse: 0.0459 - val_mae: 0.2132
# Epoch 17/40
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1092 - mse: 0.0119 - mae: 0.0847 - val_loss: 0.2224 - val_mse: 0.0495 - val_mae: 0.2214
# Epoch 18/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1070 - mse: 0.0115 - mae: 0.0822 - val_loss: 0.2340 - val_mse: 0.0547 - val_mae: 0.2331
# Epoch 19/40
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1051 - mse: 0.0110 - mae: 0.0800 - val_loss: 0.2433 - val_mse: 0.0592 - val_mae: 0.2425
# Epoch 20/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1039 - mse: 0.0108 - mae: 0.0787 - val_loss: 0.2493 - val_mse: 0.0622 - val_mae: 0.2486
# Epoch 21/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1037 - mse: 0.0108 - mae: 0.0784 - val_loss: 0.2528 - val_mse: 0.0639 - val_mae: 0.2521
# Epoch 22/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1035 - mse: 0.0107 - mae: 0.0781 - val_loss: 0.2537 - val_mse: 0.0644 - val_mae: 0.2530
# Epoch 23/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1032 - mse: 0.0107 - mae: 0.0779 - val_loss: 0.2526 - val_mse: 0.0638 - val_mae: 0.2519
# Epoch 24/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1028 - mse: 0.0106 - mae: 0.0776 - val_loss: 0.2502 - val_mse: 0.0626 - val_mae: 0.2495
# Epoch 25/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1022 - mse: 0.0105 - mae: 0.0772 - val_loss: 0.2483 - val_mse: 0.0617 - val_mae: 0.2477
# Epoch 26/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1016 - mse: 0.0104 - mae: 0.0768 - val_loss: 0.2440 - val_mse: 0.0595 - val_mae: 0.2433
# Epoch 27/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1011 - mse: 0.0102 - mae: 0.0765 - val_loss: 0.2392 - val_mse: 0.0572 - val_mae: 0.2386
# Epoch 28/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1006 - mse: 0.0101 - mae: 0.0761 - val_loss: 0.2362 - val_mse: 0.0558 - val_mae: 0.2355
# Epoch 29/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0997 - mse: 0.0100 - mae: 0.0758 - val_loss: 0.2352 - val_mse: 0.0553 - val_mae: 0.2345
# Epoch 30/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0991 - mse: 0.0099 - mae: 0.0753 - val_loss: 0.2353 - val_mse: 0.0554 - val_mae: 0.2346
# Epoch 31/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0984 - mse: 0.0098 - mae: 0.0748 - val_loss: 0.2346 - val_mse: 0.0550 - val_mae: 0.2339
# Epoch 32/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0981 - mse: 0.0097 - mae: 0.0744 - val_loss: 0.2319 - val_mse: 0.0538 - val_mae: 0.2313
# Epoch 33/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0975 - mse: 0.0095 - mae: 0.0740 - val_loss: 0.2280 - val_mse: 0.0520 - val_mae: 0.2274
# Epoch 34/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0969 - mse: 0.0094 - mae: 0.0736 - val_loss: 0.2217 - val_mse: 0.0492 - val_mae: 0.2211
# Epoch 35/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0964 - mse: 0.0093 - mae: 0.0733 - val_loss: 0.2174 - val_mse: 0.0472 - val_mae: 0.2167
# Epoch 36/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0958 - mse: 0.0092 - mae: 0.0730 - val_loss: 0.2157 - val_mse: 0.0465 - val_mae: 0.2150
# Epoch 37/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0950 - mse: 0.0090 - mae: 0.0724 - val_loss: 0.2139 - val_mse: 0.0457 - val_mae: 0.2132
# Epoch 38/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0941 - mse: 0.0089 - mae: 0.0719 - val_loss: 0.2136 - val_mse: 0.0456 - val_mae: 0.2130
# Epoch 39/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0922 - mse: 0.0087 - mae: 0.0709 - val_loss: 0.2171 - val_mse: 0.0471 - val_mae: 0.2165
# Epoch 40/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0923 - mse: 0.0085 - mae: 0.0702 - val_loss: 0.2191 - val_mse: 0.0480 - val_mae: 0.2186
# 1/1 [==============================] - 1s 539ms/step
# 0
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f820c240f70> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f820c240f70>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 339ms/step - loss: 0.2960 - mse: 0.0876 - mae: 0.2709 - val_loss: 0.5466 - val_mse: 0.2987 - val_mae: 0.5463
# Epoch 2/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2805 - mse: 0.0787 - mae: 0.2544 - val_loss: 0.5279 - val_mse: 0.2786 - val_mae: 0.5276
# Epoch 3/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2650 - mse: 0.0703 - mae: 0.2380 - val_loss: 0.5086 - val_mse: 0.2587 - val_mae: 0.5083
# Epoch 4/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2492 - mse: 0.0621 - mae: 0.2217 - val_loss: 0.4884 - val_mse: 0.2386 - val_mae: 0.4881
# Epoch 5/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2328 - mse: 0.0542 - mae: 0.2053 - val_loss: 0.4670 - val_mse: 0.2181 - val_mae: 0.4667
# Epoch 6/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2154 - mse: 0.0467 - mae: 0.1887 - val_loss: 0.4439 - val_mse: 0.1971 - val_mae: 0.4436
# Epoch 7/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1970 - mse: 0.0392 - mae: 0.1719 - val_loss: 0.4189 - val_mse: 0.1755 - val_mae: 0.4186
# Epoch 8/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1791 - mse: 0.0321 - mae: 0.1549 - val_loss: 0.3918 - val_mse: 0.1535 - val_mae: 0.3914
# Epoch 9/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1599 - mse: 0.0256 - mae: 0.1369 - val_loss: 0.3620 - val_mse: 0.1311 - val_mae: 0.3616
# Epoch 10/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1410 - mse: 0.0199 - mae: 0.1184 - val_loss: 0.3297 - val_mse: 0.1087 - val_mae: 0.3292
# Epoch 11/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1240 - mse: 0.0154 - mae: 0.1002 - val_loss: 0.2956 - val_mse: 0.0874 - val_mae: 0.2950
# Epoch 12/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1100 - mse: 0.0121 - mae: 0.0851 - val_loss: 0.2619 - val_mse: 0.0686 - val_mae: 0.2612
# Epoch 13/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1049 - mse: 0.0110 - mae: 0.0793 - val_loss: 0.2313 - val_mse: 0.0535 - val_mae: 0.2303
# Epoch 14/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1071 - mse: 0.0115 - mae: 0.0823 - val_loss: 0.2105 - val_mse: 0.0443 - val_mae: 0.2094
# Epoch 15/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1107 - mse: 0.0123 - mae: 0.0865 - val_loss: 0.2034 - val_mse: 0.0414 - val_mae: 0.2022
# Epoch 16/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1120 - mse: 0.0126 - mae: 0.0879 - val_loss: 0.2067 - val_mse: 0.0427 - val_mae: 0.2056
# Epoch 17/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1096 - mse: 0.0121 - mae: 0.0858 - val_loss: 0.2183 - val_mse: 0.0477 - val_mae: 0.2172
# Epoch 18/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1072 - mse: 0.0115 - mae: 0.0825 - val_loss: 0.2329 - val_mse: 0.0543 - val_mae: 0.2320
# Epoch 19/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1046 - mse: 0.0110 - mae: 0.0795 - val_loss: 0.2448 - val_mse: 0.0599 - val_mae: 0.2440
# Epoch 20/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1039 - mse: 0.0108 - mae: 0.0785 - val_loss: 0.2523 - val_mse: 0.0636 - val_mae: 0.2515
# Epoch 21/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1037 - mse: 0.0108 - mae: 0.0784 - val_loss: 0.2543 - val_mse: 0.0647 - val_mae: 0.2535
# Epoch 22/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1036 - mse: 0.0108 - mae: 0.0782 - val_loss: 0.2530 - val_mse: 0.0640 - val_mae: 0.2522
# Epoch 23/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1031 - mse: 0.0107 - mae: 0.0779 - val_loss: 0.2491 - val_mse: 0.0621 - val_mae: 0.2483
# Epoch 24/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1028 - mse: 0.0106 - mae: 0.0776 - val_loss: 0.2445 - val_mse: 0.0598 - val_mae: 0.2437
# Epoch 25/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1022 - mse: 0.0105 - mae: 0.0773 - val_loss: 0.2421 - val_mse: 0.0586 - val_mae: 0.2413
# Epoch 26/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1019 - mse: 0.0104 - mae: 0.0770 - val_loss: 0.2411 - val_mse: 0.0581 - val_mae: 0.2402
# Epoch 27/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1014 - mse: 0.0103 - mae: 0.0768 - val_loss: 0.2419 - val_mse: 0.0585 - val_mae: 0.2411
# Epoch 28/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1011 - mse: 0.0102 - mae: 0.0763 - val_loss: 0.2396 - val_mse: 0.0574 - val_mae: 0.2388
# Epoch 29/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1002 - mse: 0.0101 - mae: 0.0760 - val_loss: 0.2354 - val_mse: 0.0554 - val_mae: 0.2346
# Epoch 30/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1002 - mse: 0.0100 - mae: 0.0758 - val_loss: 0.2321 - val_mse: 0.0539 - val_mae: 0.2313
# Epoch 31/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0991 - mse: 0.0100 - mae: 0.0755 - val_loss: 0.2305 - val_mse: 0.0531 - val_mae: 0.2296
# Epoch 32/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0991 - mse: 0.0099 - mae: 0.0751 - val_loss: 0.2288 - val_mse: 0.0523 - val_mae: 0.2279
# Epoch 33/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0988 - mse: 0.0098 - mae: 0.0748 - val_loss: 0.2260 - val_mse: 0.0511 - val_mae: 0.2252
# Epoch 34/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0983 - mse: 0.0097 - mae: 0.0745 - val_loss: 0.2227 - val_mse: 0.0496 - val_mae: 0.2218
# Epoch 35/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0975 - mse: 0.0096 - mae: 0.0742 - val_loss: 0.2204 - val_mse: 0.0486 - val_mae: 0.2195
# Epoch 36/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0971 - mse: 0.0094 - mae: 0.0737 - val_loss: 0.2207 - val_mse: 0.0487 - val_mae: 0.2199
# Epoch 37/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0962 - mse: 0.0093 - mae: 0.0731 - val_loss: 0.2223 - val_mse: 0.0494 - val_mae: 0.2215
# Epoch 38/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0955 - mse: 0.0091 - mae: 0.0724 - val_loss: 0.2244 - val_mse: 0.0504 - val_mae: 0.2237
# Epoch 39/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0949 - mse: 0.0090 - mae: 0.0718 - val_loss: 0.2251 - val_mse: 0.0507 - val_mae: 0.2244
# Epoch 40/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0941 - mse: 0.0089 - mae: 0.0713 - val_loss: 0.2219 - val_mse: 0.0492 - val_mae: 0.2211
# 1/1 [==============================] - 1s 539ms/step
# 1
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f8172489310> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f8172489310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 330ms/step - loss: 0.3004 - mse: 0.0903 - mae: 0.2750 - val_loss: 0.5517 - val_mse: 0.3043 - val_mae: 0.5514
# Epoch 2/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2844 - mse: 0.0809 - mae: 0.2579 - val_loss: 0.5324 - val_mse: 0.2834 - val_mae: 0.5321
# Epoch 3/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2682 - mse: 0.0720 - mae: 0.2410 - val_loss: 0.5127 - val_mse: 0.2628 - val_mae: 0.5124
# Epoch 4/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2517 - mse: 0.0638 - mae: 0.2244 - val_loss: 0.4920 - val_mse: 0.2421 - val_mae: 0.4917
# Epoch 5/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2350 - mse: 0.0556 - mae: 0.2077 - val_loss: 0.4701 - val_mse: 0.2210 - val_mae: 0.4698
# Epoch 6/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2178 - mse: 0.0475 - mae: 0.1901 - val_loss: 0.4464 - val_mse: 0.1993 - val_mae: 0.4461
# Epoch 7/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1992 - mse: 0.0398 - mae: 0.1731 - val_loss: 0.4207 - val_mse: 0.1769 - val_mae: 0.4203
# Epoch 8/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1800 - mse: 0.0326 - mae: 0.1556 - val_loss: 0.3926 - val_mse: 0.1541 - val_mae: 0.3922
# Epoch 9/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1604 - mse: 0.0257 - mae: 0.1370 - val_loss: 0.3621 - val_mse: 0.1311 - val_mae: 0.3617
# Epoch 10/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1414 - mse: 0.0200 - mae: 0.1183 - val_loss: 0.3293 - val_mse: 0.1084 - val_mae: 0.3288
# Epoch 11/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1240 - mse: 0.0154 - mae: 0.0999 - val_loss: 0.2951 - val_mse: 0.0871 - val_mae: 0.2946
# Epoch 12/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1117 - mse: 0.0125 - mae: 0.0859 - val_loss: 0.2607 - val_mse: 0.0680 - val_mae: 0.2600
# Epoch 13/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1062 - mse: 0.0114 - mae: 0.0805 - val_loss: 0.2313 - val_mse: 0.0535 - val_mae: 0.2304
# Epoch 14/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1083 - mse: 0.0117 - mae: 0.0831 - val_loss: 0.2129 - val_mse: 0.0453 - val_mae: 0.2119
# Epoch 15/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1112 - mse: 0.0124 - mae: 0.0869 - val_loss: 0.2076 - val_mse: 0.0431 - val_mae: 0.2066
# Epoch 16/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1115 - mse: 0.0125 - mae: 0.0876 - val_loss: 0.2114 - val_mse: 0.0447 - val_mae: 0.2104
# Epoch 17/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1098 - mse: 0.0121 - mae: 0.0856 - val_loss: 0.2201 - val_mse: 0.0485 - val_mae: 0.2192
# Epoch 18/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1074 - mse: 0.0115 - mae: 0.0828 - val_loss: 0.2309 - val_mse: 0.0533 - val_mae: 0.2301
# Epoch 19/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1053 - mse: 0.0111 - mae: 0.0803 - val_loss: 0.2420 - val_mse: 0.0586 - val_mae: 0.2413
# Epoch 20/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1043 - mse: 0.0109 - mae: 0.0792 - val_loss: 0.2510 - val_mse: 0.0630 - val_mae: 0.2504
# Epoch 21/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1043 - mse: 0.0109 - mae: 0.0788 - val_loss: 0.2552 - val_mse: 0.0651 - val_mae: 0.2545
# Epoch 22/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1038 - mse: 0.0109 - mae: 0.0787 - val_loss: 0.2564 - val_mse: 0.0657 - val_mae: 0.2558
# Epoch 23/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1039 - mse: 0.0108 - mae: 0.0785 - val_loss: 0.2542 - val_mse: 0.0646 - val_mae: 0.2536
# Epoch 24/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1032 - mse: 0.0107 - mae: 0.0781 - val_loss: 0.2479 - val_mse: 0.0614 - val_mae: 0.2472
# Epoch 25/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1025 - mse: 0.0105 - mae: 0.0775 - val_loss: 0.2415 - val_mse: 0.0583 - val_mae: 0.2408
# Epoch 26/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1015 - mse: 0.0104 - mae: 0.0771 - val_loss: 0.2365 - val_mse: 0.0559 - val_mae: 0.2358
# Epoch 27/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1011 - mse: 0.0103 - mae: 0.0768 - val_loss: 0.2331 - val_mse: 0.0543 - val_mae: 0.2324
# Epoch 28/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1003 - mse: 0.0102 - mae: 0.0764 - val_loss: 0.2306 - val_mse: 0.0532 - val_mae: 0.2299
# Epoch 29/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1002 - mse: 0.0100 - mae: 0.0760 - val_loss: 0.2277 - val_mse: 0.0518 - val_mae: 0.2270
# Epoch 30/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0996 - mse: 0.0099 - mae: 0.0757 - val_loss: 0.2254 - val_mse: 0.0508 - val_mae: 0.2247
# Epoch 31/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0989 - mse: 0.0098 - mae: 0.0752 - val_loss: 0.2272 - val_mse: 0.0516 - val_mae: 0.2265
# Epoch 32/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0980 - mse: 0.0096 - mae: 0.0744 - val_loss: 0.2308 - val_mse: 0.0533 - val_mae: 0.2301
# Epoch 33/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0974 - mse: 0.0095 - mae: 0.0738 - val_loss: 0.2325 - val_mse: 0.0540 - val_mae: 0.2318
# Epoch 34/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0966 - mse: 0.0094 - mae: 0.0733 - val_loss: 0.2318 - val_mse: 0.0537 - val_mae: 0.2312
# Epoch 35/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0961 - mse: 0.0092 - mae: 0.0728 - val_loss: 0.2274 - val_mse: 0.0517 - val_mae: 0.2268
# Epoch 36/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0949 - mse: 0.0090 - mae: 0.0720 - val_loss: 0.2194 - val_mse: 0.0481 - val_mae: 0.2187
# Epoch 37/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0941 - mse: 0.0089 - mae: 0.0715 - val_loss: 0.2084 - val_mse: 0.0434 - val_mae: 0.2077
# Epoch 38/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0934 - mse: 0.0088 - mae: 0.0717 - val_loss: 0.2021 - val_mse: 0.0408 - val_mae: 0.2014
# Epoch 39/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0930 - mse: 0.0086 - mae: 0.0712 - val_loss: 0.2025 - val_mse: 0.0410 - val_mae: 0.2019
# Epoch 40/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0915 - mse: 0.0084 - mae: 0.0699 - val_loss: 0.2069 - val_mse: 0.0428 - val_mae: 0.2063
# 1/1 [==============================] - 1s 526ms/step
# 2
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f812a1809d0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f812a1809d0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 295ms/step - loss: 0.2986 - mse: 0.0892 - mae: 0.2730 - val_loss: 0.5501 - val_mse: 0.3027 - val_mae: 0.5498
# Epoch 2/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2846 - mse: 0.0811 - mae: 0.2581 - val_loss: 0.5334 - val_mse: 0.2846 - val_mae: 0.5331
# Epoch 3/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2708 - mse: 0.0734 - mae: 0.2433 - val_loss: 0.5162 - val_mse: 0.2665 - val_mae: 0.5159
# Epoch 4/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2565 - mse: 0.0658 - mae: 0.2284 - val_loss: 0.4982 - val_mse: 0.2482 - val_mae: 0.4979
# Epoch 5/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2415 - mse: 0.0583 - mae: 0.2132 - val_loss: 0.4789 - val_mse: 0.2293 - val_mae: 0.4786
# Epoch 6/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2258 - mse: 0.0510 - mae: 0.1976 - val_loss: 0.4580 - val_mse: 0.2098 - val_mae: 0.4577
# Epoch 7/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2088 - mse: 0.0437 - mae: 0.1814 - val_loss: 0.4351 - val_mse: 0.1893 - val_mae: 0.4348
# Epoch 8/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1914 - mse: 0.0366 - mae: 0.1652 - val_loss: 0.4100 - val_mse: 0.1681 - val_mae: 0.4096
# Epoch 9/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1731 - mse: 0.0300 - mae: 0.1485 - val_loss: 0.3825 - val_mse: 0.1463 - val_mae: 0.3821
# Epoch 10/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1543 - mse: 0.0238 - mae: 0.1305 - val_loss: 0.3527 - val_mse: 0.1244 - val_mae: 0.3523
# Epoch 11/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1359 - mse: 0.0185 - mae: 0.1121 - val_loss: 0.3206 - val_mse: 0.1028 - val_mae: 0.3202
# Epoch 12/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1205 - mse: 0.0145 - mae: 0.0946 - val_loss: 0.2871 - val_mse: 0.0824 - val_mae: 0.2865
# Epoch 13/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1104 - mse: 0.0124 - mae: 0.0847 - val_loss: 0.2552 - val_mse: 0.0651 - val_mae: 0.2545
# Epoch 14/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1073 - mse: 0.0115 - mae: 0.0812 - val_loss: 0.2300 - val_mse: 0.0529 - val_mae: 0.2293
# Epoch 15/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1096 - mse: 0.0120 - mae: 0.0849 - val_loss: 0.2143 - val_mse: 0.0459 - val_mae: 0.2134
# Epoch 16/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1127 - mse: 0.0127 - mae: 0.0886 - val_loss: 0.2111 - val_mse: 0.0446 - val_mae: 0.2102
# Epoch 17/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1112 - mse: 0.0127 - mae: 0.0884 - val_loss: 0.2177 - val_mse: 0.0474 - val_mae: 0.2169
# Epoch 18/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1102 - mse: 0.0121 - mae: 0.0857 - val_loss: 0.2284 - val_mse: 0.0522 - val_mae: 0.2277
# Epoch 19/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1074 - mse: 0.0116 - mae: 0.0828 - val_loss: 0.2399 - val_mse: 0.0575 - val_mae: 0.2392
# Epoch 20/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1060 - mse: 0.0113 - mae: 0.0809 - val_loss: 0.2504 - val_mse: 0.0627 - val_mae: 0.2497
# Epoch 21/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1057 - mse: 0.0112 - mae: 0.0804 - val_loss: 0.2571 - val_mse: 0.0661 - val_mae: 0.2565
# Epoch 22/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1058 - mse: 0.0112 - mae: 0.0801 - val_loss: 0.2596 - val_mse: 0.0674 - val_mae: 0.2590
# Epoch 23/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1058 - mse: 0.0112 - mae: 0.0799 - val_loss: 0.2578 - val_mse: 0.0665 - val_mae: 0.2572
# Epoch 24/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1052 - mse: 0.0111 - mae: 0.0795 - val_loss: 0.2531 - val_mse: 0.0641 - val_mae: 0.2525
# Epoch 25/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1043 - mse: 0.0109 - mae: 0.0790 - val_loss: 0.2466 - val_mse: 0.0608 - val_mae: 0.2460
# Epoch 26/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1036 - mse: 0.0108 - mae: 0.0787 - val_loss: 0.2393 - val_mse: 0.0573 - val_mae: 0.2387
# Epoch 27/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1032 - mse: 0.0107 - mae: 0.0787 - val_loss: 0.2335 - val_mse: 0.0545 - val_mae: 0.2328
# Epoch 28/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1030 - mse: 0.0106 - mae: 0.0786 - val_loss: 0.2296 - val_mse: 0.0527 - val_mae: 0.2289
# Epoch 29/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1026 - mse: 0.0105 - mae: 0.0785 - val_loss: 0.2287 - val_mse: 0.0523 - val_mae: 0.2281
# Epoch 30/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1020 - mse: 0.0104 - mae: 0.0779 - val_loss: 0.2307 - val_mse: 0.0532 - val_mae: 0.2300
# Epoch 31/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1013 - mse: 0.0103 - mae: 0.0771 - val_loss: 0.2330 - val_mse: 0.0543 - val_mae: 0.2324
# Epoch 32/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1006 - mse: 0.0101 - mae: 0.0765 - val_loss: 0.2341 - val_mse: 0.0548 - val_mae: 0.2334
# Epoch 33/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1000 - mse: 0.0100 - mae: 0.0759 - val_loss: 0.2329 - val_mse: 0.0542 - val_mae: 0.2323
# Epoch 34/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0993 - mse: 0.0099 - mae: 0.0754 - val_loss: 0.2314 - val_mse: 0.0536 - val_mae: 0.2308
# Epoch 35/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0986 - mse: 0.0097 - mae: 0.0749 - val_loss: 0.2298 - val_mse: 0.0528 - val_mae: 0.2292
# Epoch 36/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0979 - mse: 0.0096 - mae: 0.0744 - val_loss: 0.2274 - val_mse: 0.0517 - val_mae: 0.2268
# Epoch 37/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0973 - mse: 0.0095 - mae: 0.0738 - val_loss: 0.2236 - val_mse: 0.0500 - val_mae: 0.2229
# Epoch 38/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0964 - mse: 0.0093 - mae: 0.0733 - val_loss: 0.2202 - val_mse: 0.0485 - val_mae: 0.2196
# Epoch 39/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0954 - mse: 0.0092 - mae: 0.0728 - val_loss: 0.2168 - val_mse: 0.0470 - val_mae: 0.2162
# Epoch 40/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0948 - mse: 0.0090 - mae: 0.0722 - val_loss: 0.2116 - val_mse: 0.0448 - val_mae: 0.2110
# 1/1 [==============================] - 1s 545ms/step
# 3
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f812baa0700> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f812baa0700>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 313ms/step - loss: 0.2945 - mse: 0.0867 - mae: 0.2687 - val_loss: 0.5446 - val_mse: 0.2966 - val_mae: 0.5443
# Epoch 2/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.2805 - mse: 0.0787 - mae: 0.2539 - val_loss: 0.5278 - val_mse: 0.2785 - val_mae: 0.5274
# Epoch 3/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2664 - mse: 0.0710 - mae: 0.2389 - val_loss: 0.5101 - val_mse: 0.2602 - val_mae: 0.5098
# Epoch 4/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2516 - mse: 0.0635 - mae: 0.2238 - val_loss: 0.4914 - val_mse: 0.2415 - val_mae: 0.4911
# Epoch 5/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2364 - mse: 0.0559 - mae: 0.2083 - val_loss: 0.4713 - val_mse: 0.2221 - val_mae: 0.4710
# Epoch 6/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2200 - mse: 0.0484 - mae: 0.1921 - val_loss: 0.4495 - val_mse: 0.2021 - val_mae: 0.4492
# Epoch 7/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2029 - mse: 0.0412 - mae: 0.1761 - val_loss: 0.4257 - val_mse: 0.1813 - val_mae: 0.4254
# Epoch 8/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1848 - mse: 0.0342 - mae: 0.1595 - val_loss: 0.3997 - val_mse: 0.1598 - val_mae: 0.3994
# Epoch 9/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1659 - mse: 0.0276 - mae: 0.1416 - val_loss: 0.3713 - val_mse: 0.1378 - val_mae: 0.3709
# Epoch 10/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1470 - mse: 0.0218 - mae: 0.1237 - val_loss: 0.3404 - val_mse: 0.1159 - val_mae: 0.3400
# Epoch 11/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1289 - mse: 0.0168 - mae: 0.1052 - val_loss: 0.3077 - val_mse: 0.0947 - val_mae: 0.3072
# Epoch 12/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1156 - mse: 0.0134 - mae: 0.0896 - val_loss: 0.2736 - val_mse: 0.0749 - val_mae: 0.2729
# Epoch 13/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1079 - mse: 0.0117 - mae: 0.0818 - val_loss: 0.2419 - val_mse: 0.0585 - val_mae: 0.2410
# Epoch 14/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1075 - mse: 0.0116 - mae: 0.0823 - val_loss: 0.2191 - val_mse: 0.0480 - val_mae: 0.2181
# Epoch 15/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1109 - mse: 0.0123 - mae: 0.0864 - val_loss: 0.2086 - val_mse: 0.0435 - val_mae: 0.2075
# Epoch 16/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1127 - mse: 0.0128 - mae: 0.0890 - val_loss: 0.2093 - val_mse: 0.0438 - val_mae: 0.2083
# Epoch 17/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1109 - mse: 0.0125 - mae: 0.0876 - val_loss: 0.2190 - val_mse: 0.0480 - val_mae: 0.2181
# Epoch 18/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1085 - mse: 0.0118 - mae: 0.0841 - val_loss: 0.2332 - val_mse: 0.0544 - val_mae: 0.2324
# Epoch 19/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1059 - mse: 0.0113 - mae: 0.0812 - val_loss: 0.2461 - val_mse: 0.0606 - val_mae: 0.2454
# Epoch 20/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1052 - mse: 0.0111 - mae: 0.0801 - val_loss: 0.2550 - val_mse: 0.0650 - val_mae: 0.2543
# Epoch 21/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1053 - mse: 0.0111 - mae: 0.0798 - val_loss: 0.2599 - val_mse: 0.0676 - val_mae: 0.2592
# Epoch 22/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1057 - mse: 0.0112 - mae: 0.0798 - val_loss: 0.2609 - val_mse: 0.0681 - val_mae: 0.2603
# Epoch 23/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1053 - mse: 0.0111 - mae: 0.0796 - val_loss: 0.2583 - val_mse: 0.0667 - val_mae: 0.2576
# Epoch 24/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1045 - mse: 0.0110 - mae: 0.0791 - val_loss: 0.2527 - val_mse: 0.0638 - val_mae: 0.2520
# Epoch 25/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1040 - mse: 0.0108 - mae: 0.0786 - val_loss: 0.2459 - val_mse: 0.0605 - val_mae: 0.2452
# Epoch 26/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1030 - mse: 0.0107 - mae: 0.0782 - val_loss: 0.2398 - val_mse: 0.0575 - val_mae: 0.2391
# Epoch 27/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1029 - mse: 0.0106 - mae: 0.0783 - val_loss: 0.2333 - val_mse: 0.0544 - val_mae: 0.2326
# Epoch 28/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1020 - mse: 0.0105 - mae: 0.0782 - val_loss: 0.2303 - val_mse: 0.0531 - val_mae: 0.2296
# Epoch 29/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1018 - mse: 0.0104 - mae: 0.0778 - val_loss: 0.2319 - val_mse: 0.0538 - val_mae: 0.2312
# Epoch 30/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1015 - mse: 0.0103 - mae: 0.0772 - val_loss: 0.2356 - val_mse: 0.0555 - val_mae: 0.2349
# Epoch 31/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1006 - mse: 0.0102 - mae: 0.0764 - val_loss: 0.2383 - val_mse: 0.0568 - val_mae: 0.2376
# Epoch 32/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1003 - mse: 0.0101 - mae: 0.0761 - val_loss: 0.2421 - val_mse: 0.0586 - val_mae: 0.2414
# Epoch 33/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1000 - mse: 0.0100 - mae: 0.0756 - val_loss: 0.2418 - val_mse: 0.0585 - val_mae: 0.2412
# Epoch 34/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0993 - mse: 0.0099 - mae: 0.0752 - val_loss: 0.2383 - val_mse: 0.0568 - val_mae: 0.2377
# Epoch 35/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0984 - mse: 0.0097 - mae: 0.0748 - val_loss: 0.2322 - val_mse: 0.0539 - val_mae: 0.2316
# Epoch 36/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0977 - mse: 0.0096 - mae: 0.0741 - val_loss: 0.2266 - val_mse: 0.0513 - val_mae: 0.2259
# Epoch 37/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0971 - mse: 0.0094 - mae: 0.0737 - val_loss: 0.2206 - val_mse: 0.0487 - val_mae: 0.2199
# Epoch 38/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0962 - mse: 0.0093 - mae: 0.0733 - val_loss: 0.2185 - val_mse: 0.0477 - val_mae: 0.2178
# Epoch 39/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0955 - mse: 0.0091 - mae: 0.0727 - val_loss: 0.2179 - val_mse: 0.0475 - val_mae: 0.2172
# Epoch 40/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0947 - mse: 0.0090 - mae: 0.0720 - val_loss: 0.2185 - val_mse: 0.0477 - val_mae: 0.2179
# 1/1 [==============================] - 1s 518ms/step
# 4
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7f3df1bf70> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7f3df1bf70>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 306ms/step - loss: 0.2940 - mse: 0.0865 - mae: 0.2679 - val_loss: 0.5416 - val_mse: 0.2934 - val_mae: 0.5413
# Epoch 2/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2773 - mse: 0.0769 - mae: 0.2500 - val_loss: 0.5213 - val_mse: 0.2718 - val_mae: 0.5210
# Epoch 3/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2601 - mse: 0.0678 - mae: 0.2323 - val_loss: 0.5003 - val_mse: 0.2503 - val_mae: 0.5000
# Epoch 4/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2431 - mse: 0.0592 - mae: 0.2149 - val_loss: 0.4783 - val_mse: 0.2288 - val_mae: 0.4780
# Epoch 5/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2254 - mse: 0.0508 - mae: 0.1973 - val_loss: 0.4548 - val_mse: 0.2069 - val_mae: 0.4545
# Epoch 6/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2067 - mse: 0.0428 - mae: 0.1796 - val_loss: 0.4295 - val_mse: 0.1845 - val_mae: 0.4292
# Epoch 7/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1866 - mse: 0.0351 - mae: 0.1619 - val_loss: 0.4022 - val_mse: 0.1617 - val_mae: 0.4018
# Epoch 8/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1679 - mse: 0.0282 - mae: 0.1435 - val_loss: 0.3726 - val_mse: 0.1388 - val_mae: 0.3721
# Epoch 9/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1479 - mse: 0.0219 - mae: 0.1246 - val_loss: 0.3407 - val_mse: 0.1161 - val_mae: 0.3402
# Epoch 10/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1302 - mse: 0.0170 - mae: 0.1059 - val_loss: 0.3072 - val_mse: 0.0943 - val_mae: 0.3065
# Epoch 11/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1161 - mse: 0.0135 - mae: 0.0901 - val_loss: 0.2733 - val_mse: 0.0747 - val_mae: 0.2725
# Epoch 12/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1086 - mse: 0.0118 - mae: 0.0822 - val_loss: 0.2417 - val_mse: 0.0584 - val_mae: 0.2407
# Epoch 13/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1087 - mse: 0.0118 - mae: 0.0832 - val_loss: 0.2173 - val_mse: 0.0472 - val_mae: 0.2161
# Epoch 14/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1136 - mse: 0.0129 - mae: 0.0890 - val_loss: 0.2036 - val_mse: 0.0414 - val_mae: 0.2023
# Epoch 15/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1164 - mse: 0.0136 - mae: 0.0922 - val_loss: 0.2040 - val_mse: 0.0416 - val_mae: 0.2027
# Epoch 16/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1144 - mse: 0.0133 - mae: 0.0908 - val_loss: 0.2142 - val_mse: 0.0459 - val_mae: 0.2130
# Epoch 17/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1114 - mse: 0.0124 - mae: 0.0869 - val_loss: 0.2288 - val_mse: 0.0524 - val_mae: 0.2278
# Epoch 18/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1087 - mse: 0.0118 - mae: 0.0833 - val_loss: 0.2432 - val_mse: 0.0592 - val_mae: 0.2423
# Epoch 19/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1066 - mse: 0.0114 - mae: 0.0812 - val_loss: 0.2527 - val_mse: 0.0639 - val_mae: 0.2519
# Epoch 20/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1070 - mse: 0.0114 - mae: 0.0808 - val_loss: 0.2589 - val_mse: 0.0670 - val_mae: 0.2581
# Epoch 21/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1063 - mse: 0.0114 - mae: 0.0806 - val_loss: 0.2601 - val_mse: 0.0677 - val_mae: 0.2593
# Epoch 22/40
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1064 - mse: 0.0114 - mae: 0.0805 - val_loss: 0.2594 - val_mse: 0.0673 - val_mae: 0.2586
# Epoch 23/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1062 - mse: 0.0113 - mae: 0.0802 - val_loss: 0.2557 - val_mse: 0.0654 - val_mae: 0.2549
# Epoch 24/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1057 - mse: 0.0112 - mae: 0.0798 - val_loss: 0.2508 - val_mse: 0.0629 - val_mae: 0.2500
# Epoch 25/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1049 - mse: 0.0110 - mae: 0.0794 - val_loss: 0.2463 - val_mse: 0.0607 - val_mae: 0.2454
# Epoch 26/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1045 - mse: 0.0109 - mae: 0.0791 - val_loss: 0.2427 - val_mse: 0.0589 - val_mae: 0.2418
# Epoch 27/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1039 - mse: 0.0108 - mae: 0.0789 - val_loss: 0.2392 - val_mse: 0.0572 - val_mae: 0.2383
# Epoch 28/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1034 - mse: 0.0107 - mae: 0.0786 - val_loss: 0.2373 - val_mse: 0.0563 - val_mae: 0.2364
# Epoch 29/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1032 - mse: 0.0106 - mae: 0.0782 - val_loss: 0.2357 - val_mse: 0.0556 - val_mae: 0.2348
# Epoch 30/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1025 - mse: 0.0105 - mae: 0.0778 - val_loss: 0.2349 - val_mse: 0.0552 - val_mae: 0.2340
# Epoch 31/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1021 - mse: 0.0104 - mae: 0.0774 - val_loss: 0.2333 - val_mse: 0.0544 - val_mae: 0.2324
# Epoch 32/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1012 - mse: 0.0103 - mae: 0.0769 - val_loss: 0.2294 - val_mse: 0.0526 - val_mae: 0.2285
# Epoch 33/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1005 - mse: 0.0102 - mae: 0.0767 - val_loss: 0.2248 - val_mse: 0.0505 - val_mae: 0.2239
# Epoch 34/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1004 - mse: 0.0101 - mae: 0.0764 - val_loss: 0.2228 - val_mse: 0.0496 - val_mae: 0.2218
# Epoch 35/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0997 - mse: 0.0100 - mae: 0.0759 - val_loss: 0.2229 - val_mse: 0.0497 - val_mae: 0.2219
# Epoch 36/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0989 - mse: 0.0098 - mae: 0.0752 - val_loss: 0.2254 - val_mse: 0.0508 - val_mae: 0.2245
# Epoch 37/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0980 - mse: 0.0096 - mae: 0.0744 - val_loss: 0.2264 - val_mse: 0.0513 - val_mae: 0.2255
# Epoch 38/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0973 - mse: 0.0095 - mae: 0.0738 - val_loss: 0.2255 - val_mse: 0.0509 - val_mae: 0.2247
# Epoch 39/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0966 - mse: 0.0093 - mae: 0.0732 - val_loss: 0.2244 - val_mse: 0.0503 - val_mae: 0.2235
# Epoch 40/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0958 - mse: 0.0092 - mae: 0.0725 - val_loss: 0.2251 - val_mse: 0.0507 - val_mae: 0.2242
# 1/1 [==============================] - 1s 528ms/step
# 5
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7badd09e50> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7badd09e50>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 318ms/step - loss: 0.2972 - mse: 0.0886 - mae: 0.2714 - val_loss: 0.5467 - val_mse: 0.2988 - val_mae: 0.5463
# Epoch 2/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2823 - mse: 0.0799 - mae: 0.2551 - val_loss: 0.5280 - val_mse: 0.2788 - val_mae: 0.5276
# Epoch 3/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2667 - mse: 0.0713 - mae: 0.2387 - val_loss: 0.5085 - val_mse: 0.2586 - val_mae: 0.5082
# Epoch 4/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2507 - mse: 0.0631 - mae: 0.2223 - val_loss: 0.4879 - val_mse: 0.2380 - val_mae: 0.4875
# Epoch 5/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2341 - mse: 0.0549 - mae: 0.2055 - val_loss: 0.4656 - val_mse: 0.2168 - val_mae: 0.4653
# Epoch 6/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2165 - mse: 0.0469 - mae: 0.1882 - val_loss: 0.4414 - val_mse: 0.1948 - val_mae: 0.4410
# Epoch 7/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1971 - mse: 0.0389 - mae: 0.1706 - val_loss: 0.4147 - val_mse: 0.1720 - val_mae: 0.4143
# Epoch 8/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1771 - mse: 0.0315 - mae: 0.1520 - val_loss: 0.3855 - val_mse: 0.1486 - val_mae: 0.3851
# Epoch 9/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1573 - mse: 0.0248 - mae: 0.1331 - val_loss: 0.3535 - val_mse: 0.1250 - val_mae: 0.3531
# Epoch 10/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1378 - mse: 0.0190 - mae: 0.1130 - val_loss: 0.3194 - val_mse: 0.1020 - val_mae: 0.3189
# Epoch 11/40
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1214 - mse: 0.0147 - mae: 0.0955 - val_loss: 0.2844 - val_mse: 0.0809 - val_mae: 0.2837
# Epoch 12/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1109 - mse: 0.0123 - mae: 0.0842 - val_loss: 0.2513 - val_mse: 0.0631 - val_mae: 0.2504
# Epoch 13/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1083 - mse: 0.0118 - mae: 0.0826 - val_loss: 0.2249 - val_mse: 0.0506 - val_mae: 0.2240
# Epoch 14/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1116 - mse: 0.0125 - mae: 0.0868 - val_loss: 0.2100 - val_mse: 0.0441 - val_mae: 0.2090
# Epoch 15/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1138 - mse: 0.0130 - mae: 0.0898 - val_loss: 0.2091 - val_mse: 0.0437 - val_mae: 0.2081
# Epoch 16/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1126 - mse: 0.0128 - mae: 0.0887 - val_loss: 0.2174 - val_mse: 0.0473 - val_mae: 0.2164
# Epoch 17/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1100 - mse: 0.0121 - mae: 0.0858 - val_loss: 0.2289 - val_mse: 0.0524 - val_mae: 0.2281
# Epoch 18/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1079 - mse: 0.0117 - mae: 0.0829 - val_loss: 0.2416 - val_mse: 0.0584 - val_mae: 0.2408
# Epoch 19/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1061 - mse: 0.0113 - mae: 0.0809 - val_loss: 0.2523 - val_mse: 0.0637 - val_mae: 0.2516
# Epoch 20/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1065 - mse: 0.0113 - mae: 0.0805 - val_loss: 0.2601 - val_mse: 0.0676 - val_mae: 0.2594
# Epoch 21/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1067 - mse: 0.0114 - mae: 0.0806 - val_loss: 0.2630 - val_mse: 0.0692 - val_mae: 0.2624
# Epoch 22/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1064 - mse: 0.0114 - mae: 0.0805 - val_loss: 0.2596 - val_mse: 0.0674 - val_mae: 0.2589
# Epoch 23/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1058 - mse: 0.0112 - mae: 0.0799 - val_loss: 0.2521 - val_mse: 0.0636 - val_mae: 0.2514
# Epoch 24/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1046 - mse: 0.0110 - mae: 0.0792 - val_loss: 0.2433 - val_mse: 0.0592 - val_mae: 0.2426
# Epoch 25/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1038 - mse: 0.0108 - mae: 0.0788 - val_loss: 0.2354 - val_mse: 0.0554 - val_mae: 0.2347
# Epoch 26/40
# ...
# Epoch 36/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1192 - mse: 0.0143 - mae: 0.1035 - val_loss: 0.2897 - val_mse: 0.0839 - val_mae: 0.2811
# Epoch 37/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1167 - mse: 0.0136 - mae: 0.1013 - val_loss: 0.2822 - val_mse: 0.0797 - val_mae: 0.2738
# Epoch 38/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1134 - mse: 0.0129 - mae: 0.0985 - val_loss: 0.2757 - val_mse: 0.0760 - val_mae: 0.2675
# Epoch 39/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1099 - mse: 0.0121 - mae: 0.0953 - val_loss: 0.2725 - val_mse: 0.0743 - val_mae: 0.2647
# Epoch 40/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1058 - mse: 0.0112 - mae: 0.0917 - val_loss: 0.2603 - val_mse: 0.0678 - val_mae: 0.2526
# 1/1 [==============================] - 1s 535ms/step
# 148
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f800a97b0d0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f800a97b0d0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4/4 [==============================] - 3s 198ms/step - loss: 0.4050 - mse: 0.1642 - mae: 0.3639 - val_loss: 0.7886 - val_mse: 0.6219 - val_mae: 0.7818
# Epoch 2/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3845 - mse: 0.1478 - mae: 0.3418 - val_loss: 0.7635 - val_mse: 0.5830 - val_mae: 0.7566
# Epoch 3/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3636 - mse: 0.1326 - mae: 0.3199 - val_loss: 0.7375 - val_mse: 0.5439 - val_mae: 0.7305
# Epoch 4/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3425 - mse: 0.1175 - mae: 0.2977 - val_loss: 0.7094 - val_mse: 0.5032 - val_mae: 0.7023
# Epoch 5/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3193 - mse: 0.1025 - mae: 0.2747 - val_loss: 0.6782 - val_mse: 0.4600 - val_mae: 0.6709
# Epoch 6/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2949 - mse: 0.0872 - mae: 0.2500 - val_loss: 0.6430 - val_mse: 0.4135 - val_mae: 0.6355
# Epoch 7/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2677 - mse: 0.0717 - mae: 0.2232 - val_loss: 0.6028 - val_mse: 0.3634 - val_mae: 0.5950
# Epoch 8/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2371 - mse: 0.0564 - mae: 0.1931 - val_loss: 0.5573 - val_mse: 0.3106 - val_mae: 0.5491
# Epoch 9/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2081 - mse: 0.0435 - mae: 0.1642 - val_loss: 0.5062 - val_mse: 0.2562 - val_mae: 0.4975
# Epoch 10/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1789 - mse: 0.0321 - mae: 0.1406 - val_loss: 0.4514 - val_mse: 0.2038 - val_mae: 0.4421
# Epoch 11/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1598 - mse: 0.0255 - mae: 0.1326 - val_loss: 0.3970 - val_mse: 0.1576 - val_mae: 0.3867
# Epoch 12/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1532 - mse: 0.0235 - mae: 0.1350 - val_loss: 0.3535 - val_mse: 0.1250 - val_mae: 0.3423
# Epoch 13/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1557 - mse: 0.0243 - mae: 0.1367 - val_loss: 0.3315 - val_mse: 0.1099 - val_mae: 0.3197
# Epoch 14/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1590 - mse: 0.0253 - mae: 0.1384 - val_loss: 0.3315 - val_mse: 0.1099 - val_mae: 0.3198
# Epoch 15/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1563 - mse: 0.0244 - mae: 0.1367 - val_loss: 0.3468 - val_mse: 0.1203 - val_mae: 0.3357
# Epoch 16/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1515 - mse: 0.0230 - mae: 0.1332 - val_loss: 0.3674 - val_mse: 0.1350 - val_mae: 0.3569
# Epoch 17/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1486 - mse: 0.0222 - mae: 0.1309 - val_loss: 0.3837 - val_mse: 0.1472 - val_mae: 0.3737
# Epoch 18/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1481 - mse: 0.0220 - mae: 0.1292 - val_loss: 0.3889 - val_mse: 0.1512 - val_mae: 0.3790
# Epoch 19/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1476 - mse: 0.0218 - mae: 0.1279 - val_loss: 0.3855 - val_mse: 0.1486 - val_mae: 0.3758
# Epoch 20/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1460 - mse: 0.0213 - mae: 0.1269 - val_loss: 0.3741 - val_mse: 0.1400 - val_mae: 0.3643
# Epoch 21/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1447 - mse: 0.0210 - mae: 0.1269 - val_loss: 0.3554 - val_mse: 0.1263 - val_mae: 0.3453
# Epoch 22/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1433 - mse: 0.0206 - mae: 0.1263 - val_loss: 0.3443 - val_mse: 0.1185 - val_mae: 0.3341
# Epoch 23/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1422 - mse: 0.0203 - mae: 0.1255 - val_loss: 0.3401 - val_mse: 0.1157 - val_mae: 0.3300
# Epoch 24/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1408 - mse: 0.0198 - mae: 0.1241 - val_loss: 0.3446 - val_mse: 0.1188 - val_mae: 0.3348
# Epoch 25/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1388 - mse: 0.0193 - mae: 0.1220 - val_loss: 0.3510 - val_mse: 0.1232 - val_mae: 0.3415
# Epoch 26/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1372 - mse: 0.0188 - mae: 0.1200 - val_loss: 0.3516 - val_mse: 0.1236 - val_mae: 0.3423
# Epoch 27/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1354 - mse: 0.0184 - mae: 0.1182 - val_loss: 0.3483 - val_mse: 0.1213 - val_mae: 0.3391
# Epoch 28/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1336 - mse: 0.0179 - mae: 0.1165 - val_loss: 0.3389 - val_mse: 0.1149 - val_mae: 0.3298
# Epoch 29/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1313 - mse: 0.0173 - mae: 0.1152 - val_loss: 0.3234 - val_mse: 0.1046 - val_mae: 0.3142
# Epoch 30/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1298 - mse: 0.0168 - mae: 0.1140 - val_loss: 0.3092 - val_mse: 0.0956 - val_mae: 0.2999
# Epoch 31/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1273 - mse: 0.0162 - mae: 0.1120 - val_loss: 0.3091 - val_mse: 0.0956 - val_mae: 0.3001
# Epoch 32/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1246 - mse: 0.0155 - mae: 0.1093 - val_loss: 0.3148 - val_mse: 0.0991 - val_mae: 0.3063
# Epoch 33/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1222 - mse: 0.0150 - mae: 0.1065 - val_loss: 0.3154 - val_mse: 0.0995 - val_mae: 0.3071
# Epoch 34/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1198 - mse: 0.0144 - mae: 0.1040 - val_loss: 0.3024 - val_mse: 0.0915 - val_mae: 0.2942
# Epoch 35/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1162 - mse: 0.0135 - mae: 0.1015 - val_loss: 0.2864 - val_mse: 0.0820 - val_mae: 0.2781
# Epoch 36/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1132 - mse: 0.0128 - mae: 0.0992 - val_loss: 0.2724 - val_mse: 0.0742 - val_mae: 0.2641
# Epoch 37/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1101 - mse: 0.0121 - mae: 0.0965 - val_loss: 0.2635 - val_mse: 0.0694 - val_mae: 0.2554
# Epoch 38/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1063 - mse: 0.0113 - mae: 0.0930 - val_loss: 0.2642 - val_mse: 0.0698 - val_mae: 0.2566
# Epoch 39/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1021 - mse: 0.0105 - mae: 0.0890 - val_loss: 0.2584 - val_mse: 0.0668 - val_mae: 0.2511
# Epoch 40/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0974 - mse: 0.0096 - mae: 0.0850 - val_loss: 0.2428 - val_mse: 0.0589 - val_mae: 0.2356
# 1/1 [==============================] - 1s 539ms/step
# 149
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7f09093f70> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7f09093f70>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4/4 [==============================] - 3s 202ms/step - loss: 0.4047 - mse: 0.1639 - mae: 0.3632 - val_loss: 0.7932 - val_mse: 0.6291 - val_mae: 0.7863
# Epoch 2/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3853 - mse: 0.1486 - mae: 0.3427 - val_loss: 0.7693 - val_mse: 0.5918 - val_mae: 0.7623
# Epoch 3/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3661 - mse: 0.1340 - mae: 0.3220 - val_loss: 0.7439 - val_mse: 0.5535 - val_mae: 0.7368
# Epoch 4/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3454 - mse: 0.1195 - mae: 0.3007 - val_loss: 0.7163 - val_mse: 0.5130 - val_mae: 0.7090
# Epoch 5/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3227 - mse: 0.1047 - mae: 0.2779 - val_loss: 0.6854 - val_mse: 0.4698 - val_mae: 0.6780
# Epoch 6/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2989 - mse: 0.0894 - mae: 0.2538 - val_loss: 0.6506 - val_mse: 0.4232 - val_mae: 0.6430
# Epoch 7/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2715 - mse: 0.0738 - mae: 0.2272 - val_loss: 0.6107 - val_mse: 0.3730 - val_mae: 0.6029
# Epoch 8/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2426 - mse: 0.0589 - mae: 0.1990 - val_loss: 0.5651 - val_mse: 0.3193 - val_mae: 0.5570
# Epoch 9/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2117 - mse: 0.0449 - mae: 0.1683 - val_loss: 0.5140 - val_mse: 0.2642 - val_mae: 0.5054
# Epoch 10/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1832 - mse: 0.0337 - mae: 0.1432 - val_loss: 0.4593 - val_mse: 0.2109 - val_mae: 0.4501
# Epoch 11/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1602 - mse: 0.0257 - mae: 0.1309 - val_loss: 0.4054 - val_mse: 0.1643 - val_mae: 0.3953
# Epoch 12/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1511 - mse: 0.0229 - mae: 0.1316 - val_loss: 0.3594 - val_mse: 0.1292 - val_mae: 0.3484
# Epoch 13/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1522 - mse: 0.0232 - mae: 0.1336 - val_loss: 0.3330 - val_mse: 0.1109 - val_mae: 0.3213
# Epoch 14/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1555 - mse: 0.0243 - mae: 0.1356 - val_loss: 0.3271 - val_mse: 0.1070 - val_mae: 0.3153
# Epoch 15/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1547 - mse: 0.0240 - mae: 0.1348 - val_loss: 0.3351 - val_mse: 0.1123 - val_mae: 0.3237
# Epoch 16/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1511 - mse: 0.0228 - mae: 0.1323 - val_loss: 0.3504 - val_mse: 0.1228 - val_mae: 0.3396
# Epoch 17/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1475 - mse: 0.0218 - mae: 0.1298 - val_loss: 0.3687 - val_mse: 0.1360 - val_mae: 0.3584
# Epoch 18/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1455 - mse: 0.0212 - mae: 0.1274 - val_loss: 0.3803 - val_mse: 0.1446 - val_mae: 0.3704
# Epoch 19/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1449 - mse: 0.0210 - mae: 0.1257 - val_loss: 0.3819 - val_mse: 0.1459 - val_mae: 0.3722
# Epoch 20/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1438 - mse: 0.0207 - mae: 0.1246 - val_loss: 0.3738 - val_mse: 0.1397 - val_mae: 0.3641
# Epoch 21/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1421 - mse: 0.0202 - mae: 0.1236 - val_loss: 0.3652 - val_mse: 0.1334 - val_mae: 0.3554
# Epoch 22/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1402 - mse: 0.0197 - mae: 0.1225 - val_loss: 0.3597 - val_mse: 0.1294 - val_mae: 0.3501
# Epoch 23/40
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1386 - mse: 0.0193 - mae: 0.1212 - val_loss: 0.3553 - val_mse: 0.1262 - val_mae: 0.3457
# Epoch 24/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1368 - mse: 0.0188 - mae: 0.1197 - val_loss: 0.3509 - val_mse: 0.1231 - val_mae: 0.3414
# Epoch 25/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1350 - mse: 0.0183 - mae: 0.1182 - val_loss: 0.3438 - val_mse: 0.1182 - val_mae: 0.3344
# Epoch 26/40
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1333 - mse: 0.0178 - mae: 0.1166 - val_loss: 0.3368 - val_mse: 0.1134 - val_mae: 0.3274
# Epoch 27/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1312 - mse: 0.0173 - mae: 0.1149 - val_loss: 0.3304 - val_mse: 0.1091 - val_mae: 0.3212
# Epoch 28/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1291 - mse: 0.0167 - mae: 0.1128 - val_loss: 0.3282 - val_mse: 0.1077 - val_mae: 0.3192
# Epoch 29/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1265 - mse: 0.0161 - mae: 0.1106 - val_loss: 0.3182 - val_mse: 0.1013 - val_mae: 0.3093
# Epoch 30/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1241 - mse: 0.0154 - mae: 0.1084 - val_loss: 0.3112 - val_mse: 0.0968 - val_mae: 0.3024
# Epoch 31/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1212 - mse: 0.0147 - mae: 0.1061 - val_loss: 0.2967 - val_mse: 0.0881 - val_mae: 0.2880
# Epoch 32/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1182 - mse: 0.0140 - mae: 0.1038 - val_loss: 0.2898 - val_mse: 0.0840 - val_mae: 0.2813
# Epoch 33/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1151 - mse: 0.0132 - mae: 0.1009 - val_loss: 0.2853 - val_mse: 0.0814 - val_mae: 0.2770
# Epoch 34/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1114 - mse: 0.0124 - mae: 0.0976 - val_loss: 0.2738 - val_mse: 0.0750 - val_mae: 0.2657
# Epoch 35/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1078 - mse: 0.0116 - mae: 0.0945 - val_loss: 0.2603 - val_mse: 0.0678 - val_mae: 0.2523
# Epoch 36/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1037 - mse: 0.0108 - mae: 0.0910 - val_loss: 0.2530 - val_mse: 0.0640 - val_mae: 0.2452
# Epoch 37/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0990 - mse: 0.0099 - mae: 0.0869 - val_loss: 0.2461 - val_mse: 0.0606 - val_mae: 0.2387
# Epoch 38/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0944 - mse: 0.0089 - mae: 0.0825 - val_loss: 0.2334 - val_mse: 0.0545 - val_mae: 0.2261
# Epoch 39/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0891 - mse: 0.0079 - mae: 0.0778 - val_loss: 0.2182 - val_mse: 0.0476 - val_mae: 0.2111
# Epoch 40/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0834 - mse: 0.0070 - mae: 0.0728 - val_loss: 0.2042 - val_mse: 0.0417 - val_mae: 0.1973
# 1/1 [==============================] - 1s 565ms/step
# 150
# CPU times: user 20min 47s, sys: 52.2 s, total: 21min 39s
# Wall time: 17min 2s
# <ipython-input-1-22ec611b2563>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
# <ipython-input-1-22ec611b2563>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_data.before_close[i+1] = price_data.Close[i]

# %%
lstm_2_pred = scaler_y.inverse_transform(lstm_2_pred.reshape(len(x_t),1))

# %%
import pickle
with open(file='/home/whfhrs3260/deeplearning_result_data/lstm_2_pred_2016_2017.pkl', mode='wb') as f:
    pickle.dump(lstm_2_pred, f)
