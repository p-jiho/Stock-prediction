# %%
import json
import numpy as np
import pandas as pd

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import regex as re
from nltk.corpus import stopwords

from nltk.sentiment.vader import SentimentIntensityAnalyzer
import datetime

import yfinance as yf
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.layers import Embedding, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import optimizers
from keras import backend as K
import matplotlib.pyplot as plt

import datetime
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error 
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error

from multiprocessing import Pool

# %%
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
# 데이터 생성, 처리
def time_conversion(time):
    time = pd.Timestamp(time)
    return time

def date_cut_day(dataframe_date_timestamp):
    dataframe_date_timestamp = datetime.datetime.strftime(dataframe_date_timestamp, "%Y-%m-%d")
    return dataframe_date_timestamp

def train_test_result(dir, stock, variable, window_size):
    #score data 뽑기
    score = pd.read_csv(dir)
    score.columns = ["Date", "Score"]
    
    #price data 뽑기
    price_data = yf.download([stock],start = '2012-01-01', end = "2022-05-01")
    
    opening = price_data.index.copy()
    opening = pd.DataFrame(opening)
    opening["opening_date"] = 1
    opening.Date = opening.Date.apply(lambda x: date_cut_day(x))
    
    Date = pd.date_range(start='20111230', end='20220430')
    Date = pd.DataFrame({"Date" : Date.values})
    Date.Date = Date.Date.apply(lambda x: date_cut_day(x))

    
    set_news_data_date = pd.merge(Date, opening, how ="left",left_on='Date', right_on = "Date") 
    set_news_data_date = set_news_data_date.where(pd.notnull(set_news_data_date), 0) 
    set_news_data_date.Date = set_news_data_date.Date.apply(lambda x: pd.to_datetime(x, errors="ignore"))

    standard=set_news_data_date.Date.iloc[len(set_news_data_date)-1] + datetime.timedelta(days=1)
    set_news_data_date["price_date"]=0
    for i in range(len(set_news_data_date)-1,-1,-1):
        if i==(len(set_news_data_date)-1):
            standard = set_news_data_date.Date[i]
            set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
        elif (set_news_data_date.opening_date[i]==1)&(set_news_data_date.opening_date[i+1]==1):
            standard = set_news_data_date.Date[i]
            set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
        elif (i!=0):
            if((set_news_data_date.opening_date[i]==1)&(set_news_data_date.opening_date[i+1]==0)&(set_news_data_date.opening_date[i-1]==0)):
                set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
                standard = set_news_data_date.Date[i]
            else:
                set_news_data_date.price_date[i]=standard
        else:
            set_news_data_date.price_date[i]=standard
    
    set_news_data_date.Date = set_news_data_date.Date.apply(lambda x: date_cut_day(x))
    
    score = pd.merge(set_news_data_date,score, how ="left",on = "Date")
    
    score = score[['Date','Score', "price_date"]]
    score = score.groupby('price_date').mean({"Score"})
    score = score[score.index<="2022-04-29"]

    first_data = yf.download([stock],start = '2011-12-30', end = '2012-01-01')
    
    price_data = price_data.reset_index()
    score = score.reset_index()
    score.columns = ["Date", "Score"]
    
    price_data = price_data[(price_data["Date"]<"2022-01-01")&("2020-01-01"<=price_data["Date"])]
    
    #price data와 score data 결합
    price_data = pd.merge(price_data, score, how ="left",left_on='Date', right_on = "Date")[["Close","Open","Score"]]

    #뉴스가 없는 날은 즉, score가 없는 날은 중립의 의미로 0으로 처리
    price_data.Score[price_data.Score.isnull()]=0

    #전날 종가의 영향을 받으므로 전날 종가 변수를 생성
    price_data["before_close"] = 0
    price_data = price_data.reset_index(drop=True)
    for i in range(len(price_data)-1):
        price_data.before_close[i+1] = price_data.Close[i]
    
    price_data.before_close[0] = first_data["Close"][0]

    # minmaxscaler 사용
    price_data.columns = ["Close","Open","Score","before_close"]
    
    x = price_data[variable]
    y = price_data[["Close"]]
    scaler_x = MinMaxScaler()
    scaler_y = MinMaxScaler()

    x = pd.DataFrame(scaler_x.fit_transform(x))
    y = pd.DataFrame(scaler_y.fit_transform(y))
    
    x.columns = variable
    y.columns = ["Close"]

    train_index = int(len(x)*0.7)

    train_x = x.iloc[0:train_index]
    test_x = x.iloc[train_index:len(x)]

    train_y = y.iloc[0:train_index]
    test_y = y.iloc[train_index:len(y)]

    train_x = train_x.to_numpy().reshape(train_x.shape[0],1,train_x.shape[1])
    train_y = train_y.to_numpy().reshape(train_y.shape[0],train_y.shape[1])
    test_x = test_x.to_numpy().reshape(test_x.shape[0],1,test_x.shape[1])
    test_y = test_y.to_numpy().reshape(test_y.shape[0],test_y.shape[1])
    
    #window size에 맞게 데이터 설정
    x = np.zeros(shape=(train_x.shape[0]-window_size+1,window_size,x.shape[1]))
    for i in range(train_x.shape[0]-window_size+1):
        x[i]=np.vstack((train_x[i:i+window_size]))

    y = train_y[window_size-1:train_x.shape[0]]

    x_t = np.zeros(shape=(test_x.shape[0]-window_size+1,window_size,x.shape[2]))
    for i in range(test_x.shape[0]-window_size+1):
        x_t[i]=np.vstack((test_x[i:i+window_size]))
    
    y_t = test_y[window_size-1:test_x.shape[0]]
    
    return scaler_x, scaler_y, x, y, x_t, y_t

# %%
# %%time
dir = "/home/whfhrs3260/csv_data/price_data_score_10years.csv"
stock = "^DJI"
variable = ["before_close","Score"]
window_size = 1

scaler_x, scaler_y, x, y, x_t, y_t = train_test_result(dir, stock, variable, window_size)


lstm_2_pred = []
model_input = 0
len_x = x.shape[0]
len_y = y.shape[0]


for i in range(len(x_t)):
    lstm_2_model = Sequential()
    lstm_2_model.add(LSTM(50, input_shape = (x.shape[1],x.shape[2]),return_sequences=True))
    lstm_2_model.add((LSTM(50)))
    lstm_2_model.add(Dense(1,activation="tanh"))
    def root_mean_squared_error(y_true, y_pred):
            return K.sqrt(K.mean(K.square(y_pred - y_true))) 
    lstm_2_model.compile(optimizer="adam", loss = root_mean_squared_error, metrics=['mse',"mae"])
    lstm_2_model.fit(x, y, epochs=40, batch_size=128, validation_split=0.2)
    
    model_input = x_t[i].reshape(1, window_size, len(variable))
    lstm_2_pred = np.append(lstm_2_pred,lstm_2_model.predict(model_input)[0])

    x = np.append(x,x_t[i])
    y = np.append(y,y_t[i])
    len_x += 1
    len_y += 1
    x = x.reshape(len_x,window_size,len(variable))
    y = y.reshape(len_y,1)
    print(i)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7bc40c11f0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7bc40c11f0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 312ms/step - loss: 0.5039 - mse: 0.2540 - mae: 0.4812 - val_loss: 0.7968 - val_mse: 0.6349 - val_mae: 0.7945
# Epoch 2/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4873 - mse: 0.2377 - mae: 0.4642 - val_loss: 0.7780 - val_mse: 0.6052 - val_mae: 0.7756
# Epoch 3/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4703 - mse: 0.2213 - mae: 0.4466 - val_loss: 0.7582 - val_mse: 0.5748 - val_mae: 0.7558
# Epoch 4/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4524 - mse: 0.2046 - mae: 0.4281 - val_loss: 0.7370 - val_mse: 0.5432 - val_mae: 0.7346
# Epoch 5/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4331 - mse: 0.1876 - mae: 0.4083 - val_loss: 0.7140 - val_mse: 0.5098 - val_mae: 0.7115
# Epoch 6/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4123 - mse: 0.1701 - mae: 0.3871 - val_loss: 0.6888 - val_mse: 0.4744 - val_mae: 0.6862
# Epoch 7/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3897 - mse: 0.1520 - mae: 0.3638 - val_loss: 0.6608 - val_mse: 0.4367 - val_mae: 0.6582
# Epoch 8/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3646 - mse: 0.1330 - mae: 0.3384 - val_loss: 0.6298 - val_mse: 0.3967 - val_mae: 0.6271
# Epoch 9/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3373 - mse: 0.1140 - mae: 0.3109 - val_loss: 0.5953 - val_mse: 0.3544 - val_mae: 0.5924
# Epoch 10/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3073 - mse: 0.0947 - mae: 0.2809 - val_loss: 0.5571 - val_mse: 0.3104 - val_mae: 0.5541
# Epoch 11/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2748 - mse: 0.0757 - mae: 0.2484 - val_loss: 0.5150 - val_mse: 0.2652 - val_mae: 0.5117
# Epoch 12/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2402 - mse: 0.0577 - mae: 0.2133 - val_loss: 0.4690 - val_mse: 0.2200 - val_mae: 0.4654
# Epoch 13/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.2046 - mse: 0.0419 - mae: 0.1806 - val_loss: 0.4195 - val_mse: 0.1759 - val_mae: 0.4155
# Epoch 14/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1715 - mse: 0.0294 - mae: 0.1499 - val_loss: 0.3677 - val_mse: 0.1352 - val_mae: 0.3632
# Epoch 15/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1444 - mse: 0.0209 - mae: 0.1220 - val_loss: 0.3176 - val_mse: 0.1009 - val_mae: 0.3125
# Epoch 16/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1314 - mse: 0.0173 - mae: 0.1059 - val_loss: 0.2755 - val_mse: 0.0759 - val_mae: 0.2695
# Epoch 17/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1315 - mse: 0.0174 - mae: 0.1001 - val_loss: 0.2480 - val_mse: 0.0615 - val_mae: 0.2414
# Epoch 18/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1371 - mse: 0.0189 - mae: 0.1022 - val_loss: 0.2358 - val_mse: 0.0556 - val_mae: 0.2289
# Epoch 19/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1399 - mse: 0.0197 - mae: 0.1041 - val_loss: 0.2371 - val_mse: 0.0562 - val_mae: 0.2303
# Epoch 20/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1381 - mse: 0.0192 - mae: 0.1028 - val_loss: 0.2479 - val_mse: 0.0615 - val_mae: 0.2415
# Epoch 21/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1343 - mse: 0.0180 - mae: 0.1005 - val_loss: 0.2626 - val_mse: 0.0690 - val_mae: 0.2566
# Epoch 22/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1294 - mse: 0.0170 - mae: 0.0994 - val_loss: 0.2762 - val_mse: 0.0763 - val_mae: 0.2705
# Epoch 23/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1280 - mse: 0.0165 - mae: 0.1000 - val_loss: 0.2857 - val_mse: 0.0816 - val_mae: 0.2802
# Epoch 24/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1272 - mse: 0.0163 - mae: 0.1010 - val_loss: 0.2925 - val_mse: 0.0856 - val_mae: 0.2872
# Epoch 25/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1270 - mse: 0.0163 - mae: 0.1021 - val_loss: 0.2970 - val_mse: 0.0882 - val_mae: 0.2918
# Epoch 26/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1276 - mse: 0.0163 - mae: 0.1028 - val_loss: 0.2984 - val_mse: 0.0890 - val_mae: 0.2932
# Epoch 27/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1273 - mse: 0.0162 - mae: 0.1028 - val_loss: 0.2969 - val_mse: 0.0882 - val_mae: 0.2918
# Epoch 28/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1269 - mse: 0.0161 - mae: 0.1023 - val_loss: 0.2935 - val_mse: 0.0861 - val_mae: 0.2884
# Epoch 29/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1260 - mse: 0.0159 - mae: 0.1014 - val_loss: 0.2889 - val_mse: 0.0835 - val_mae: 0.2838
# Epoch 30/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1253 - mse: 0.0157 - mae: 0.1003 - val_loss: 0.2829 - val_mse: 0.0800 - val_mae: 0.2777
# Epoch 31/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1244 - mse: 0.0155 - mae: 0.0990 - val_loss: 0.2774 - val_mse: 0.0770 - val_mae: 0.2722
# Epoch 32/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1238 - mse: 0.0154 - mae: 0.0979 - val_loss: 0.2730 - val_mse: 0.0745 - val_mae: 0.2677
# Epoch 33/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1228 - mse: 0.0152 - mae: 0.0971 - val_loss: 0.2714 - val_mse: 0.0736 - val_mae: 0.2661
# Epoch 34/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1224 - mse: 0.0151 - mae: 0.0966 - val_loss: 0.2703 - val_mse: 0.0730 - val_mae: 0.2651
# Epoch 35/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1219 - mse: 0.0149 - mae: 0.0962 - val_loss: 0.2700 - val_mse: 0.0729 - val_mae: 0.2648
# Epoch 36/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1209 - mse: 0.0147 - mae: 0.0959 - val_loss: 0.2694 - val_mse: 0.0726 - val_mae: 0.2643
# Epoch 37/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1204 - mse: 0.0146 - mae: 0.0954 - val_loss: 0.2656 - val_mse: 0.0705 - val_mae: 0.2605
# Epoch 38/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1200 - mse: 0.0144 - mae: 0.0943 - val_loss: 0.2591 - val_mse: 0.0671 - val_mae: 0.2539
# Epoch 39/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1194 - mse: 0.0143 - mae: 0.0932 - val_loss: 0.2551 - val_mse: 0.0651 - val_mae: 0.2500
# Epoch 40/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1186 - mse: 0.0141 - mae: 0.0924 - val_loss: 0.2546 - val_mse: 0.0648 - val_mae: 0.2495
# 1/1 [==============================] - 1s 530ms/step
# 0
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7bc5690040> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7bc5690040>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 304ms/step - loss: 0.5050 - mse: 0.2550 - mae: 0.4822 - val_loss: 0.7990 - val_mse: 0.6383 - val_mae: 0.7967
# Epoch 2/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4889 - mse: 0.2390 - mae: 0.4656 - val_loss: 0.7806 - val_mse: 0.6093 - val_mae: 0.7783
# Epoch 3/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4723 - mse: 0.2231 - mae: 0.4486 - val_loss: 0.7613 - val_mse: 0.5796 - val_mae: 0.7590
# Epoch 4/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4547 - mse: 0.2068 - mae: 0.4307 - val_loss: 0.7406 - val_mse: 0.5485 - val_mae: 0.7383
# Epoch 5/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4362 - mse: 0.1903 - mae: 0.4114 - val_loss: 0.7181 - val_mse: 0.5156 - val_mae: 0.7156
# Epoch 6/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4157 - mse: 0.1728 - mae: 0.3905 - val_loss: 0.6932 - val_mse: 0.4805 - val_mae: 0.6907
# Epoch 7/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3931 - mse: 0.1546 - mae: 0.3675 - val_loss: 0.6655 - val_mse: 0.4430 - val_mae: 0.6630
# Epoch 8/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3686 - mse: 0.1359 - mae: 0.3421 - val_loss: 0.6347 - val_mse: 0.4028 - val_mae: 0.6320
# Epoch 9/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3411 - mse: 0.1163 - mae: 0.3145 - val_loss: 0.6002 - val_mse: 0.3602 - val_mae: 0.5973
# Epoch 10/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3111 - mse: 0.0968 - mae: 0.2847 - val_loss: 0.5618 - val_mse: 0.3156 - val_mae: 0.5588
# Epoch 11/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2782 - mse: 0.0774 - mae: 0.2515 - val_loss: 0.5193 - val_mse: 0.2696 - val_mae: 0.5160
# Epoch 12/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2430 - mse: 0.0593 - mae: 0.2165 - val_loss: 0.4726 - val_mse: 0.2234 - val_mae: 0.4691
# Epoch 13/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2073 - mse: 0.0430 - mae: 0.1828 - val_loss: 0.4224 - val_mse: 0.1785 - val_mae: 0.4185
# Epoch 14/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1726 - mse: 0.0299 - mae: 0.1514 - val_loss: 0.3699 - val_mse: 0.1368 - val_mae: 0.3654
# Epoch 15/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1455 - mse: 0.0213 - mae: 0.1235 - val_loss: 0.3183 - val_mse: 0.1013 - val_mae: 0.3132
# Epoch 16/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1307 - mse: 0.0172 - mae: 0.1056 - val_loss: 0.2733 - val_mse: 0.0747 - val_mae: 0.2674
# Epoch 17/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1323 - mse: 0.0175 - mae: 0.1000 - val_loss: 0.2405 - val_mse: 0.0578 - val_mae: 0.2338
# Epoch 18/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1389 - mse: 0.0197 - mae: 0.1039 - val_loss: 0.2256 - val_mse: 0.0509 - val_mae: 0.2185
# Epoch 19/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1439 - mse: 0.0208 - mae: 0.1066 - val_loss: 0.2269 - val_mse: 0.0515 - val_mae: 0.2198
# Epoch 20/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1420 - mse: 0.0202 - mae: 0.1054 - val_loss: 0.2384 - val_mse: 0.0568 - val_mae: 0.2317
# Epoch 21/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1362 - mse: 0.0188 - mae: 0.1019 - val_loss: 0.2554 - val_mse: 0.0652 - val_mae: 0.2492
# Epoch 22/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1314 - mse: 0.0173 - mae: 0.0991 - val_loss: 0.2731 - val_mse: 0.0746 - val_mae: 0.2673
# Epoch 23/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1286 - mse: 0.0166 - mae: 0.0997 - val_loss: 0.2887 - val_mse: 0.0834 - val_mae: 0.2833
# Epoch 24/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1279 - mse: 0.0164 - mae: 0.1019 - val_loss: 0.2993 - val_mse: 0.0896 - val_mae: 0.2941
# Epoch 25/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1282 - mse: 0.0164 - mae: 0.1033 - val_loss: 0.3034 - val_mse: 0.0920 - val_mae: 0.2983
# Epoch 26/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1281 - mse: 0.0165 - mae: 0.1038 - val_loss: 0.3019 - val_mse: 0.0912 - val_mae: 0.2969
# Epoch 27/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1276 - mse: 0.0163 - mae: 0.1032 - val_loss: 0.2957 - val_mse: 0.0875 - val_mae: 0.2906
# Epoch 28/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1258 - mse: 0.0160 - mae: 0.1017 - val_loss: 0.2862 - val_mse: 0.0819 - val_mae: 0.2810
# Epoch 29/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1252 - mse: 0.0158 - mae: 0.0996 - val_loss: 0.2768 - val_mse: 0.0766 - val_mae: 0.2715
# Epoch 30/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1251 - mse: 0.0157 - mae: 0.0981 - val_loss: 0.2695 - val_mse: 0.0726 - val_mae: 0.2640
# Epoch 31/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1245 - mse: 0.0156 - mae: 0.0970 - val_loss: 0.2666 - val_mse: 0.0711 - val_mae: 0.2612
# Epoch 32/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1240 - mse: 0.0155 - mae: 0.0965 - val_loss: 0.2670 - val_mse: 0.0713 - val_mae: 0.2616
# Epoch 33/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1237 - mse: 0.0153 - mae: 0.0964 - val_loss: 0.2692 - val_mse: 0.0725 - val_mae: 0.2639
# Epoch 34/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1227 - mse: 0.0152 - mae: 0.0963 - val_loss: 0.2713 - val_mse: 0.0736 - val_mae: 0.2661
# Epoch 35/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1223 - mse: 0.0150 - mae: 0.0964 - val_loss: 0.2732 - val_mse: 0.0746 - val_mae: 0.2681
# Epoch 36/40
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1218 - mse: 0.0149 - mae: 0.0964 - val_loss: 0.2745 - val_mse: 0.0753 - val_mae: 0.2695
# Epoch 37/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1212 - mse: 0.0147 - mae: 0.0963 - val_loss: 0.2754 - val_mse: 0.0759 - val_mae: 0.2705
# Epoch 38/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1205 - mse: 0.0146 - mae: 0.0961 - val_loss: 0.2744 - val_mse: 0.0753 - val_mae: 0.2695
# Epoch 39/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1197 - mse: 0.0144 - mae: 0.0957 - val_loss: 0.2727 - val_mse: 0.0744 - val_mae: 0.2679
# Epoch 40/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1193 - mse: 0.0142 - mae: 0.0952 - val_loss: 0.2692 - val_mse: 0.0725 - val_mae: 0.2643
# 1/1 [==============================] - 1s 531ms/step
# 1
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7f1a40c5e0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7f1a40c5e0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 294ms/step - loss: 0.5020 - mse: 0.2521 - mae: 0.4793 - val_loss: 0.7951 - val_mse: 0.6322 - val_mae: 0.7929
# Epoch 2/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4855 - mse: 0.2358 - mae: 0.4623 - val_loss: 0.7766 - val_mse: 0.6031 - val_mae: 0.7743
# Epoch 3/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4686 - mse: 0.2197 - mae: 0.4449 - val_loss: 0.7571 - val_mse: 0.5732 - val_mae: 0.7548
# Epoch 4/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4507 - mse: 0.2035 - mae: 0.4267 - val_loss: 0.7364 - val_mse: 0.5423 - val_mae: 0.7341
# Epoch 5/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4320 - mse: 0.1867 - mae: 0.4072 - val_loss: 0.7140 - val_mse: 0.5097 - val_mae: 0.7116
# Epoch 6/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4116 - mse: 0.1696 - mae: 0.3862 - val_loss: 0.6894 - val_mse: 0.4753 - val_mae: 0.6869
# Epoch 7/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3892 - mse: 0.1520 - mae: 0.3638 - val_loss: 0.6624 - val_mse: 0.4387 - val_mae: 0.6598
# Epoch 8/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3654 - mse: 0.1336 - mae: 0.3390 - val_loss: 0.6325 - val_mse: 0.4001 - val_mae: 0.6299
# Epoch 9/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.3387 - mse: 0.1150 - mae: 0.3125 - val_loss: 0.5994 - val_mse: 0.3593 - val_mae: 0.5967
# Epoch 10/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3100 - mse: 0.0962 - mae: 0.2835 - val_loss: 0.5629 - val_mse: 0.3169 - val_mae: 0.5599
# Epoch 11/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2783 - mse: 0.0777 - mae: 0.2520 - val_loss: 0.5226 - val_mse: 0.2731 - val_mae: 0.5195
# Epoch 12/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2457 - mse: 0.0606 - mae: 0.2190 - val_loss: 0.4786 - val_mse: 0.2291 - val_mae: 0.4752
# Epoch 13/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2114 - mse: 0.0448 - mae: 0.1862 - val_loss: 0.4313 - val_mse: 0.1861 - val_mae: 0.4276
# Epoch 14/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1767 - mse: 0.0314 - mae: 0.1551 - val_loss: 0.3819 - val_mse: 0.1459 - val_mae: 0.3777
# Epoch 15/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1504 - mse: 0.0227 - mae: 0.1286 - val_loss: 0.3327 - val_mse: 0.1107 - val_mae: 0.3279
# Epoch 16/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1330 - mse: 0.0178 - mae: 0.1084 - val_loss: 0.2890 - val_mse: 0.0835 - val_mae: 0.2835
# Epoch 17/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1312 - mse: 0.0172 - mae: 0.1014 - val_loss: 0.2559 - val_mse: 0.0655 - val_mae: 0.2497
# Epoch 18/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1361 - mse: 0.0187 - mae: 0.1016 - val_loss: 0.2387 - val_mse: 0.0570 - val_mae: 0.2320
# Epoch 19/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1406 - mse: 0.0198 - mae: 0.1044 - val_loss: 0.2367 - val_mse: 0.0560 - val_mae: 0.2300
# Epoch 20/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1397 - mse: 0.0195 - mae: 0.1037 - val_loss: 0.2459 - val_mse: 0.0605 - val_mae: 0.2395
# Epoch 21/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1353 - mse: 0.0184 - mae: 0.1010 - val_loss: 0.2622 - val_mse: 0.0687 - val_mae: 0.2562
# Epoch 22/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1307 - mse: 0.0171 - mae: 0.0994 - val_loss: 0.2799 - val_mse: 0.0783 - val_mae: 0.2744
# Epoch 23/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1285 - mse: 0.0165 - mae: 0.1005 - val_loss: 0.2948 - val_mse: 0.0869 - val_mae: 0.2896
# Epoch 24/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1282 - mse: 0.0164 - mae: 0.1024 - val_loss: 0.3044 - val_mse: 0.0927 - val_mae: 0.2994
# Epoch 25/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1287 - mse: 0.0166 - mae: 0.1041 - val_loss: 0.3083 - val_mse: 0.0951 - val_mae: 0.3034
# Epoch 26/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1288 - mse: 0.0167 - mae: 0.1047 - val_loss: 0.3063 - val_mse: 0.0938 - val_mae: 0.3014
# Epoch 27/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1280 - mse: 0.0165 - mae: 0.1040 - val_loss: 0.3000 - val_mse: 0.0900 - val_mae: 0.2950
# Epoch 28/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1271 - mse: 0.0162 - mae: 0.1025 - val_loss: 0.2921 - val_mse: 0.0853 - val_mae: 0.2871
# Epoch 29/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1259 - mse: 0.0159 - mae: 0.1008 - val_loss: 0.2841 - val_mse: 0.0807 - val_mae: 0.2790
# Epoch 30/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1252 - mse: 0.0157 - mae: 0.0990 - val_loss: 0.2752 - val_mse: 0.0757 - val_mae: 0.2699
# Epoch 31/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1251 - mse: 0.0157 - mae: 0.0975 - val_loss: 0.2684 - val_mse: 0.0720 - val_mae: 0.2630
# Epoch 32/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1248 - mse: 0.0156 - mae: 0.0966 - val_loss: 0.2653 - val_mse: 0.0704 - val_mae: 0.2599
# Epoch 33/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1245 - mse: 0.0155 - mae: 0.0961 - val_loss: 0.2669 - val_mse: 0.0712 - val_mae: 0.2616
# Epoch 34/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1237 - mse: 0.0153 - mae: 0.0961 - val_loss: 0.2701 - val_mse: 0.0729 - val_mae: 0.2649
# Epoch 35/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1229 - mse: 0.0151 - mae: 0.0963 - val_loss: 0.2738 - val_mse: 0.0749 - val_mae: 0.2687
# Epoch 36/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1220 - mse: 0.0150 - mae: 0.0965 - val_loss: 0.2753 - val_mse: 0.0758 - val_mae: 0.2703
# Epoch 37/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1218 - mse: 0.0148 - mae: 0.0965 - val_loss: 0.2757 - val_mse: 0.0760 - val_mae: 0.2707
# Epoch 38/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1213 - mse: 0.0147 - mae: 0.0962 - val_loss: 0.2737 - val_mse: 0.0749 - val_mae: 0.2688
# Epoch 39/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1203 - mse: 0.0146 - mae: 0.0957 - val_loss: 0.2721 - val_mse: 0.0740 - val_mae: 0.2672
# Epoch 40/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1199 - mse: 0.0144 - mae: 0.0952 - val_loss: 0.2704 - val_mse: 0.0731 - val_mae: 0.2656
# 1/1 [==============================] - 1s 531ms/step
# 2
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f8172e4ae50> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f8172e4ae50>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 297ms/step - loss: 0.5065 - mse: 0.2569 - mae: 0.4840 - val_loss: 0.8009 - val_mse: 0.6415 - val_mae: 0.7987
# Epoch 2/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4882 - mse: 0.2384 - mae: 0.4648 - val_loss: 0.7800 - val_mse: 0.6084 - val_mae: 0.7777
# Epoch 3/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4691 - mse: 0.2202 - mae: 0.4453 - val_loss: 0.7582 - val_mse: 0.5749 - val_mae: 0.7559
# Epoch 4/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4494 - mse: 0.2020 - mae: 0.4249 - val_loss: 0.7351 - val_mse: 0.5404 - val_mae: 0.7327
# Epoch 5/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4278 - mse: 0.1837 - mae: 0.4034 - val_loss: 0.7100 - val_mse: 0.5041 - val_mae: 0.7076
# Epoch 6/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4057 - mse: 0.1647 - mae: 0.3801 - val_loss: 0.6825 - val_mse: 0.4658 - val_mae: 0.6800
# Epoch 7/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.3808 - mse: 0.1454 - mae: 0.3550 - val_loss: 0.6522 - val_mse: 0.4253 - val_mae: 0.6495
# Epoch 8/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3536 - mse: 0.1252 - mae: 0.3272 - val_loss: 0.6187 - val_mse: 0.3827 - val_mae: 0.6159
# Epoch 9/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.3247 - mse: 0.1056 - mae: 0.2981 - val_loss: 0.5815 - val_mse: 0.3382 - val_mae: 0.5786
# Epoch 10/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2924 - mse: 0.0856 - mae: 0.2656 - val_loss: 0.5406 - val_mse: 0.2922 - val_mae: 0.5375
# Epoch 11/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2581 - mse: 0.0671 - mae: 0.2315 - val_loss: 0.4957 - val_mse: 0.2457 - val_mae: 0.4923
# Epoch 12/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2219 - mse: 0.0493 - mae: 0.1959 - val_loss: 0.4472 - val_mse: 0.2000 - val_mae: 0.4435
# Epoch 13/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1872 - mse: 0.0352 - mae: 0.1649 - val_loss: 0.3958 - val_mse: 0.1566 - val_mae: 0.3916
# Epoch 14/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1561 - mse: 0.0244 - mae: 0.1337 - val_loss: 0.3440 - val_mse: 0.1184 - val_mae: 0.3393
# Epoch 15/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1357 - mse: 0.0184 - mae: 0.1122 - val_loss: 0.2966 - val_mse: 0.0880 - val_mae: 0.2911
# Epoch 16/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1300 - mse: 0.0170 - mae: 0.1018 - val_loss: 0.2601 - val_mse: 0.0677 - val_mae: 0.2539
# Epoch 17/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1360 - mse: 0.0186 - mae: 0.1019 - val_loss: 0.2393 - val_mse: 0.0572 - val_mae: 0.2326
# Epoch 18/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1413 - mse: 0.0200 - mae: 0.1050 - val_loss: 0.2340 - val_mse: 0.0547 - val_mae: 0.2272
# Epoch 19/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1417 - mse: 0.0201 - mae: 0.1054 - val_loss: 0.2401 - val_mse: 0.0577 - val_mae: 0.2335
# Epoch 20/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1378 - mse: 0.0191 - mae: 0.1027 - val_loss: 0.2550 - val_mse: 0.0650 - val_mae: 0.2489
# Epoch 21/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1329 - mse: 0.0177 - mae: 0.1001 - val_loss: 0.2739 - val_mse: 0.0750 - val_mae: 0.2682
# Epoch 22/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1290 - mse: 0.0167 - mae: 0.0998 - val_loss: 0.2904 - val_mse: 0.0843 - val_mae: 0.2851
# Epoch 23/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1284 - mse: 0.0165 - mae: 0.1020 - val_loss: 0.3019 - val_mse: 0.0912 - val_mae: 0.2969
# Epoch 24/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1287 - mse: 0.0166 - mae: 0.1037 - val_loss: 0.3048 - val_mse: 0.0929 - val_mae: 0.2999
# Epoch 25/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1282 - mse: 0.0165 - mae: 0.1039 - val_loss: 0.3011 - val_mse: 0.0906 - val_mae: 0.2961
# Epoch 26/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1273 - mse: 0.0163 - mae: 0.1028 - val_loss: 0.2935 - val_mse: 0.0861 - val_mae: 0.2884
# Epoch 27/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1264 - mse: 0.0161 - mae: 0.1012 - val_loss: 0.2853 - val_mse: 0.0814 - val_mae: 0.2801
# Epoch 28/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1258 - mse: 0.0158 - mae: 0.0995 - val_loss: 0.2794 - val_mse: 0.0780 - val_mae: 0.2741
# Epoch 29/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1251 - mse: 0.0157 - mae: 0.0984 - val_loss: 0.2750 - val_mse: 0.0756 - val_mae: 0.2697
# Epoch 30/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1248 - mse: 0.0156 - mae: 0.0976 - val_loss: 0.2720 - val_mse: 0.0740 - val_mae: 0.2668
# Epoch 31/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1238 - mse: 0.0154 - mae: 0.0969 - val_loss: 0.2702 - val_mse: 0.0730 - val_mae: 0.2650
# Epoch 32/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1233 - mse: 0.0153 - mae: 0.0965 - val_loss: 0.2708 - val_mse: 0.0733 - val_mae: 0.2656
# Epoch 33/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1227 - mse: 0.0151 - mae: 0.0962 - val_loss: 0.2709 - val_mse: 0.0734 - val_mae: 0.2659
# Epoch 34/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1220 - mse: 0.0149 - mae: 0.0959 - val_loss: 0.2717 - val_mse: 0.0738 - val_mae: 0.2668
# Epoch 35/40
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1212 - mse: 0.0147 - mae: 0.0958 - val_loss: 0.2723 - val_mse: 0.0742 - val_mae: 0.2674
# Epoch 36/40
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1207 - mse: 0.0146 - mae: 0.0957 - val_loss: 0.2732 - val_mse: 0.0746 - val_mae: 0.2683
# Epoch 37/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1196 - mse: 0.0144 - mae: 0.0953 - val_loss: 0.2699 - val_mse: 0.0728 - val_mae: 0.2651
# Epoch 38/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1189 - mse: 0.0142 - mae: 0.0945 - val_loss: 0.2672 - val_mse: 0.0714 - val_mae: 0.2624
# Epoch 39/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1177 - mse: 0.0140 - mae: 0.0937 - val_loss: 0.2651 - val_mse: 0.0703 - val_mae: 0.2603
# Epoch 40/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1172 - mse: 0.0138 - mae: 0.0931 - val_loss: 0.2629 - val_mse: 0.0691 - val_mae: 0.2582
# 1/1 [==============================] - 1s 543ms/step
# 3
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f8358d65430> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f8358d65430>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 303ms/step - loss: 0.5080 - mse: 0.2583 - mae: 0.4852 - val_loss: 0.8048 - val_mse: 0.6477 - val_mae: 0.8026
# Epoch 2/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4892 - mse: 0.2393 - mae: 0.4657 - val_loss: 0.7832 - val_mse: 0.6134 - val_mae: 0.7810
# Epoch 3/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4696 - mse: 0.2206 - mae: 0.4455 - val_loss: 0.7606 - val_mse: 0.5786 - val_mae: 0.7584
# Epoch 4/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4492 - mse: 0.2019 - mae: 0.4244 - val_loss: 0.7367 - val_mse: 0.5427 - val_mae: 0.7344
# Epoch 5/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4275 - mse: 0.1829 - mae: 0.4021 - val_loss: 0.7109 - val_mse: 0.5054 - val_mae: 0.7085
# Epoch 6/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4044 - mse: 0.1635 - mae: 0.3785 - val_loss: 0.6829 - val_mse: 0.4663 - val_mae: 0.6804
# Epoch 7/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3787 - mse: 0.1441 - mae: 0.3529 - val_loss: 0.6521 - val_mse: 0.4253 - val_mae: 0.6495
# Epoch 8/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3518 - mse: 0.1238 - mae: 0.3249 - val_loss: 0.6183 - val_mse: 0.3823 - val_mae: 0.6156
# Epoch 9/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3221 - mse: 0.1039 - mae: 0.2952 - val_loss: 0.5809 - val_mse: 0.3375 - val_mae: 0.5780
# Epoch 10/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.2898 - mse: 0.0840 - mae: 0.2630 - val_loss: 0.5398 - val_mse: 0.2914 - val_mae: 0.5367
# Epoch 11/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2558 - mse: 0.0658 - mae: 0.2288 - val_loss: 0.4950 - val_mse: 0.2450 - val_mae: 0.4916
# Epoch 12/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2199 - mse: 0.0484 - mae: 0.1942 - val_loss: 0.4469 - val_mse: 0.1998 - val_mae: 0.4433
# Epoch 13/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1852 - mse: 0.0345 - mae: 0.1624 - val_loss: 0.3961 - val_mse: 0.1569 - val_mae: 0.3920
# Epoch 14/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1547 - mse: 0.0241 - mae: 0.1330 - val_loss: 0.3448 - val_mse: 0.1189 - val_mae: 0.3401
# Epoch 15/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1358 - mse: 0.0185 - mae: 0.1117 - val_loss: 0.2982 - val_mse: 0.0889 - val_mae: 0.2928
# Epoch 16/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1321 - mse: 0.0176 - mae: 0.1025 - val_loss: 0.2629 - val_mse: 0.0691 - val_mae: 0.2567
# Epoch 17/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1376 - mse: 0.0190 - mae: 0.1029 - val_loss: 0.2432 - val_mse: 0.0591 - val_mae: 0.2366
# Epoch 18/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1425 - mse: 0.0203 - mae: 0.1058 - val_loss: 0.2396 - val_mse: 0.0574 - val_mae: 0.2330
# Epoch 19/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1415 - mse: 0.0203 - mae: 0.1056 - val_loss: 0.2475 - val_mse: 0.0613 - val_mae: 0.2411
# Epoch 20/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1370 - mse: 0.0191 - mae: 0.1029 - val_loss: 0.2612 - val_mse: 0.0682 - val_mae: 0.2552
# Epoch 21/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1338 - mse: 0.0180 - mae: 0.1009 - val_loss: 0.2780 - val_mse: 0.0773 - val_mae: 0.2723
# Epoch 22/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1310 - mse: 0.0172 - mae: 0.1011 - val_loss: 0.2917 - val_mse: 0.0851 - val_mae: 0.2863
# Epoch 23/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1298 - mse: 0.0169 - mae: 0.1025 - val_loss: 0.3021 - val_mse: 0.0913 - val_mae: 0.2970
# Epoch 24/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1297 - mse: 0.0168 - mae: 0.1039 - val_loss: 0.3068 - val_mse: 0.0941 - val_mae: 0.3018
# Epoch 25/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1296 - mse: 0.0169 - mae: 0.1046 - val_loss: 0.3065 - val_mse: 0.0939 - val_mae: 0.3015
# Epoch 26/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1295 - mse: 0.0168 - mae: 0.1043 - val_loss: 0.3032 - val_mse: 0.0919 - val_mae: 0.2982
# Epoch 27/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1287 - mse: 0.0166 - mae: 0.1033 - val_loss: 0.2970 - val_mse: 0.0882 - val_mae: 0.2919
# Epoch 28/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1277 - mse: 0.0164 - mae: 0.1019 - val_loss: 0.2911 - val_mse: 0.0848 - val_mae: 0.2860
# Epoch 29/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1272 - mse: 0.0162 - mae: 0.1006 - val_loss: 0.2857 - val_mse: 0.0816 - val_mae: 0.2806
# Epoch 30/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1268 - mse: 0.0161 - mae: 0.0997 - val_loss: 0.2817 - val_mse: 0.0794 - val_mae: 0.2765
# Epoch 31/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1263 - mse: 0.0160 - mae: 0.0990 - val_loss: 0.2803 - val_mse: 0.0786 - val_mae: 0.2751
# Epoch 32/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1253 - mse: 0.0159 - mae: 0.0985 - val_loss: 0.2794 - val_mse: 0.0780 - val_mae: 0.2742
# Epoch 33/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1250 - mse: 0.0157 - mae: 0.0982 - val_loss: 0.2794 - val_mse: 0.0780 - val_mae: 0.2743
# Epoch 34/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1244 - mse: 0.0156 - mae: 0.0979 - val_loss: 0.2786 - val_mse: 0.0776 - val_mae: 0.2736
# Epoch 35/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1243 - mse: 0.0155 - mae: 0.0976 - val_loss: 0.2763 - val_mse: 0.0764 - val_mae: 0.2713
# Epoch 36/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1234 - mse: 0.0153 - mae: 0.0969 - val_loss: 0.2703 - val_mse: 0.0731 - val_mae: 0.2652
# Epoch 37/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1232 - mse: 0.0152 - mae: 0.0958 - val_loss: 0.2668 - val_mse: 0.0712 - val_mae: 0.2617
# Epoch 38/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1228 - mse: 0.0151 - mae: 0.0951 - val_loss: 0.2656 - val_mse: 0.0705 - val_mae: 0.2605
# Epoch 39/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1218 - mse: 0.0149 - mae: 0.0947 - val_loss: 0.2662 - val_mse: 0.0708 - val_mae: 0.2611
# Epoch 40/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1213 - mse: 0.0147 - mae: 0.0945 - val_loss: 0.2682 - val_mse: 0.0719 - val_mae: 0.2633
# 1/1 [==============================] - 1s 551ms/step
# 4
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7e5bc8a4c0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7e5bc8a4c0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 297ms/step - loss: 0.5055 - mse: 0.2556 - mae: 0.4824 - val_loss: 0.8057 - val_mse: 0.6492 - val_mae: 0.8036
# Epoch 2/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4893 - mse: 0.2396 - mae: 0.4657 - val_loss: 0.7879 - val_mse: 0.6208 - val_mae: 0.7857
# Epoch 3/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4728 - mse: 0.2236 - mae: 0.4486 - val_loss: 0.7693 - val_mse: 0.5918 - val_mae: 0.7670
# Epoch 4/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4553 - mse: 0.2074 - mae: 0.4306 - val_loss: 0.7493 - val_mse: 0.5615 - val_mae: 0.7470
# Epoch 5/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4367 - mse: 0.1907 - mae: 0.4112 - val_loss: 0.7277 - val_mse: 0.5295 - val_mae: 0.7253
# Epoch 6/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4166 - mse: 0.1735 - mae: 0.3906 - val_loss: 0.7039 - val_mse: 0.4955 - val_mae: 0.7014
# Epoch 7/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3946 - mse: 0.1557 - mae: 0.3680 - val_loss: 0.6775 - val_mse: 0.4590 - val_mae: 0.6749
# Epoch 8/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3704 - mse: 0.1374 - mae: 0.3432 - val_loss: 0.6480 - val_mse: 0.4200 - val_mae: 0.6454
# Epoch 9/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3438 - mse: 0.1183 - mae: 0.3164 - val_loss: 0.6151 - val_mse: 0.3784 - val_mae: 0.6123
# Epoch 10/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.3142 - mse: 0.0987 - mae: 0.2870 - val_loss: 0.5784 - val_mse: 0.3345 - val_mae: 0.5754
# Epoch 11/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2826 - mse: 0.0799 - mae: 0.2548 - val_loss: 0.5375 - val_mse: 0.2889 - val_mae: 0.5343
# Epoch 12/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2487 - mse: 0.0619 - mae: 0.2211 - val_loss: 0.4927 - val_mse: 0.2428 - val_mae: 0.4893
# Epoch 13/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2141 - mse: 0.0459 - mae: 0.1885 - val_loss: 0.4447 - val_mse: 0.1977 - val_mae: 0.4408
# Epoch 14/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1805 - mse: 0.0327 - mae: 0.1582 - val_loss: 0.3948 - val_mse: 0.1559 - val_mae: 0.3905
# Epoch 15/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1535 - mse: 0.0236 - mae: 0.1296 - val_loss: 0.3457 - val_mse: 0.1195 - val_mae: 0.3408
# Epoch 16/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1374 - mse: 0.0190 - mae: 0.1116 - val_loss: 0.3020 - val_mse: 0.0912 - val_mae: 0.2964
# Epoch 17/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1369 - mse: 0.0188 - mae: 0.1053 - val_loss: 0.2698 - val_mse: 0.0728 - val_mae: 0.2635
# Epoch 18/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1422 - mse: 0.0202 - mae: 0.1062 - val_loss: 0.2543 - val_mse: 0.0647 - val_mae: 0.2476
# Epoch 19/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1456 - mse: 0.0212 - mae: 0.1082 - val_loss: 0.2536 - val_mse: 0.0643 - val_mae: 0.2470
# Epoch 20/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1439 - mse: 0.0209 - mae: 0.1075 - val_loss: 0.2629 - val_mse: 0.0691 - val_mae: 0.2565
# Epoch 21/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1400 - mse: 0.0197 - mae: 0.1049 - val_loss: 0.2759 - val_mse: 0.0761 - val_mae: 0.2699
# Epoch 22/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1363 - mse: 0.0186 - mae: 0.1031 - val_loss: 0.2929 - val_mse: 0.0858 - val_mae: 0.2872
# Epoch 23/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1340 - mse: 0.0180 - mae: 0.1042 - val_loss: 0.3083 - val_mse: 0.0951 - val_mae: 0.3030
# Epoch 24/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1333 - mse: 0.0178 - mae: 0.1063 - val_loss: 0.3189 - val_mse: 0.1017 - val_mae: 0.3138
# Epoch 25/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1340 - mse: 0.0180 - mae: 0.1084 - val_loss: 0.3241 - val_mse: 0.1051 - val_mae: 0.3192
# Epoch 26/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1342 - mse: 0.0181 - mae: 0.1089 - val_loss: 0.3208 - val_mse: 0.1029 - val_mae: 0.3158
# Epoch 27/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1334 - mse: 0.0178 - mae: 0.1078 - val_loss: 0.3127 - val_mse: 0.0978 - val_mae: 0.3076
# Epoch 28/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1324 - mse: 0.0175 - mae: 0.1061 - val_loss: 0.3045 - val_mse: 0.0927 - val_mae: 0.2993
# Epoch 29/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1314 - mse: 0.0173 - mae: 0.1043 - val_loss: 0.2972 - val_mse: 0.0884 - val_mae: 0.2920
# Epoch 30/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1309 - mse: 0.0172 - mae: 0.1029 - val_loss: 0.2901 - val_mse: 0.0842 - val_mae: 0.2848
# Epoch 31/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1299 - mse: 0.0171 - mae: 0.1017 - val_loss: 0.2847 - val_mse: 0.0810 - val_mae: 0.2793
# Epoch 32/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1302 - mse: 0.0170 - mae: 0.1009 - val_loss: 0.2835 - val_mse: 0.0804 - val_mae: 0.2782
# Epoch 33/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1294 - mse: 0.0169 - mae: 0.1006 - val_loss: 0.2869 - val_mse: 0.0823 - val_mae: 0.2816
# Epoch 34/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1284 - mse: 0.0166 - mae: 0.1008 - val_loss: 0.2892 - val_mse: 0.0836 - val_mae: 0.2840
# Epoch 35/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1282 - mse: 0.0165 - mae: 0.1009 - val_loss: 0.2913 - val_mse: 0.0848 - val_mae: 0.2862
# Epoch 36/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1275 - mse: 0.0163 - mae: 0.1011 - val_loss: 0.2902 - val_mse: 0.0842 - val_mae: 0.2852
# Epoch 37/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1268 - mse: 0.0162 - mae: 0.1004 - val_loss: 0.2839 - val_mse: 0.0806 - val_mae: 0.2788
# Epoch 38/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1262 - mse: 0.0160 - mae: 0.0991 - val_loss: 0.2790 - val_mse: 0.0778 - val_mae: 0.2739
# Epoch 39/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1260 - mse: 0.0159 - mae: 0.0983 - val_loss: 0.2781 - val_mse: 0.0774 - val_mae: 0.2730
# Epoch 40/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1248 - mse: 0.0157 - mae: 0.0979 - val_loss: 0.2788 - val_mse: 0.0777 - val_mae: 0.2738
# 1/1 [==============================] - 1s 530ms/step
# 5
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7f3d585430> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7f3d585430>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 313ms/step - loss: 0.5068 - mse: 0.2569 - mae: 0.4837 - val_loss: 0.8053 - val_mse: 0.6486 - val_mae: 0.8033
# Epoch 2/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4880 - mse: 0.2383 - mae: 0.4645 - val_loss: 0.7839 - val_mse: 0.6145 - val_mae: 0.7818
# Epoch 3/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4691 - mse: 0.2201 - mae: 0.4450 - val_loss: 0.7615 - val_mse: 0.5799 - val_mae: 0.7593
# Epoch 4/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4489 - mse: 0.2015 - mae: 0.4243 - val_loss: 0.7377 - val_mse: 0.5442 - val_mae: 0.7355
# Epoch 5/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4276 - mse: 0.1829 - mae: 0.4024 - val_loss: 0.7120 - val_mse: 0.5069 - val_mae: 0.7097
# Epoch 6/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4045 - mse: 0.1638 - mae: 0.3788 - val_loss: 0.6840 - val_mse: 0.4678 - val_mae: 0.6816
# Epoch 7/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3796 - mse: 0.1445 - mae: 0.3535 - val_loss: 0.6532 - val_mse: 0.4267 - val_mae: 0.6508
# Epoch 8/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.3527 - mse: 0.1245 - mae: 0.3257 - val_loss: 0.6192 - val_mse: 0.3834 - val_mae: 0.6167
# Epoch 9/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3232 - mse: 0.1045 - mae: 0.2965 - val_loss: 0.5817 - val_mse: 0.3384 - val_mae: 0.5790
# Epoch 10/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2912 - mse: 0.0848 - mae: 0.2644 - val_loss: 0.5404 - val_mse: 0.2920 - val_mae: 0.5375
# Epoch 11/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2568 - mse: 0.0659 - mae: 0.2296 - val_loss: 0.4952 - val_mse: 0.2452 - val_mae: 0.4921
# Epoch 12/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2214 - mse: 0.0492 - mae: 0.1953 - val_loss: 0.4465 - val_mse: 0.1994 - val_mae: 0.4431
# Epoch 13/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1863 - mse: 0.0348 - mae: 0.1635 - val_loss: 0.3953 - val_mse: 0.1562 - val_mae: 0.3915
# Epoch 14/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1553 - mse: 0.0242 - mae: 0.1333 - val_loss: 0.3438 - val_mse: 0.1182 - val_mae: 0.3394
# Epoch 15/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1352 - mse: 0.0183 - mae: 0.1117 - val_loss: 0.2967 - val_mse: 0.0880 - val_mae: 0.2917
# Epoch 16/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1308 - mse: 0.0171 - mae: 0.1025 - val_loss: 0.2601 - val_mse: 0.0677 - val_mae: 0.2544
# Epoch 17/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1352 - mse: 0.0183 - mae: 0.1013 - val_loss: 0.2397 - val_mse: 0.0575 - val_mae: 0.2336
# Epoch 18/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1407 - mse: 0.0198 - mae: 0.1048 - val_loss: 0.2344 - val_mse: 0.0550 - val_mae: 0.2282
# Epoch 19/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1410 - mse: 0.0199 - mae: 0.1050 - val_loss: 0.2417 - val_mse: 0.0584 - val_mae: 0.2357
# Epoch 20/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1371 - mse: 0.0188 - mae: 0.1022 - val_loss: 0.2569 - val_mse: 0.0660 - val_mae: 0.2513
# Epoch 21/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1319 - mse: 0.0174 - mae: 0.0993 - val_loss: 0.2751 - val_mse: 0.0757 - val_mae: 0.2698
# Epoch 22/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1278 - mse: 0.0166 - mae: 0.0997 - val_loss: 0.2925 - val_mse: 0.0855 - val_mae: 0.2876
# Epoch 23/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1271 - mse: 0.0164 - mae: 0.1019 - val_loss: 0.3052 - val_mse: 0.0931 - val_mae: 0.3005
# Epoch 24/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1287 - mse: 0.0166 - mae: 0.1040 - val_loss: 0.3115 - val_mse: 0.0971 - val_mae: 0.3070
# Epoch 25/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1292 - mse: 0.0167 - mae: 0.1051 - val_loss: 0.3106 - val_mse: 0.0965 - val_mae: 0.3061
# Epoch 26/40
# ...
# Epoch 36/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1342 - mse: 0.0180 - mae: 0.1098 - val_loss: 0.2229 - val_mse: 0.0497 - val_mae: 0.2214
# Epoch 37/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1307 - mse: 0.0172 - mae: 0.1068 - val_loss: 0.2205 - val_mse: 0.0486 - val_mae: 0.2190
# Epoch 38/40
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1268 - mse: 0.0163 - mae: 0.1038 - val_loss: 0.2092 - val_mse: 0.0438 - val_mae: 0.2077
# Epoch 39/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1238 - mse: 0.0153 - mae: 0.1012 - val_loss: 0.1983 - val_mse: 0.0393 - val_mae: 0.1967
# Epoch 40/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1200 - mse: 0.0144 - mae: 0.0982 - val_loss: 0.1921 - val_mse: 0.0369 - val_mae: 0.1905
# 1/1 [==============================] - 0s 499ms/step
# 149
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7f2c5bce50> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7f2c5bce50>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4/4 [==============================] - 3s 202ms/step - loss: 0.6271 - mse: 0.3933 - mae: 0.5912 - val_loss: 0.9131 - val_mse: 0.8337 - val_mae: 0.9124
# Epoch 2/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6060 - mse: 0.3677 - mae: 0.5697 - val_loss: 0.8883 - val_mse: 0.7892 - val_mae: 0.8876
# Epoch 3/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5838 - mse: 0.3417 - mae: 0.5470 - val_loss: 0.8614 - val_mse: 0.7420 - val_mae: 0.8607
# Epoch 4/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5605 - mse: 0.3143 - mae: 0.5224 - val_loss: 0.8312 - val_mse: 0.6909 - val_mae: 0.8305
# Epoch 5/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5338 - mse: 0.2851 - mae: 0.4945 - val_loss: 0.7968 - val_mse: 0.6348 - val_mae: 0.7960
# Epoch 6/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5031 - mse: 0.2538 - mae: 0.4632 - val_loss: 0.7570 - val_mse: 0.5731 - val_mae: 0.7562
# Epoch 7/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4685 - mse: 0.2195 - mae: 0.4270 - val_loss: 0.7111 - val_mse: 0.5057 - val_mae: 0.7103
# Epoch 8/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4288 - mse: 0.1840 - mae: 0.3863 - val_loss: 0.6580 - val_mse: 0.4330 - val_mae: 0.6571
# Epoch 9/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3834 - mse: 0.1473 - mae: 0.3402 - val_loss: 0.5972 - val_mse: 0.3566 - val_mae: 0.5962
# Epoch 10/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3332 - mse: 0.1113 - mae: 0.2885 - val_loss: 0.5287 - val_mse: 0.2795 - val_mae: 0.5275
# Epoch 11/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2805 - mse: 0.0790 - mae: 0.2380 - val_loss: 0.4539 - val_mse: 0.2060 - val_mae: 0.4525
# Epoch 12/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2293 - mse: 0.0526 - mae: 0.1884 - val_loss: 0.3769 - val_mse: 0.1420 - val_mae: 0.3751
# Epoch 13/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1908 - mse: 0.0366 - mae: 0.1541 - val_loss: 0.3051 - val_mse: 0.0931 - val_mae: 0.3029
# Epoch 14/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1734 - mse: 0.0301 - mae: 0.1408 - val_loss: 0.2506 - val_mse: 0.0628 - val_mae: 0.2479
# Epoch 15/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1775 - mse: 0.0315 - mae: 0.1474 - val_loss: 0.2197 - val_mse: 0.0482 - val_mae: 0.2166
# Epoch 16/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1826 - mse: 0.0335 - mae: 0.1530 - val_loss: 0.2125 - val_mse: 0.0451 - val_mae: 0.2093
# Epoch 17/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1825 - mse: 0.0334 - mae: 0.1525 - val_loss: 0.2221 - val_mse: 0.0493 - val_mae: 0.2192
# Epoch 18/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1776 - mse: 0.0316 - mae: 0.1482 - val_loss: 0.2396 - val_mse: 0.0574 - val_mae: 0.2369
# Epoch 19/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1726 - mse: 0.0298 - mae: 0.1429 - val_loss: 0.2604 - val_mse: 0.0678 - val_mae: 0.2580
# Epoch 20/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1692 - mse: 0.0286 - mae: 0.1384 - val_loss: 0.2749 - val_mse: 0.0755 - val_mae: 0.2727
# Epoch 21/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1676 - mse: 0.0284 - mae: 0.1373 - val_loss: 0.2844 - val_mse: 0.0809 - val_mae: 0.2824
# Epoch 22/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1679 - mse: 0.0282 - mae: 0.1365 - val_loss: 0.2867 - val_mse: 0.0822 - val_mae: 0.2847
# Epoch 23/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1669 - mse: 0.0279 - mae: 0.1356 - val_loss: 0.2820 - val_mse: 0.0795 - val_mae: 0.2800
# Epoch 24/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1652 - mse: 0.0273 - mae: 0.1343 - val_loss: 0.2750 - val_mse: 0.0756 - val_mae: 0.2730
# Epoch 25/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1633 - mse: 0.0267 - mae: 0.1330 - val_loss: 0.2661 - val_mse: 0.0708 - val_mae: 0.2640
# Epoch 26/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1618 - mse: 0.0262 - mae: 0.1319 - val_loss: 0.2572 - val_mse: 0.0662 - val_mae: 0.2552
# Epoch 27/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1600 - mse: 0.0256 - mae: 0.1308 - val_loss: 0.2510 - val_mse: 0.0630 - val_mae: 0.2490
# Epoch 28/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1586 - mse: 0.0252 - mae: 0.1298 - val_loss: 0.2480 - val_mse: 0.0615 - val_mae: 0.2460
# Epoch 29/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1564 - mse: 0.0247 - mae: 0.1285 - val_loss: 0.2472 - val_mse: 0.0611 - val_mae: 0.2452
# Epoch 30/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1551 - mse: 0.0241 - mae: 0.1269 - val_loss: 0.2450 - val_mse: 0.0600 - val_mae: 0.2430
# Epoch 31/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1532 - mse: 0.0235 - mae: 0.1253 - val_loss: 0.2445 - val_mse: 0.0598 - val_mae: 0.2426
# Epoch 32/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1509 - mse: 0.0229 - mae: 0.1236 - val_loss: 0.2440 - val_mse: 0.0595 - val_mae: 0.2422
# Epoch 33/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1492 - mse: 0.0223 - mae: 0.1217 - val_loss: 0.2468 - val_mse: 0.0609 - val_mae: 0.2451
# Epoch 34/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1473 - mse: 0.0217 - mae: 0.1200 - val_loss: 0.2459 - val_mse: 0.0605 - val_mae: 0.2442
# Epoch 35/40
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1452 - mse: 0.0211 - mae: 0.1183 - val_loss: 0.2405 - val_mse: 0.0578 - val_mae: 0.2388
# Epoch 36/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1427 - mse: 0.0204 - mae: 0.1163 - val_loss: 0.2387 - val_mse: 0.0570 - val_mae: 0.2370
# Epoch 37/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1401 - mse: 0.0197 - mae: 0.1143 - val_loss: 0.2307 - val_mse: 0.0532 - val_mae: 0.2291
# Epoch 38/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1375 - mse: 0.0190 - mae: 0.1124 - val_loss: 0.2211 - val_mse: 0.0489 - val_mae: 0.2195
# Epoch 39/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1349 - mse: 0.0183 - mae: 0.1103 - val_loss: 0.2181 - val_mse: 0.0476 - val_mae: 0.2164
# Epoch 40/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1324 - mse: 0.0176 - mae: 0.1080 - val_loss: 0.2184 - val_mse: 0.0477 - val_mae: 0.2168
# 1/1 [==============================] - 1s 518ms/step
# 150
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7eaf0293a0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7eaf0293a0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4/4 [==============================] - 3s 213ms/step - loss: 0.6209 - mse: 0.3856 - mae: 0.5846 - val_loss: 0.9044 - val_mse: 0.8180 - val_mae: 0.9037
# Epoch 2/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5972 - mse: 0.3571 - mae: 0.5603 - val_loss: 0.8769 - val_mse: 0.7689 - val_mae: 0.8762
# Epoch 3/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5727 - mse: 0.3284 - mae: 0.5346 - val_loss: 0.8469 - val_mse: 0.7173 - val_mae: 0.8461
# Epoch 4/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5459 - mse: 0.2981 - mae: 0.5065 - val_loss: 0.8134 - val_mse: 0.6617 - val_mae: 0.8126
# Epoch 5/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5160 - mse: 0.2665 - mae: 0.4754 - val_loss: 0.7755 - val_mse: 0.6013 - val_mae: 0.7746
# Epoch 6/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4820 - mse: 0.2324 - mae: 0.4401 - val_loss: 0.7319 - val_mse: 0.5357 - val_mae: 0.7310
# Epoch 7/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4439 - mse: 0.1973 - mae: 0.4009 - val_loss: 0.6818 - val_mse: 0.4649 - val_mae: 0.6808
# Epoch 8/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4009 - mse: 0.1611 - mae: 0.3563 - val_loss: 0.6245 - val_mse: 0.3901 - val_mae: 0.6234
# Epoch 9/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3529 - mse: 0.1248 - mae: 0.3069 - val_loss: 0.5601 - val_mse: 0.3138 - val_mae: 0.5588
# Epoch 10/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3023 - mse: 0.0916 - mae: 0.2576 - val_loss: 0.4894 - val_mse: 0.2395 - val_mae: 0.4877
# Epoch 11/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2506 - mse: 0.0631 - mae: 0.2081 - val_loss: 0.4157 - val_mse: 0.1728 - val_mae: 0.4136
# Epoch 12/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2086 - mse: 0.0438 - mae: 0.1682 - val_loss: 0.3444 - val_mse: 0.1186 - val_mae: 0.3418
# Epoch 13/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1856 - mse: 0.0346 - mae: 0.1501 - val_loss: 0.2831 - val_mse: 0.0802 - val_mae: 0.2798
# Epoch 14/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1824 - mse: 0.0333 - mae: 0.1499 - val_loss: 0.2424 - val_mse: 0.0588 - val_mae: 0.2386
# Epoch 15/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1878 - mse: 0.0354 - mae: 0.1569 - val_loss: 0.2249 - val_mse: 0.0506 - val_mae: 0.2208
# Epoch 16/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1897 - mse: 0.0360 - mae: 0.1587 - val_loss: 0.2296 - val_mse: 0.0527 - val_mae: 0.2257
# Epoch 17/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1857 - mse: 0.0345 - mae: 0.1550 - val_loss: 0.2466 - val_mse: 0.0608 - val_mae: 0.2430
# Epoch 18/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1802 - mse: 0.0325 - mae: 0.1494 - val_loss: 0.2704 - val_mse: 0.0731 - val_mae: 0.2672
# Epoch 19/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1765 - mse: 0.0312 - mae: 0.1445 - val_loss: 0.2889 - val_mse: 0.0835 - val_mae: 0.2860
# Epoch 20/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1761 - mse: 0.0310 - mae: 0.1430 - val_loss: 0.2983 - val_mse: 0.0890 - val_mae: 0.2956
# Epoch 21/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1758 - mse: 0.0309 - mae: 0.1425 - val_loss: 0.2973 - val_mse: 0.0884 - val_mae: 0.2946
# Epoch 22/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1744 - mse: 0.0305 - mae: 0.1415 - val_loss: 0.2880 - val_mse: 0.0830 - val_mae: 0.2853
# Epoch 23/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1726 - mse: 0.0298 - mae: 0.1402 - val_loss: 0.2777 - val_mse: 0.0771 - val_mae: 0.2749
# Epoch 24/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1710 - mse: 0.0293 - mae: 0.1393 - val_loss: 0.2687 - val_mse: 0.0722 - val_mae: 0.2659
# Epoch 25/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1697 - mse: 0.0289 - mae: 0.1389 - val_loss: 0.2603 - val_mse: 0.0678 - val_mae: 0.2575
# Epoch 26/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1685 - mse: 0.0284 - mae: 0.1382 - val_loss: 0.2595 - val_mse: 0.0674 - val_mae: 0.2568
# Epoch 27/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1663 - mse: 0.0279 - mae: 0.1367 - val_loss: 0.2620 - val_mse: 0.0687 - val_mae: 0.2594
# Epoch 28/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1650 - mse: 0.0273 - mae: 0.1349 - val_loss: 0.2632 - val_mse: 0.0693 - val_mae: 0.2607
# Epoch 29/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1634 - mse: 0.0268 - mae: 0.1333 - val_loss: 0.2634 - val_mse: 0.0694 - val_mae: 0.2610
# Epoch 30/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1616 - mse: 0.0262 - mae: 0.1317 - val_loss: 0.2638 - val_mse: 0.0696 - val_mae: 0.2614
# Epoch 31/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1600 - mse: 0.0257 - mae: 0.1303 - val_loss: 0.2621 - val_mse: 0.0687 - val_mae: 0.2598
# Epoch 32/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1577 - mse: 0.0250 - mae: 0.1286 - val_loss: 0.2526 - val_mse: 0.0638 - val_mae: 0.2502
# Epoch 33/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1559 - mse: 0.0244 - mae: 0.1273 - val_loss: 0.2456 - val_mse: 0.0603 - val_mae: 0.2432
# Epoch 34/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1535 - mse: 0.0237 - mae: 0.1256 - val_loss: 0.2467 - val_mse: 0.0609 - val_mae: 0.2445
# Epoch 35/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1509 - mse: 0.0230 - mae: 0.1234 - val_loss: 0.2463 - val_mse: 0.0607 - val_mae: 0.2442
# Epoch 36/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1492 - mse: 0.0223 - mae: 0.1215 - val_loss: 0.2426 - val_mse: 0.0588 - val_mae: 0.2405
# Epoch 37/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1465 - mse: 0.0216 - mae: 0.1194 - val_loss: 0.2397 - val_mse: 0.0575 - val_mae: 0.2377
# Epoch 38/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1437 - mse: 0.0208 - mae: 0.1172 - val_loss: 0.2307 - val_mse: 0.0532 - val_mae: 0.2287
# Epoch 39/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1412 - mse: 0.0200 - mae: 0.1152 - val_loss: 0.2219 - val_mse: 0.0492 - val_mae: 0.2199
# Epoch 40/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1386 - mse: 0.0193 - mae: 0.1133 - val_loss: 0.2175 - val_mse: 0.0473 - val_mae: 0.2156
# 1/1 [==============================] - 0s 494ms/step
# 151
# CPU times: user 20min 59s, sys: 54.2 s, total: 21min 53s
# Wall time: 17min 11s
# <ipython-input-1-9be4142ebfd5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
# <ipython-input-1-9be4142ebfd5>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_data.before_close[i+1] = price_data.Close[i]

# %%
lstm_2_pred = scaler_y.inverse_transform(lstm_2_pred.reshape(len(x_t),1))

# %%
import pickle
with open(file='/home/whfhrs3260/deeplearning_result_data/lstm_2_pred_2020_2021.pkl', mode='wb') as f:
    pickle.dump(lstm_2_pred, f)
