# %%
import json
import numpy as np
import pandas as pd

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import regex as re
from nltk.corpus import stopwords

from nltk.sentiment.vader import SentimentIntensityAnalyzer
import datetime

import yfinance as yf
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.layers import Embedding, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import optimizers
from keras import backend as K
import matplotlib.pyplot as plt

import datetime
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error 
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error

from multiprocessing import Pool

# %%
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
# 데이터 생성, 처리
def time_conversion(time):
    time = pd.Timestamp(time)
    return time

def date_cut_day(dataframe_date_timestamp):
    dataframe_date_timestamp = datetime.datetime.strftime(dataframe_date_timestamp, "%Y-%m-%d")
    return dataframe_date_timestamp

def train_test_result(dir, stock, variable, window_size):
    #score data 뽑기
    score = pd.read_csv(dir)
    score.columns = ["Date", "Score"]
    
    #price data 뽑기
    price_data = yf.download([stock],start = '2012-01-01', end = "2022-05-01")
    
    opening = price_data.index.copy()
    opening = pd.DataFrame(opening)
    opening["opening_date"] = 1
    opening.Date = opening.Date.apply(lambda x: date_cut_day(x))
    
    Date = pd.date_range(start='20111230', end='20220430')
    Date = pd.DataFrame({"Date" : Date.values})
    Date.Date = Date.Date.apply(lambda x: date_cut_day(x))

    
    set_news_data_date = pd.merge(Date, opening, how ="left",left_on='Date', right_on = "Date") 
    set_news_data_date = set_news_data_date.where(pd.notnull(set_news_data_date), 0) 
    set_news_data_date.Date = set_news_data_date.Date.apply(lambda x: pd.to_datetime(x, errors="ignore"))

    standard=set_news_data_date.Date.iloc[len(set_news_data_date)-1] + datetime.timedelta(days=1)
    set_news_data_date["price_date"]=0
    for i in range(len(set_news_data_date)-1,-1,-1):
        if i==(len(set_news_data_date)-1):
            standard = set_news_data_date.Date[i]
            set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
        elif (set_news_data_date.opening_date[i]==1)&(set_news_data_date.opening_date[i+1]==1):
            standard = set_news_data_date.Date[i]
            set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
        elif (i!=0):
            if((set_news_data_date.opening_date[i]==1)&(set_news_data_date.opening_date[i+1]==0)&(set_news_data_date.opening_date[i-1]==0)):
                set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
                standard = set_news_data_date.Date[i]
            else:
                set_news_data_date.price_date[i]=standard
        else:
            set_news_data_date.price_date[i]=standard
    
    set_news_data_date.Date = set_news_data_date.Date.apply(lambda x: date_cut_day(x))
    
    score = pd.merge(set_news_data_date,score, how ="left",on = "Date")
    
    score = score[['Date','Score', "price_date"]]
    score = score.groupby('price_date').mean({"Score"})
    score = score[score.index<="2022-04-29"]

    first_data = yf.download([stock],start = '2011-12-30', end = '2012-01-01')
    
    price_data = price_data.reset_index()
    score = score.reset_index()
    score.columns = ["Date", "Score"]
    
    price_data = price_data[(price_data["Date"]<"2016-01-01")&("2014-01-01"<=price_data["Date"])]
    
    #price data와 score data 결합
    price_data = pd.merge(price_data, score, how ="left",left_on='Date', right_on = "Date")[["Close","Open","Score"]]

    #뉴스가 없는 날은 즉, score가 없는 날은 중립의 의미로 0으로 처리
    price_data.Score[price_data.Score.isnull()]=0

    #전날 종가의 영향을 받으므로 전날 종가 변수를 생성
    price_data["before_close"] = 0
    price_data = price_data.reset_index(drop=True)
    for i in range(len(price_data)-1):
        price_data.before_close[i+1] = price_data.Close[i]
    
    price_data.before_close[0] = first_data["Close"][0]

    # minmaxscaler 사용
    price_data.columns = ["Close","Open","Score","before_close"]
    
    x = price_data[variable]
    y = price_data[["Close"]]
    scaler_x = MinMaxScaler()
    scaler_y = MinMaxScaler()

    x = pd.DataFrame(scaler_x.fit_transform(x))
    y = pd.DataFrame(scaler_y.fit_transform(y))
    
    x.columns = variable
    y.columns = ["Close"]

    train_index = int(len(x)*0.7)

    train_x = x.iloc[0:train_index]
    test_x = x.iloc[train_index:len(x)]

    train_y = y.iloc[0:train_index]
    test_y = y.iloc[train_index:len(y)]

    train_x = train_x.to_numpy().reshape(train_x.shape[0],1,train_x.shape[1])
    train_y = train_y.to_numpy().reshape(train_y.shape[0],train_y.shape[1])
    test_x = test_x.to_numpy().reshape(test_x.shape[0],1,test_x.shape[1])
    test_y = test_y.to_numpy().reshape(test_y.shape[0],test_y.shape[1])
    
    #window size에 맞게 데이터 설정
    x = np.zeros(shape=(train_x.shape[0]-window_size+1,window_size,x.shape[1]))
    for i in range(train_x.shape[0]-window_size+1):
        x[i]=np.vstack((train_x[i:i+window_size]))

    y = train_y[window_size-1:train_x.shape[0]]

    x_t = np.zeros(shape=(test_x.shape[0]-window_size+1,window_size,x.shape[2]))
    for i in range(test_x.shape[0]-window_size+1):
        x_t[i]=np.vstack((test_x[i:i+window_size]))
    
    y_t = test_y[window_size-1:test_x.shape[0]]
    
    return scaler_x, scaler_y, x, y, x_t, y_t

# %%
# %%time
dir = "/home/whfhrs3260/csv_data/price_data_score_10years.csv"
stock = "^DJI"
variable = ["before_close","Score"]
window_size = 1

scaler_x, scaler_y, x, y, x_t, y_t = train_test_result(dir, stock, variable, window_size)


lstm_2_pred = []
model_input = 0
len_x = x.shape[0]
len_y = y.shape[0]


for i in range(len(x_t)):
    lstm_2_model = Sequential()
    lstm_2_model.add(LSTM(50, input_shape = (x.shape[1],x.shape[2]),return_sequences=True))
    lstm_2_model.add((LSTM(50)))
    lstm_2_model.add(Dense(1,activation="tanh"))
    def root_mean_squared_error(y_true, y_pred):
            return K.sqrt(K.mean(K.square(y_pred - y_true))) 
    lstm_2_model.compile(optimizer="adam", loss = root_mean_squared_error, metrics=['mse',"mae"])
    lstm_2_model.fit(x, y, epochs=40, batch_size=128, validation_split=0.2)
    
    model_input = x_t[i].reshape(1, window_size, len(variable))
    lstm_2_pred = np.append(lstm_2_pred,lstm_2_model.predict(model_input)[0])

    x = np.append(x,x_t[i])
    y = np.append(y,y_t[i])
    len_x += 1
    len_y += 1
    x = x.reshape(len_x,window_size,len(variable))
    y = y.reshape(len_y,1)
    print(i)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f8300e16dc0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f8300e16dc0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 290ms/step - loss: 0.5391 - mse: 0.2907 - mae: 0.5015 - val_loss: 0.8793 - val_mse: 0.7732 - val_mae: 0.8775
# Epoch 2/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5206 - mse: 0.2715 - mae: 0.4820 - val_loss: 0.8588 - val_mse: 0.7375 - val_mae: 0.8569
# Epoch 3/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.5014 - mse: 0.2522 - mae: 0.4620 - val_loss: 0.8372 - val_mse: 0.7010 - val_mae: 0.8353
# Epoch 4/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4822 - mse: 0.2326 - mae: 0.4411 - val_loss: 0.8142 - val_mse: 0.6630 - val_mae: 0.8123
# Epoch 5/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4608 - mse: 0.2130 - mae: 0.4186 - val_loss: 0.7894 - val_mse: 0.6232 - val_mae: 0.7874
# Epoch 6/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4380 - mse: 0.1927 - mae: 0.3945 - val_loss: 0.7624 - val_mse: 0.5812 - val_mae: 0.7603
# Epoch 7/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4141 - mse: 0.1721 - mae: 0.3683 - val_loss: 0.7326 - val_mse: 0.5368 - val_mae: 0.7305
# Epoch 8/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3884 - mse: 0.1511 - mae: 0.3403 - val_loss: 0.6999 - val_mse: 0.4898 - val_mae: 0.6977
# Epoch 9/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3604 - mse: 0.1299 - mae: 0.3099 - val_loss: 0.6638 - val_mse: 0.4407 - val_mae: 0.6615
# Epoch 10/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3296 - mse: 0.1089 - mae: 0.2773 - val_loss: 0.6243 - val_mse: 0.3898 - val_mae: 0.6219
# Epoch 11/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2990 - mse: 0.0894 - mae: 0.2435 - val_loss: 0.5813 - val_mse: 0.3379 - val_mae: 0.5786
# Epoch 12/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2665 - mse: 0.0712 - mae: 0.2101 - val_loss: 0.5351 - val_mse: 0.2863 - val_mae: 0.5322
# Epoch 13/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2376 - mse: 0.0566 - mae: 0.1834 - val_loss: 0.4867 - val_mse: 0.2369 - val_mae: 0.4836
# Epoch 14/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2130 - mse: 0.0455 - mae: 0.1670 - val_loss: 0.4385 - val_mse: 0.1923 - val_mae: 0.4350
# Epoch 15/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1968 - mse: 0.0389 - mae: 0.1599 - val_loss: 0.3941 - val_mse: 0.1553 - val_mae: 0.3902
# Epoch 16/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1906 - mse: 0.0364 - mae: 0.1576 - val_loss: 0.3579 - val_mse: 0.1281 - val_mae: 0.3536
# Epoch 17/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1919 - mse: 0.0369 - mae: 0.1598 - val_loss: 0.3336 - val_mse: 0.1113 - val_mae: 0.3290
# Epoch 18/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1972 - mse: 0.0389 - mae: 0.1655 - val_loss: 0.3220 - val_mse: 0.1037 - val_mae: 0.3173
# Epoch 19/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1984 - mse: 0.0394 - mae: 0.1670 - val_loss: 0.3234 - val_mse: 0.1046 - val_mae: 0.3187
# Epoch 20/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1970 - mse: 0.0389 - mae: 0.1655 - val_loss: 0.3317 - val_mse: 0.1101 - val_mae: 0.3272
# Epoch 21/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1939 - mse: 0.0376 - mae: 0.1623 - val_loss: 0.3445 - val_mse: 0.1187 - val_mae: 0.3402
# Epoch 22/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1907 - mse: 0.0364 - mae: 0.1587 - val_loss: 0.3596 - val_mse: 0.1293 - val_mae: 0.3554
# Epoch 23/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1886 - mse: 0.0356 - mae: 0.1563 - val_loss: 0.3716 - val_mse: 0.1381 - val_mae: 0.3676
# Epoch 24/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1872 - mse: 0.0352 - mae: 0.1549 - val_loss: 0.3797 - val_mse: 0.1442 - val_mae: 0.3758
# Epoch 25/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1869 - mse: 0.0350 - mae: 0.1543 - val_loss: 0.3862 - val_mse: 0.1492 - val_mae: 0.3824
# Epoch 26/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1870 - mse: 0.0351 - mae: 0.1540 - val_loss: 0.3908 - val_mse: 0.1527 - val_mae: 0.3871
# Epoch 27/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1867 - mse: 0.0350 - mae: 0.1536 - val_loss: 0.3903 - val_mse: 0.1523 - val_mae: 0.3865
# Epoch 28/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1861 - mse: 0.0348 - mae: 0.1532 - val_loss: 0.3872 - val_mse: 0.1499 - val_mae: 0.3834
# Epoch 29/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1857 - mse: 0.0346 - mae: 0.1527 - val_loss: 0.3824 - val_mse: 0.1462 - val_mae: 0.3786
# Epoch 30/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1851 - mse: 0.0343 - mae: 0.1523 - val_loss: 0.3780 - val_mse: 0.1428 - val_mae: 0.3741
# Epoch 31/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1842 - mse: 0.0340 - mae: 0.1518 - val_loss: 0.3765 - val_mse: 0.1418 - val_mae: 0.3727
# Epoch 32/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1836 - mse: 0.0337 - mae: 0.1513 - val_loss: 0.3743 - val_mse: 0.1401 - val_mae: 0.3705
# Epoch 33/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1827 - mse: 0.0335 - mae: 0.1507 - val_loss: 0.3707 - val_mse: 0.1374 - val_mae: 0.3668
# Epoch 34/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1820 - mse: 0.0332 - mae: 0.1503 - val_loss: 0.3641 - val_mse: 0.1326 - val_mae: 0.3602
# Epoch 35/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1812 - mse: 0.0329 - mae: 0.1498 - val_loss: 0.3597 - val_mse: 0.1294 - val_mae: 0.3557
# Epoch 36/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1803 - mse: 0.0327 - mae: 0.1493 - val_loss: 0.3585 - val_mse: 0.1285 - val_mae: 0.3546
# Epoch 37/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1796 - mse: 0.0324 - mae: 0.1486 - val_loss: 0.3573 - val_mse: 0.1277 - val_mae: 0.3534
# Epoch 38/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1791 - mse: 0.0321 - mae: 0.1479 - val_loss: 0.3552 - val_mse: 0.1262 - val_mae: 0.3513
# Epoch 39/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1783 - mse: 0.0318 - mae: 0.1472 - val_loss: 0.3508 - val_mse: 0.1231 - val_mae: 0.3469
# Epoch 40/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1769 - mse: 0.0315 - mae: 0.1465 - val_loss: 0.3443 - val_mse: 0.1185 - val_mae: 0.3403
# 1/1 [==============================] - 1s 524ms/step
# 0
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7fc60855e0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7fc60855e0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 12s 505ms/step - loss: 0.5410 - mse: 0.2927 - mae: 0.5026 - val_loss: 0.8827 - val_mse: 0.7792 - val_mae: 0.8809
# Epoch 2/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.5228 - mse: 0.2737 - mae: 0.4834 - val_loss: 0.8629 - val_mse: 0.7446 - val_mae: 0.8610
# Epoch 3/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5046 - mse: 0.2547 - mae: 0.4639 - val_loss: 0.8422 - val_mse: 0.7093 - val_mae: 0.8402
# Epoch 4/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4852 - mse: 0.2356 - mae: 0.4433 - val_loss: 0.8202 - val_mse: 0.6728 - val_mae: 0.8183
# Epoch 5/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4651 - mse: 0.2164 - mae: 0.4215 - val_loss: 0.7967 - val_mse: 0.6347 - val_mae: 0.7947
# Epoch 6/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4429 - mse: 0.1968 - mae: 0.3982 - val_loss: 0.7711 - val_mse: 0.5946 - val_mae: 0.7690
# Epoch 7/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4202 - mse: 0.1767 - mae: 0.3730 - val_loss: 0.7431 - val_mse: 0.5522 - val_mae: 0.7409
# Epoch 8/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3947 - mse: 0.1563 - mae: 0.3456 - val_loss: 0.7123 - val_mse: 0.5074 - val_mae: 0.7100
# Epoch 9/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3673 - mse: 0.1356 - mae: 0.3166 - val_loss: 0.6782 - val_mse: 0.4600 - val_mae: 0.6759
# Epoch 10/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3389 - mse: 0.1150 - mae: 0.2847 - val_loss: 0.6407 - val_mse: 0.4105 - val_mae: 0.6382
# Epoch 11/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3089 - mse: 0.0956 - mae: 0.2516 - val_loss: 0.5995 - val_mse: 0.3594 - val_mae: 0.5969
# Epoch 12/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2778 - mse: 0.0774 - mae: 0.2193 - val_loss: 0.5550 - val_mse: 0.3080 - val_mae: 0.5521
# Epoch 13/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2488 - mse: 0.0621 - mae: 0.1914 - val_loss: 0.5082 - val_mse: 0.2583 - val_mae: 0.5050
# Epoch 14/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2238 - mse: 0.0501 - mae: 0.1745 - val_loss: 0.4615 - val_mse: 0.2130 - val_mae: 0.4580
# Epoch 15/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2066 - mse: 0.0428 - mae: 0.1657 - val_loss: 0.4189 - val_mse: 0.1755 - val_mae: 0.4150
# Epoch 16/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1980 - mse: 0.0394 - mae: 0.1632 - val_loss: 0.3854 - val_mse: 0.1486 - val_mae: 0.3812
# Epoch 17/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1969 - mse: 0.0390 - mae: 0.1639 - val_loss: 0.3634 - val_mse: 0.1320 - val_mae: 0.3589
# Epoch 18/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1995 - mse: 0.0398 - mae: 0.1669 - val_loss: 0.3512 - val_mse: 0.1234 - val_mae: 0.3466
# Epoch 19/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2004 - mse: 0.0403 - mae: 0.1684 - val_loss: 0.3483 - val_mse: 0.1213 - val_mae: 0.3436
# Epoch 20/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1994 - mse: 0.0401 - mae: 0.1680 - val_loss: 0.3510 - val_mse: 0.1232 - val_mae: 0.3464
# Epoch 21/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1984 - mse: 0.0395 - mae: 0.1664 - val_loss: 0.3574 - val_mse: 0.1278 - val_mae: 0.3530
# Epoch 22/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1965 - mse: 0.0387 - mae: 0.1642 - val_loss: 0.3665 - val_mse: 0.1343 - val_mae: 0.3622
# Epoch 23/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1949 - mse: 0.0381 - mae: 0.1621 - val_loss: 0.3757 - val_mse: 0.1411 - val_mae: 0.3715
# Epoch 24/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1937 - mse: 0.0375 - mae: 0.1606 - val_loss: 0.3828 - val_mse: 0.1466 - val_mae: 0.3788
# Epoch 25/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1924 - mse: 0.0372 - mae: 0.1595 - val_loss: 0.3880 - val_mse: 0.1506 - val_mae: 0.3840
# Epoch 26/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1925 - mse: 0.0371 - mae: 0.1588 - val_loss: 0.3920 - val_mse: 0.1537 - val_mae: 0.3881
# Epoch 27/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1918 - mse: 0.0368 - mae: 0.1581 - val_loss: 0.3919 - val_mse: 0.1536 - val_mae: 0.3880
# Epoch 28/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1913 - mse: 0.0366 - mae: 0.1575 - val_loss: 0.3883 - val_mse: 0.1508 - val_mae: 0.3844
# Epoch 29/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1901 - mse: 0.0363 - mae: 0.1571 - val_loss: 0.3816 - val_mse: 0.1456 - val_mae: 0.3776
# Epoch 30/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1894 - mse: 0.0360 - mae: 0.1565 - val_loss: 0.3755 - val_mse: 0.1410 - val_mae: 0.3715
# Epoch 31/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1890 - mse: 0.0358 - mae: 0.1563 - val_loss: 0.3702 - val_mse: 0.1371 - val_mae: 0.3662
# Epoch 32/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1882 - mse: 0.0355 - mae: 0.1558 - val_loss: 0.3680 - val_mse: 0.1354 - val_mae: 0.3639
# Epoch 33/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1876 - mse: 0.0352 - mae: 0.1551 - val_loss: 0.3683 - val_mse: 0.1357 - val_mae: 0.3643
# Epoch 34/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1861 - mse: 0.0349 - mae: 0.1543 - val_loss: 0.3683 - val_mse: 0.1356 - val_mae: 0.3643
# Epoch 35/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1860 - mse: 0.0346 - mae: 0.1536 - val_loss: 0.3682 - val_mse: 0.1356 - val_mae: 0.3643
# Epoch 36/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1852 - mse: 0.0343 - mae: 0.1529 - val_loss: 0.3667 - val_mse: 0.1345 - val_mae: 0.3628
# Epoch 37/40
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1839 - mse: 0.0340 - mae: 0.1522 - val_loss: 0.3670 - val_mse: 0.1347 - val_mae: 0.3631
# Epoch 38/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1835 - mse: 0.0337 - mae: 0.1514 - val_loss: 0.3627 - val_mse: 0.1316 - val_mae: 0.3588
# Epoch 39/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1822 - mse: 0.0333 - mae: 0.1507 - val_loss: 0.3562 - val_mse: 0.1269 - val_mae: 0.3522
# Epoch 40/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1814 - mse: 0.0330 - mae: 0.1500 - val_loss: 0.3490 - val_mse: 0.1218 - val_mae: 0.3450
# 1/1 [==============================] - 1s 766ms/step
# 1
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f81724891f0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f81724891f0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 4s 400ms/step - loss: 0.5571 - mse: 0.3106 - mae: 0.5201 - val_loss: 0.8934 - val_mse: 0.7982 - val_mae: 0.8916
# Epoch 2/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5379 - mse: 0.2894 - mae: 0.4996 - val_loss: 0.8724 - val_mse: 0.7610 - val_mae: 0.8705
# Epoch 3/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5187 - mse: 0.2691 - mae: 0.4794 - val_loss: 0.8511 - val_mse: 0.7243 - val_mae: 0.8492
# Epoch 4/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4997 - mse: 0.2497 - mae: 0.4593 - val_loss: 0.8291 - val_mse: 0.6874 - val_mae: 0.8271
# Epoch 5/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4795 - mse: 0.2305 - mae: 0.4382 - val_loss: 0.8059 - val_mse: 0.6495 - val_mae: 0.8039
# Epoch 6/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4591 - mse: 0.2108 - mae: 0.4160 - val_loss: 0.7809 - val_mse: 0.6098 - val_mae: 0.7789
# Epoch 7/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4367 - mse: 0.1911 - mae: 0.3921 - val_loss: 0.7536 - val_mse: 0.5680 - val_mae: 0.7515
# Epoch 8/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4129 - mse: 0.1706 - mae: 0.3663 - val_loss: 0.7236 - val_mse: 0.5236 - val_mae: 0.7214
# Epoch 9/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3863 - mse: 0.1495 - mae: 0.3384 - val_loss: 0.6904 - val_mse: 0.4767 - val_mae: 0.6882
# Epoch 10/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3585 - mse: 0.1286 - mae: 0.3081 - val_loss: 0.6537 - val_mse: 0.4273 - val_mae: 0.6514
# Epoch 11/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.3280 - mse: 0.1077 - mae: 0.2757 - val_loss: 0.6132 - val_mse: 0.3761 - val_mae: 0.6108
# Epoch 12/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2963 - mse: 0.0879 - mae: 0.2413 - val_loss: 0.5691 - val_mse: 0.3239 - val_mae: 0.5664
# Epoch 13/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.2633 - mse: 0.0695 - mae: 0.2078 - val_loss: 0.5217 - val_mse: 0.2722 - val_mae: 0.5188
# Epoch 14/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2334 - mse: 0.0547 - mae: 0.1808 - val_loss: 0.4717 - val_mse: 0.2225 - val_mae: 0.4686
# Epoch 15/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2086 - mse: 0.0437 - mae: 0.1647 - val_loss: 0.4225 - val_mse: 0.1785 - val_mae: 0.4190
# Epoch 16/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1931 - mse: 0.0373 - mae: 0.1563 - val_loss: 0.3784 - val_mse: 0.1432 - val_mae: 0.3745
# Epoch 17/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1874 - mse: 0.0352 - mae: 0.1543 - val_loss: 0.3433 - val_mse: 0.1178 - val_mae: 0.3390
# Epoch 18/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1907 - mse: 0.0364 - mae: 0.1591 - val_loss: 0.3203 - val_mse: 0.1026 - val_mae: 0.3158
# Epoch 19/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1935 - mse: 0.0376 - mae: 0.1624 - val_loss: 0.3125 - val_mse: 0.0976 - val_mae: 0.3078
# Epoch 20/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1943 - mse: 0.0379 - mae: 0.1632 - val_loss: 0.3159 - val_mse: 0.0998 - val_mae: 0.3113
# Epoch 21/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1923 - mse: 0.0372 - mae: 0.1613 - val_loss: 0.3259 - val_mse: 0.1062 - val_mae: 0.3214
# Epoch 22/40
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1891 - mse: 0.0359 - mae: 0.1581 - val_loss: 0.3378 - val_mse: 0.1141 - val_mae: 0.3335
# Epoch 23/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1865 - mse: 0.0350 - mae: 0.1551 - val_loss: 0.3510 - val_mse: 0.1232 - val_mae: 0.3469
# Epoch 24/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1856 - mse: 0.0345 - mae: 0.1535 - val_loss: 0.3624 - val_mse: 0.1313 - val_mae: 0.3584
# Epoch 25/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1841 - mse: 0.0341 - mae: 0.1524 - val_loss: 0.3683 - val_mse: 0.1356 - val_mae: 0.3644
# Epoch 26/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1843 - mse: 0.0340 - mae: 0.1519 - val_loss: 0.3711 - val_mse: 0.1377 - val_mae: 0.3672
# Epoch 27/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1838 - mse: 0.0338 - mae: 0.1514 - val_loss: 0.3721 - val_mse: 0.1385 - val_mae: 0.3683
# Epoch 28/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1832 - mse: 0.0336 - mae: 0.1509 - val_loss: 0.3692 - val_mse: 0.1363 - val_mae: 0.3654
# Epoch 29/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1823 - mse: 0.0333 - mae: 0.1503 - val_loss: 0.3641 - val_mse: 0.1326 - val_mae: 0.3602
# Epoch 30/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1816 - mse: 0.0330 - mae: 0.1498 - val_loss: 0.3568 - val_mse: 0.1273 - val_mae: 0.3528
# Epoch 31/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1807 - mse: 0.0327 - mae: 0.1492 - val_loss: 0.3475 - val_mse: 0.1208 - val_mae: 0.3435
# Epoch 32/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1805 - mse: 0.0326 - mae: 0.1490 - val_loss: 0.3399 - val_mse: 0.1155 - val_mae: 0.3358
# Epoch 33/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1788 - mse: 0.0323 - mae: 0.1487 - val_loss: 0.3393 - val_mse: 0.1152 - val_mae: 0.3353
# Epoch 34/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1787 - mse: 0.0321 - mae: 0.1480 - val_loss: 0.3391 - val_mse: 0.1150 - val_mae: 0.3350
# Epoch 35/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1779 - mse: 0.0318 - mae: 0.1472 - val_loss: 0.3374 - val_mse: 0.1138 - val_mae: 0.3333
# Epoch 36/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1769 - mse: 0.0315 - mae: 0.1465 - val_loss: 0.3384 - val_mse: 0.1145 - val_mae: 0.3344
# Epoch 37/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1763 - mse: 0.0312 - mae: 0.1457 - val_loss: 0.3397 - val_mse: 0.1154 - val_mae: 0.3357
# Epoch 38/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1752 - mse: 0.0308 - mae: 0.1448 - val_loss: 0.3382 - val_mse: 0.1144 - val_mae: 0.3342
# Epoch 39/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1744 - mse: 0.0305 - mae: 0.1440 - val_loss: 0.3382 - val_mse: 0.1144 - val_mae: 0.3342
# Epoch 40/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1736 - mse: 0.0301 - mae: 0.1432 - val_loss: 0.3370 - val_mse: 0.1135 - val_mae: 0.3330
# 1/1 [==============================] - 1s 640ms/step
# 2
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f83983cc790> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f83983cc790>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 4s 352ms/step - loss: 0.5450 - mse: 0.2974 - mae: 0.5067 - val_loss: 0.8815 - val_mse: 0.7771 - val_mae: 0.8797
# Epoch 2/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.5269 - mse: 0.2777 - mae: 0.4871 - val_loss: 0.8611 - val_mse: 0.7415 - val_mae: 0.8592
# Epoch 3/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5078 - mse: 0.2580 - mae: 0.4671 - val_loss: 0.8396 - val_mse: 0.7050 - val_mae: 0.8377
# Epoch 4/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4879 - mse: 0.2383 - mae: 0.4462 - val_loss: 0.8166 - val_mse: 0.6669 - val_mae: 0.8147
# Epoch 5/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4672 - mse: 0.2185 - mae: 0.4235 - val_loss: 0.7916 - val_mse: 0.6267 - val_mae: 0.7896
# Epoch 6/40
# 3/3 [==============================] - 0s 30ms/step - loss: 0.4446 - mse: 0.1977 - mae: 0.3991 - val_loss: 0.7641 - val_mse: 0.5839 - val_mae: 0.7621
# Epoch 7/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4198 - mse: 0.1763 - mae: 0.3724 - val_loss: 0.7337 - val_mse: 0.5384 - val_mae: 0.7316
# Epoch 8/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3930 - mse: 0.1547 - mae: 0.3432 - val_loss: 0.7000 - val_mse: 0.4900 - val_mae: 0.6978
# Epoch 9/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3640 - mse: 0.1326 - mae: 0.3118 - val_loss: 0.6626 - val_mse: 0.4391 - val_mae: 0.6602
# Epoch 10/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3324 - mse: 0.1112 - mae: 0.2784 - val_loss: 0.6215 - val_mse: 0.3862 - val_mae: 0.6190
# Epoch 11/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.3003 - mse: 0.0903 - mae: 0.2431 - val_loss: 0.5768 - val_mse: 0.3327 - val_mae: 0.5741
# Epoch 12/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2679 - mse: 0.0718 - mae: 0.2097 - val_loss: 0.5286 - val_mse: 0.2794 - val_mae: 0.5257
# Epoch 13/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2375 - mse: 0.0565 - mae: 0.1832 - val_loss: 0.4780 - val_mse: 0.2285 - val_mae: 0.4747
# Epoch 14/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2127 - mse: 0.0454 - mae: 0.1681 - val_loss: 0.4276 - val_mse: 0.1828 - val_mae: 0.4240
# Epoch 15/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1962 - mse: 0.0387 - mae: 0.1599 - val_loss: 0.3819 - val_mse: 0.1458 - val_mae: 0.3778
# Epoch 16/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1961 - mse: 0.0385 - mae: 0.1627 - val_loss: 0.3445 - val_mse: 0.1187 - val_mae: 0.3400
# Epoch 17/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1995 - mse: 0.0399 - mae: 0.1676 - val_loss: 0.3237 - val_mse: 0.1048 - val_mae: 0.3189
# Epoch 18/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2031 - mse: 0.0414 - mae: 0.1717 - val_loss: 0.3190 - val_mse: 0.1018 - val_mae: 0.3142
# Epoch 19/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2034 - mse: 0.0414 - mae: 0.1717 - val_loss: 0.3261 - val_mse: 0.1063 - val_mae: 0.3213
# Epoch 20/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2001 - mse: 0.0402 - mae: 0.1685 - val_loss: 0.3384 - val_mse: 0.1145 - val_mae: 0.3338
# Epoch 21/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1969 - mse: 0.0388 - mae: 0.1649 - val_loss: 0.3554 - val_mse: 0.1263 - val_mae: 0.3511
# Epoch 22/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1940 - mse: 0.0377 - mae: 0.1615 - val_loss: 0.3713 - val_mse: 0.1379 - val_mae: 0.3672
# Epoch 23/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1928 - mse: 0.0372 - mae: 0.1594 - val_loss: 0.3829 - val_mse: 0.1466 - val_mae: 0.3790
# Epoch 24/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1925 - mse: 0.0372 - mae: 0.1589 - val_loss: 0.3905 - val_mse: 0.1525 - val_mae: 0.3867
# Epoch 25/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1917 - mse: 0.0371 - mae: 0.1583 - val_loss: 0.3918 - val_mse: 0.1535 - val_mae: 0.3880
# Epoch 26/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1923 - mse: 0.0370 - mae: 0.1580 - val_loss: 0.3912 - val_mse: 0.1530 - val_mae: 0.3873
# Epoch 27/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1919 - mse: 0.0369 - mae: 0.1577 - val_loss: 0.3897 - val_mse: 0.1519 - val_mae: 0.3859
# Epoch 28/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1913 - mse: 0.0367 - mae: 0.1573 - val_loss: 0.3844 - val_mse: 0.1478 - val_mae: 0.3806
# Epoch 29/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1906 - mse: 0.0364 - mae: 0.1568 - val_loss: 0.3784 - val_mse: 0.1432 - val_mae: 0.3745
# Epoch 30/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1899 - mse: 0.0361 - mae: 0.1566 - val_loss: 0.3730 - val_mse: 0.1391 - val_mae: 0.3690
# Epoch 31/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1890 - mse: 0.0358 - mae: 0.1561 - val_loss: 0.3689 - val_mse: 0.1361 - val_mae: 0.3650
# Epoch 32/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1883 - mse: 0.0356 - mae: 0.1558 - val_loss: 0.3627 - val_mse: 0.1315 - val_mae: 0.3586
# Epoch 33/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1879 - mse: 0.0354 - mae: 0.1555 - val_loss: 0.3578 - val_mse: 0.1281 - val_mae: 0.3538
# Epoch 34/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1876 - mse: 0.0353 - mae: 0.1553 - val_loss: 0.3553 - val_mse: 0.1262 - val_mae: 0.3512
# Epoch 35/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1871 - mse: 0.0351 - mae: 0.1548 - val_loss: 0.3544 - val_mse: 0.1256 - val_mae: 0.3503
# Epoch 36/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1865 - mse: 0.0348 - mae: 0.1544 - val_loss: 0.3530 - val_mse: 0.1246 - val_mae: 0.3489
# Epoch 37/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1858 - mse: 0.0346 - mae: 0.1538 - val_loss: 0.3552 - val_mse: 0.1262 - val_mae: 0.3511
# Epoch 38/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1851 - mse: 0.0343 - mae: 0.1530 - val_loss: 0.3585 - val_mse: 0.1285 - val_mae: 0.3545
# Epoch 39/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1839 - mse: 0.0340 - mae: 0.1523 - val_loss: 0.3606 - val_mse: 0.1300 - val_mae: 0.3566
# Epoch 40/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1839 - mse: 0.0338 - mae: 0.1518 - val_loss: 0.3609 - val_mse: 0.1302 - val_mae: 0.3570
# 1/1 [==============================] - 1s 554ms/step
# 3
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7f4f00ca60> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7f4f00ca60>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 310ms/step - loss: 0.5505 - mse: 0.3032 - mae: 0.5119 - val_loss: 0.8894 - val_mse: 0.7911 - val_mae: 0.8876
# Epoch 2/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5326 - mse: 0.2837 - mae: 0.4928 - val_loss: 0.8698 - val_mse: 0.7565 - val_mae: 0.8679
# Epoch 3/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5145 - mse: 0.2649 - mae: 0.4738 - val_loss: 0.8496 - val_mse: 0.7218 - val_mae: 0.8477
# Epoch 4/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4963 - mse: 0.2464 - mae: 0.4543 - val_loss: 0.8285 - val_mse: 0.6863 - val_mae: 0.8265
# Epoch 5/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4770 - mse: 0.2277 - mae: 0.4338 - val_loss: 0.8059 - val_mse: 0.6494 - val_mae: 0.8039
# Epoch 6/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4560 - mse: 0.2084 - mae: 0.4117 - val_loss: 0.7814 - val_mse: 0.6106 - val_mae: 0.7794
# Epoch 7/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4344 - mse: 0.1894 - mae: 0.3882 - val_loss: 0.7546 - val_mse: 0.5694 - val_mae: 0.7525
# Epoch 8/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4111 - mse: 0.1691 - mae: 0.3627 - val_loss: 0.7250 - val_mse: 0.5256 - val_mae: 0.7228
# Epoch 9/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3851 - mse: 0.1486 - mae: 0.3348 - val_loss: 0.6922 - val_mse: 0.4791 - val_mae: 0.6899
# Epoch 10/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3567 - mse: 0.1282 - mae: 0.3048 - val_loss: 0.6558 - val_mse: 0.4300 - val_mae: 0.6534
# Epoch 11/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3273 - mse: 0.1074 - mae: 0.2721 - val_loss: 0.6157 - val_mse: 0.3790 - val_mae: 0.6132
# Epoch 12/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2961 - mse: 0.0879 - mae: 0.2382 - val_loss: 0.5716 - val_mse: 0.3267 - val_mae: 0.5689
# Epoch 13/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2642 - mse: 0.0700 - mae: 0.2073 - val_loss: 0.5241 - val_mse: 0.2747 - val_mae: 0.5212
# Epoch 14/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2356 - mse: 0.0555 - mae: 0.1814 - val_loss: 0.4746 - val_mse: 0.2252 - val_mae: 0.4714
# Epoch 15/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2132 - mse: 0.0455 - mae: 0.1688 - val_loss: 0.4263 - val_mse: 0.1817 - val_mae: 0.4227
# Epoch 16/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1976 - mse: 0.0391 - mae: 0.1604 - val_loss: 0.3845 - val_mse: 0.1478 - val_mae: 0.3806
# Epoch 17/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1944 - mse: 0.0380 - mae: 0.1611 - val_loss: 0.3510 - val_mse: 0.1232 - val_mae: 0.3467
# Epoch 18/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1968 - mse: 0.0388 - mae: 0.1647 - val_loss: 0.3306 - val_mse: 0.1093 - val_mae: 0.3260
# Epoch 19/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1995 - mse: 0.0399 - mae: 0.1679 - val_loss: 0.3225 - val_mse: 0.1040 - val_mae: 0.3179
# Epoch 20/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1996 - mse: 0.0401 - mae: 0.1684 - val_loss: 0.3256 - val_mse: 0.1060 - val_mae: 0.3210
# Epoch 21/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1984 - mse: 0.0394 - mae: 0.1664 - val_loss: 0.3348 - val_mse: 0.1121 - val_mae: 0.3303
# Epoch 22/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1954 - mse: 0.0382 - mae: 0.1634 - val_loss: 0.3471 - val_mse: 0.1205 - val_mae: 0.3428
# Epoch 23/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1929 - mse: 0.0372 - mae: 0.1607 - val_loss: 0.3608 - val_mse: 0.1302 - val_mae: 0.3567
# Epoch 24/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1910 - mse: 0.0365 - mae: 0.1581 - val_loss: 0.3722 - val_mse: 0.1385 - val_mae: 0.3683
# Epoch 25/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1900 - mse: 0.0362 - mae: 0.1569 - val_loss: 0.3791 - val_mse: 0.1437 - val_mae: 0.3753
# Epoch 26/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1894 - mse: 0.0361 - mae: 0.1563 - val_loss: 0.3816 - val_mse: 0.1456 - val_mae: 0.3778
# Epoch 27/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1894 - mse: 0.0359 - mae: 0.1558 - val_loss: 0.3814 - val_mse: 0.1455 - val_mae: 0.3776
# Epoch 28/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1886 - mse: 0.0357 - mae: 0.1553 - val_loss: 0.3790 - val_mse: 0.1436 - val_mae: 0.3752
# Epoch 29/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1879 - mse: 0.0353 - mae: 0.1546 - val_loss: 0.3725 - val_mse: 0.1388 - val_mae: 0.3687
# Epoch 30/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1868 - mse: 0.0349 - mae: 0.1540 - val_loss: 0.3633 - val_mse: 0.1320 - val_mae: 0.3594
# Epoch 31/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1860 - mse: 0.0347 - mae: 0.1536 - val_loss: 0.3551 - val_mse: 0.1261 - val_mae: 0.3512
# Epoch 32/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1848 - mse: 0.0344 - mae: 0.1530 - val_loss: 0.3501 - val_mse: 0.1226 - val_mae: 0.3461
# Epoch 33/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1842 - mse: 0.0341 - mae: 0.1526 - val_loss: 0.3467 - val_mse: 0.1202 - val_mae: 0.3427
# Epoch 34/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1837 - mse: 0.0338 - mae: 0.1521 - val_loss: 0.3449 - val_mse: 0.1190 - val_mae: 0.3409
# Epoch 35/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1830 - mse: 0.0335 - mae: 0.1513 - val_loss: 0.3442 - val_mse: 0.1185 - val_mae: 0.3402
# Epoch 36/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1821 - mse: 0.0332 - mae: 0.1504 - val_loss: 0.3431 - val_mse: 0.1177 - val_mae: 0.3391
# Epoch 37/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1804 - mse: 0.0328 - mae: 0.1496 - val_loss: 0.3404 - val_mse: 0.1159 - val_mae: 0.3363
# Epoch 38/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1797 - mse: 0.0324 - mae: 0.1488 - val_loss: 0.3371 - val_mse: 0.1137 - val_mae: 0.3331
# Epoch 39/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1789 - mse: 0.0321 - mae: 0.1481 - val_loss: 0.3332 - val_mse: 0.1111 - val_mae: 0.3292
# Epoch 40/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1780 - mse: 0.0318 - mae: 0.1473 - val_loss: 0.3311 - val_mse: 0.1096 - val_mae: 0.3270
# 1/1 [==============================] - 1s 536ms/step
# 4
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f80301e1700> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f80301e1700>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 321ms/step - loss: 0.5504 - mse: 0.3035 - mae: 0.5120 - val_loss: 0.8882 - val_mse: 0.7890 - val_mae: 0.8864
# Epoch 2/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5327 - mse: 0.2840 - mae: 0.4928 - val_loss: 0.8683 - val_mse: 0.7539 - val_mae: 0.8664
# Epoch 3/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5145 - mse: 0.2649 - mae: 0.4737 - val_loss: 0.8480 - val_mse: 0.7191 - val_mae: 0.8461
# Epoch 4/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4966 - mse: 0.2466 - mae: 0.4543 - val_loss: 0.8269 - val_mse: 0.6837 - val_mae: 0.8250
# Epoch 5/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4774 - mse: 0.2280 - mae: 0.4340 - val_loss: 0.8045 - val_mse: 0.6472 - val_mae: 0.8025
# Epoch 6/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4561 - mse: 0.2090 - mae: 0.4124 - val_loss: 0.7803 - val_mse: 0.6089 - val_mae: 0.7783
# Epoch 7/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4358 - mse: 0.1900 - mae: 0.3892 - val_loss: 0.7539 - val_mse: 0.5684 - val_mae: 0.7518
# Epoch 8/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4111 - mse: 0.1702 - mae: 0.3639 - val_loss: 0.7248 - val_mse: 0.5253 - val_mae: 0.7226
# Epoch 9/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3867 - mse: 0.1500 - mae: 0.3369 - val_loss: 0.6925 - val_mse: 0.4796 - val_mae: 0.6903
# Epoch 10/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3578 - mse: 0.1297 - mae: 0.3071 - val_loss: 0.6568 - val_mse: 0.4314 - val_mae: 0.6545
# Epoch 11/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3298 - mse: 0.1093 - mae: 0.2752 - val_loss: 0.6175 - val_mse: 0.3813 - val_mae: 0.6150
# Epoch 12/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2984 - mse: 0.0899 - mae: 0.2415 - val_loss: 0.5744 - val_mse: 0.3299 - val_mae: 0.5717
# Epoch 13/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2672 - mse: 0.0721 - mae: 0.2103 - val_loss: 0.5278 - val_mse: 0.2786 - val_mae: 0.5250
# Epoch 14/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2384 - mse: 0.0568 - mae: 0.1835 - val_loss: 0.4792 - val_mse: 0.2296 - val_mae: 0.4761
# Epoch 15/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2140 - mse: 0.0458 - mae: 0.1682 - val_loss: 0.4306 - val_mse: 0.1854 - val_mae: 0.4271
# Epoch 16/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1990 - mse: 0.0396 - mae: 0.1613 - val_loss: 0.3863 - val_mse: 0.1492 - val_mae: 0.3824
# Epoch 17/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1940 - mse: 0.0376 - mae: 0.1603 - val_loss: 0.3516 - val_mse: 0.1236 - val_mae: 0.3474
# Epoch 18/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1957 - mse: 0.0385 - mae: 0.1640 - val_loss: 0.3289 - val_mse: 0.1082 - val_mae: 0.3244
# Epoch 19/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1999 - mse: 0.0400 - mae: 0.1683 - val_loss: 0.3202 - val_mse: 0.1025 - val_mae: 0.3156
# Epoch 20/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2007 - mse: 0.0403 - mae: 0.1690 - val_loss: 0.3244 - val_mse: 0.1053 - val_mae: 0.3199
# Epoch 21/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1983 - mse: 0.0394 - mae: 0.1669 - val_loss: 0.3362 - val_mse: 0.1131 - val_mae: 0.3319
# Epoch 22/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1944 - mse: 0.0380 - mae: 0.1628 - val_loss: 0.3503 - val_mse: 0.1227 - val_mae: 0.3461
# Epoch 23/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1924 - mse: 0.0371 - mae: 0.1601 - val_loss: 0.3650 - val_mse: 0.1333 - val_mae: 0.3610
# Epoch 24/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1911 - mse: 0.0366 - mae: 0.1580 - val_loss: 0.3766 - val_mse: 0.1418 - val_mae: 0.3727
# Epoch 25/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1908 - mse: 0.0364 - mae: 0.1573 - val_loss: 0.3850 - val_mse: 0.1482 - val_mae: 0.3812
# Epoch 26/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1906 - mse: 0.0364 - mae: 0.1568 - val_loss: 0.3885 - val_mse: 0.1509 - val_mae: 0.3847
# Epoch 27/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1898 - mse: 0.0364 - mae: 0.1565 - val_loss: 0.3872 - val_mse: 0.1499 - val_mae: 0.3835
# Epoch 28/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1897 - mse: 0.0361 - mae: 0.1560 - val_loss: 0.3814 - val_mse: 0.1455 - val_mae: 0.3777
# Epoch 29/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1888 - mse: 0.0357 - mae: 0.1554 - val_loss: 0.3739 - val_mse: 0.1398 - val_mae: 0.3701
# Epoch 30/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1877 - mse: 0.0353 - mae: 0.1547 - val_loss: 0.3667 - val_mse: 0.1345 - val_mae: 0.3629
# Epoch 31/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1864 - mse: 0.0350 - mae: 0.1544 - val_loss: 0.3585 - val_mse: 0.1285 - val_mae: 0.3546
# Epoch 32/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1860 - mse: 0.0348 - mae: 0.1541 - val_loss: 0.3516 - val_mse: 0.1237 - val_mae: 0.3477
# Epoch 33/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1858 - mse: 0.0345 - mae: 0.1537 - val_loss: 0.3488 - val_mse: 0.1217 - val_mae: 0.3448
# Epoch 34/40
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1845 - mse: 0.0343 - mae: 0.1532 - val_loss: 0.3471 - val_mse: 0.1205 - val_mae: 0.3431
# Epoch 35/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1837 - mse: 0.0340 - mae: 0.1525 - val_loss: 0.3480 - val_mse: 0.1211 - val_mae: 0.3441
# Epoch 36/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1832 - mse: 0.0337 - mae: 0.1517 - val_loss: 0.3472 - val_mse: 0.1205 - val_mae: 0.3432
# Epoch 37/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1827 - mse: 0.0334 - mae: 0.1510 - val_loss: 0.3471 - val_mse: 0.1205 - val_mae: 0.3431
# Epoch 38/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1817 - mse: 0.0331 - mae: 0.1502 - val_loss: 0.3450 - val_mse: 0.1190 - val_mae: 0.3410
# Epoch 39/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1803 - mse: 0.0327 - mae: 0.1495 - val_loss: 0.3448 - val_mse: 0.1189 - val_mae: 0.3409
# Epoch 40/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1799 - mse: 0.0324 - mae: 0.1487 - val_loss: 0.3439 - val_mse: 0.1183 - val_mae: 0.3400
# 1/1 [==============================] - 1s 571ms/step
# 5
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f803fb014c0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f803fb014c0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 319ms/step - loss: 0.5472 - mse: 0.2997 - mae: 0.5081 - val_loss: 0.8809 - val_mse: 0.7760 - val_mae: 0.8791
# Epoch 2/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.5309 - mse: 0.2823 - mae: 0.4909 - val_loss: 0.8625 - val_mse: 0.7439 - val_mae: 0.8606
# Epoch 3/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.5144 - mse: 0.2648 - mae: 0.4734 - val_loss: 0.8432 - val_mse: 0.7110 - val_mae: 0.8413
# Epoch 4/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4972 - mse: 0.2473 - mae: 0.4551 - val_loss: 0.8226 - val_mse: 0.6766 - val_mae: 0.8206
# Epoch 5/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4784 - mse: 0.2293 - mae: 0.4353 - val_loss: 0.8002 - val_mse: 0.6403 - val_mae: 0.7982
# Epoch 6/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.4586 - mse: 0.2104 - mae: 0.4139 - val_loss: 0.7755 - val_mse: 0.6014 - val_mae: 0.7735
# Epoch 7/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4367 - mse: 0.1909 - mae: 0.3908 - val_loss: 0.7481 - val_mse: 0.5597 - val_mae: 0.7460
# Epoch 8/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4128 - mse: 0.1705 - mae: 0.3648 - val_loss: 0.7176 - val_mse: 0.5149 - val_mae: 0.7154
# Epoch 9/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3863 - mse: 0.1494 - mae: 0.3364 - val_loss: 0.6835 - val_mse: 0.4671 - val_mae: 0.6812
# Epoch 10/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3576 - mse: 0.1280 - mae: 0.3058 - val_loss: 0.6455 - val_mse: 0.4167 - val_mae: 0.6432
# Epoch 11/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3267 - mse: 0.1071 - mae: 0.2722 - val_loss: 0.6034 - val_mse: 0.3641 - val_mae: 0.6009
# Epoch 12/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2940 - mse: 0.0867 - mae: 0.2373 - val_loss: 0.5572 - val_mse: 0.3105 - val_mae: 0.5546
# Epoch 13/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2595 - mse: 0.0678 - mae: 0.2043 - val_loss: 0.5076 - val_mse: 0.2576 - val_mae: 0.5047
# Epoch 14/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2310 - mse: 0.0534 - mae: 0.1785 - val_loss: 0.4560 - val_mse: 0.2079 - val_mae: 0.4528
# Epoch 15/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2074 - mse: 0.0432 - mae: 0.1648 - val_loss: 0.4059 - val_mse: 0.1647 - val_mae: 0.4023
# Epoch 16/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1945 - mse: 0.0378 - mae: 0.1588 - val_loss: 0.3622 - val_mse: 0.1312 - val_mae: 0.3582
# Epoch 17/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1910 - mse: 0.0365 - mae: 0.1580 - val_loss: 0.3307 - val_mse: 0.1093 - val_mae: 0.3263
# Epoch 18/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1931 - mse: 0.0375 - mae: 0.1618 - val_loss: 0.3131 - val_mse: 0.0980 - val_mae: 0.3085
# Epoch 19/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1963 - mse: 0.0387 - mae: 0.1651 - val_loss: 0.3076 - val_mse: 0.0946 - val_mae: 0.3029
# Epoch 20/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1963 - mse: 0.0387 - mae: 0.1653 - val_loss: 0.3119 - val_mse: 0.0973 - val_mae: 0.3074
# Epoch 21/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1945 - mse: 0.0378 - mae: 0.1631 - val_loss: 0.3236 - val_mse: 0.1047 - val_mae: 0.3192
# Epoch 22/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1909 - mse: 0.0365 - mae: 0.1594 - val_loss: 0.3386 - val_mse: 0.1146 - val_mae: 0.3344
# Epoch 23/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1876 - mse: 0.0356 - mae: 0.1563 - val_loss: 0.3550 - val_mse: 0.1260 - val_mae: 0.3510
# Epoch 24/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1871 - mse: 0.0350 - mae: 0.1544 - val_loss: 0.3662 - val_mse: 0.1341 - val_mae: 0.3624
# Epoch 25/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1870 - mse: 0.0350 - mae: 0.1541 - val_loss: 0.3729 - val_mse: 0.1390 - val_mae: 0.3691
# Epoch 26/40
# ...
# Epoch 36/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1966 - mse: 0.0388 - mae: 0.1739 - val_loss: 0.1669 - val_mse: 0.0279 - val_mae: 0.1403
# Epoch 37/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1947 - mse: 0.0379 - mae: 0.1722 - val_loss: 0.1657 - val_mse: 0.0274 - val_mae: 0.1380
# Epoch 38/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1920 - mse: 0.0369 - mae: 0.1699 - val_loss: 0.1632 - val_mse: 0.0266 - val_mae: 0.1367
# Epoch 39/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1892 - mse: 0.0358 - mae: 0.1670 - val_loss: 0.1608 - val_mse: 0.0259 - val_mae: 0.1353
# Epoch 40/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1864 - mse: 0.0348 - mae: 0.1640 - val_loss: 0.1584 - val_mse: 0.0251 - val_mae: 0.1338
# 1/1 [==============================] - 1s 560ms/step
# 149
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f82b14edf70> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f82b14edf70>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4/4 [==============================] - 3s 206ms/step - loss: 0.6544 - mse: 0.4290 - mae: 0.6094 - val_loss: 0.6137 - val_mse: 0.3766 - val_mae: 0.5794
# Epoch 2/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6326 - mse: 0.4002 - mae: 0.5860 - val_loss: 0.5909 - val_mse: 0.3491 - val_mae: 0.5555
# Epoch 3/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6091 - mse: 0.3713 - mae: 0.5615 - val_loss: 0.5663 - val_mse: 0.3207 - val_mae: 0.5296
# Epoch 4/40
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5839 - mse: 0.3413 - mae: 0.5347 - val_loss: 0.5390 - val_mse: 0.2906 - val_mae: 0.5007
# Epoch 5/40
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5555 - mse: 0.3091 - mae: 0.5047 - val_loss: 0.5082 - val_mse: 0.2583 - val_mae: 0.4682
# Epoch 6/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5235 - mse: 0.2746 - mae: 0.4706 - val_loss: 0.4729 - val_mse: 0.2237 - val_mae: 0.4307
# Epoch 7/40
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4872 - mse: 0.2375 - mae: 0.4313 - val_loss: 0.4327 - val_mse: 0.1872 - val_mae: 0.3883
# Epoch 8/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4456 - mse: 0.1987 - mae: 0.3870 - val_loss: 0.3871 - val_mse: 0.1498 - val_mae: 0.3410
# Epoch 9/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3995 - mse: 0.1597 - mae: 0.3378 - val_loss: 0.3369 - val_mse: 0.1135 - val_mae: 0.2910
# Epoch 10/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3494 - mse: 0.1227 - mae: 0.2875 - val_loss: 0.2848 - val_mse: 0.0811 - val_mae: 0.2475
# Epoch 11/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2998 - mse: 0.0901 - mae: 0.2473 - val_loss: 0.2366 - val_mse: 0.0560 - val_mae: 0.2110
# Epoch 12/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2576 - mse: 0.0665 - mae: 0.2177 - val_loss: 0.2025 - val_mse: 0.0410 - val_mae: 0.1830
# Epoch 13/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2328 - mse: 0.0542 - mae: 0.2034 - val_loss: 0.1899 - val_mse: 0.0361 - val_mae: 0.1659
# Epoch 14/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2255 - mse: 0.0509 - mae: 0.2010 - val_loss: 0.1920 - val_mse: 0.0369 - val_mae: 0.1595
# Epoch 15/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2274 - mse: 0.0518 - mae: 0.2019 - val_loss: 0.1956 - val_mse: 0.0383 - val_mae: 0.1581
# Epoch 16/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2294 - mse: 0.0528 - mae: 0.2024 - val_loss: 0.1960 - val_mse: 0.0384 - val_mae: 0.1574
# Epoch 17/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2286 - mse: 0.0523 - mae: 0.2014 - val_loss: 0.1927 - val_mse: 0.0371 - val_mae: 0.1570
# Epoch 18/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2251 - mse: 0.0508 - mae: 0.1999 - val_loss: 0.1886 - val_mse: 0.0356 - val_mae: 0.1574
# Epoch 19/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2217 - mse: 0.0492 - mae: 0.1974 - val_loss: 0.1859 - val_mse: 0.0346 - val_mae: 0.1590
# Epoch 20/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2195 - mse: 0.0482 - mae: 0.1954 - val_loss: 0.1849 - val_mse: 0.0342 - val_mae: 0.1604
# Epoch 21/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2184 - mse: 0.0478 - mae: 0.1938 - val_loss: 0.1842 - val_mse: 0.0339 - val_mae: 0.1610
# Epoch 22/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2176 - mse: 0.0474 - mae: 0.1926 - val_loss: 0.1833 - val_mse: 0.0336 - val_mae: 0.1600
# Epoch 23/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2165 - mse: 0.0469 - mae: 0.1915 - val_loss: 0.1822 - val_mse: 0.0332 - val_mae: 0.1585
# Epoch 24/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2148 - mse: 0.0463 - mae: 0.1903 - val_loss: 0.1812 - val_mse: 0.0328 - val_mae: 0.1574
# Epoch 25/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2135 - mse: 0.0457 - mae: 0.1891 - val_loss: 0.1801 - val_mse: 0.0324 - val_mae: 0.1561
# Epoch 26/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2122 - mse: 0.0451 - mae: 0.1879 - val_loss: 0.1790 - val_mse: 0.0320 - val_mae: 0.1541
# Epoch 27/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2108 - mse: 0.0444 - mae: 0.1868 - val_loss: 0.1780 - val_mse: 0.0317 - val_mae: 0.1520
# Epoch 28/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2090 - mse: 0.0438 - mae: 0.1857 - val_loss: 0.1769 - val_mse: 0.0313 - val_mae: 0.1506
# Epoch 29/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2077 - mse: 0.0432 - mae: 0.1843 - val_loss: 0.1759 - val_mse: 0.0309 - val_mae: 0.1490
# Epoch 30/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2060 - mse: 0.0425 - mae: 0.1829 - val_loss: 0.1748 - val_mse: 0.0306 - val_mae: 0.1474
# Epoch 31/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2045 - mse: 0.0418 - mae: 0.1815 - val_loss: 0.1735 - val_mse: 0.0301 - val_mae: 0.1461
# Epoch 32/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2024 - mse: 0.0411 - mae: 0.1796 - val_loss: 0.1717 - val_mse: 0.0295 - val_mae: 0.1454
# Epoch 33/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2004 - mse: 0.0402 - mae: 0.1777 - val_loss: 0.1699 - val_mse: 0.0289 - val_mae: 0.1448
# Epoch 34/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1982 - mse: 0.0394 - mae: 0.1755 - val_loss: 0.1682 - val_mse: 0.0283 - val_mae: 0.1434
# Epoch 35/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1961 - mse: 0.0385 - mae: 0.1733 - val_loss: 0.1664 - val_mse: 0.0277 - val_mae: 0.1424
# Epoch 36/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1940 - mse: 0.0377 - mae: 0.1710 - val_loss: 0.1645 - val_mse: 0.0271 - val_mae: 0.1419
# Epoch 37/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1918 - mse: 0.0369 - mae: 0.1685 - val_loss: 0.1627 - val_mse: 0.0265 - val_mae: 0.1408
# Epoch 38/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1892 - mse: 0.0360 - mae: 0.1660 - val_loss: 0.1607 - val_mse: 0.0258 - val_mae: 0.1389
# Epoch 39/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1870 - mse: 0.0350 - mae: 0.1636 - val_loss: 0.1585 - val_mse: 0.0251 - val_mae: 0.1355
# Epoch 40/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1836 - mse: 0.0338 - mae: 0.1609 - val_loss: 0.1564 - val_mse: 0.0245 - val_mae: 0.1326
# 1/1 [==============================] - 0s 500ms/step
# 150
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7f2b78e700> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7f2b78e700>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4/4 [==============================] - 3s 199ms/step - loss: 0.6569 - mse: 0.4321 - mae: 0.6121 - val_loss: 0.6166 - val_mse: 0.3802 - val_mae: 0.5823
# Epoch 2/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6348 - mse: 0.4030 - mae: 0.5883 - val_loss: 0.5931 - val_mse: 0.3518 - val_mae: 0.5576
# Epoch 3/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6106 - mse: 0.3731 - mae: 0.5629 - val_loss: 0.5675 - val_mse: 0.3220 - val_mae: 0.5305
# Epoch 4/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5842 - mse: 0.3415 - mae: 0.5348 - val_loss: 0.5387 - val_mse: 0.2902 - val_mae: 0.4998
# Epoch 5/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5542 - mse: 0.3075 - mae: 0.5029 - val_loss: 0.5059 - val_mse: 0.2559 - val_mae: 0.4652
# Epoch 6/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5200 - mse: 0.2712 - mae: 0.4666 - val_loss: 0.4684 - val_mse: 0.2194 - val_mae: 0.4254
# Epoch 7/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4809 - mse: 0.2323 - mae: 0.4251 - val_loss: 0.4258 - val_mse: 0.1813 - val_mae: 0.3804
# Epoch 8/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4381 - mse: 0.1925 - mae: 0.3781 - val_loss: 0.3781 - val_mse: 0.1430 - val_mae: 0.3311
# Epoch 9/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3899 - mse: 0.1530 - mae: 0.3279 - val_loss: 0.3267 - val_mse: 0.1068 - val_mae: 0.2815
# Epoch 10/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3391 - mse: 0.1151 - mae: 0.2775 - val_loss: 0.2749 - val_mse: 0.0755 - val_mae: 0.2401
# Epoch 11/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2910 - mse: 0.0847 - mae: 0.2411 - val_loss: 0.2293 - val_mse: 0.0526 - val_mae: 0.2063
# Epoch 12/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2530 - mse: 0.0641 - mae: 0.2162 - val_loss: 0.2008 - val_mse: 0.0403 - val_mae: 0.1811
# Epoch 13/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2314 - mse: 0.0537 - mae: 0.2032 - val_loss: 0.1932 - val_mse: 0.0373 - val_mae: 0.1669
# Epoch 14/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2303 - mse: 0.0531 - mae: 0.2052 - val_loss: 0.1975 - val_mse: 0.0390 - val_mae: 0.1620
# Epoch 15/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2328 - mse: 0.0543 - mae: 0.2059 - val_loss: 0.2004 - val_mse: 0.0402 - val_mae: 0.1610
# Epoch 16/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2338 - mse: 0.0548 - mae: 0.2057 - val_loss: 0.1984 - val_mse: 0.0394 - val_mae: 0.1605
# Epoch 17/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2311 - mse: 0.0535 - mae: 0.2041 - val_loss: 0.1943 - val_mse: 0.0377 - val_mae: 0.1604
# Epoch 18/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2267 - mse: 0.0518 - mae: 0.2022 - val_loss: 0.1908 - val_mse: 0.0364 - val_mae: 0.1611
# Epoch 19/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2247 - mse: 0.0505 - mae: 0.2002 - val_loss: 0.1889 - val_mse: 0.0357 - val_mae: 0.1622
# Epoch 20/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2228 - mse: 0.0497 - mae: 0.1982 - val_loss: 0.1879 - val_mse: 0.0353 - val_mae: 0.1629
# Epoch 21/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2217 - mse: 0.0492 - mae: 0.1967 - val_loss: 0.1870 - val_mse: 0.0350 - val_mae: 0.1628
# Epoch 22/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2206 - mse: 0.0487 - mae: 0.1954 - val_loss: 0.1860 - val_mse: 0.0346 - val_mae: 0.1616
# Epoch 23/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2190 - mse: 0.0481 - mae: 0.1943 - val_loss: 0.1849 - val_mse: 0.0342 - val_mae: 0.1597
# Epoch 24/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2178 - mse: 0.0474 - mae: 0.1932 - val_loss: 0.1839 - val_mse: 0.0338 - val_mae: 0.1584
# Epoch 25/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2164 - mse: 0.0468 - mae: 0.1920 - val_loss: 0.1830 - val_mse: 0.0335 - val_mae: 0.1567
# Epoch 26/40
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2149 - mse: 0.0463 - mae: 0.1909 - val_loss: 0.1819 - val_mse: 0.0331 - val_mae: 0.1554
# Epoch 27/40
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2134 - mse: 0.0456 - mae: 0.1896 - val_loss: 0.1808 - val_mse: 0.0327 - val_mae: 0.1541
# Epoch 28/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2115 - mse: 0.0449 - mae: 0.1880 - val_loss: 0.1793 - val_mse: 0.0322 - val_mae: 0.1537
# Epoch 29/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2102 - mse: 0.0442 - mae: 0.1863 - val_loss: 0.1779 - val_mse: 0.0316 - val_mae: 0.1535
# Epoch 30/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2084 - mse: 0.0435 - mae: 0.1844 - val_loss: 0.1766 - val_mse: 0.0312 - val_mae: 0.1521
# Epoch 31/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2058 - mse: 0.0428 - mae: 0.1828 - val_loss: 0.1753 - val_mse: 0.0307 - val_mae: 0.1502
# Epoch 32/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2046 - mse: 0.0420 - mae: 0.1812 - val_loss: 0.1740 - val_mse: 0.0303 - val_mae: 0.1482
# Epoch 33/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2026 - mse: 0.0412 - mae: 0.1796 - val_loss: 0.1725 - val_mse: 0.0297 - val_mae: 0.1470
# Epoch 34/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2011 - mse: 0.0404 - mae: 0.1776 - val_loss: 0.1707 - val_mse: 0.0291 - val_mae: 0.1461
# Epoch 35/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1984 - mse: 0.0395 - mae: 0.1754 - val_loss: 0.1690 - val_mse: 0.0286 - val_mae: 0.1446
# Epoch 36/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1965 - mse: 0.0386 - mae: 0.1732 - val_loss: 0.1673 - val_mse: 0.0280 - val_mae: 0.1429
# Epoch 37/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1939 - mse: 0.0377 - mae: 0.1710 - val_loss: 0.1654 - val_mse: 0.0274 - val_mae: 0.1410
# Epoch 38/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1914 - mse: 0.0367 - mae: 0.1684 - val_loss: 0.1633 - val_mse: 0.0267 - val_mae: 0.1394
# Epoch 39/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1888 - mse: 0.0357 - mae: 0.1658 - val_loss: 0.1613 - val_mse: 0.0260 - val_mae: 0.1370
# Epoch 40/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1856 - mse: 0.0345 - mae: 0.1632 - val_loss: 0.1595 - val_mse: 0.0255 - val_mae: 0.1339
# 1/1 [==============================] - 0s 487ms/step
# 151
# CPU times: user 19min 57s, sys: 53.5 s, total: 20min 50s
# Wall time: 16min 11s
# <ipython-input-1-8e1fe4ba9a94>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
# <ipython-input-1-8e1fe4ba9a94>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_data.before_close[i+1] = price_data.Close[i]

# %%
lstm_2_pred = scaler_y.inverse_transform(lstm_2_pred.reshape(len(x_t),1))

# %%
import pickle
with open(file='/home/whfhrs3260/deeplearning_result_data/lstm_2_pred_2014_2015.pkl', mode='wb') as f:
    pickle.dump(lstm_2_pred, f)
