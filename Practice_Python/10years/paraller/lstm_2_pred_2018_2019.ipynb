# %%
import json
import numpy as np
import pandas as pd

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import regex as re
from nltk.corpus import stopwords

from nltk.sentiment.vader import SentimentIntensityAnalyzer
import datetime

import yfinance as yf
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.layers import Embedding, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import optimizers
from keras import backend as K
import matplotlib.pyplot as plt

import datetime
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error 
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error

from multiprocessing import Pool

# %%
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
# 데이터 생성, 처리
def time_conversion(time):
    time = pd.Timestamp(time)
    return time

def date_cut_day(dataframe_date_timestamp):
    dataframe_date_timestamp = datetime.datetime.strftime(dataframe_date_timestamp, "%Y-%m-%d")
    return dataframe_date_timestamp

def train_test_result(dir, stock, variable, window_size):
    #score data 뽑기
    score = pd.read_csv(dir)
    score.columns = ["Date", "Score"]
    
    #price data 뽑기
    price_data = yf.download([stock],start = '2012-01-01', end = "2022-05-01")
    
    opening = price_data.index.copy()
    opening = pd.DataFrame(opening)
    opening["opening_date"] = 1
    opening.Date = opening.Date.apply(lambda x: date_cut_day(x))
    
    Date = pd.date_range(start='20111230', end='20220430')
    Date = pd.DataFrame({"Date" : Date.values})
    Date.Date = Date.Date.apply(lambda x: date_cut_day(x))

    
    set_news_data_date = pd.merge(Date, opening, how ="left",left_on='Date', right_on = "Date") 
    set_news_data_date = set_news_data_date.where(pd.notnull(set_news_data_date), 0) 
    set_news_data_date.Date = set_news_data_date.Date.apply(lambda x: pd.to_datetime(x, errors="ignore"))

    standard=set_news_data_date.Date.iloc[len(set_news_data_date)-1] + datetime.timedelta(days=1)
    set_news_data_date["price_date"]=0
    for i in range(len(set_news_data_date)-1,-1,-1):
        if i==(len(set_news_data_date)-1):
            standard = set_news_data_date.Date[i]
            set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
        elif (set_news_data_date.opening_date[i]==1)&(set_news_data_date.opening_date[i+1]==1):
            standard = set_news_data_date.Date[i]
            set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
        elif (i!=0):
            if((set_news_data_date.opening_date[i]==1)&(set_news_data_date.opening_date[i+1]==0)&(set_news_data_date.opening_date[i-1]==0)):
                set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
                standard = set_news_data_date.Date[i]
            else:
                set_news_data_date.price_date[i]=standard
        else:
            set_news_data_date.price_date[i]=standard
    
    set_news_data_date.Date = set_news_data_date.Date.apply(lambda x: date_cut_day(x))
    
    score = pd.merge(set_news_data_date,score, how ="left",on = "Date")
    
    score = score[['Date','Score', "price_date"]]
    score = score.groupby('price_date').mean({"Score"})
    score = score[score.index<="2022-04-29"]

    first_data = yf.download([stock],start = '2011-12-30', end = '2012-01-01')
    
    price_data = price_data.reset_index()
    score = score.reset_index()
    score.columns = ["Date", "Score"]
    
    price_data = price_data[(price_data["Date"]<"2020-01-01")&("2018-01-01"<=price_data["Date"])]
    
    #price data와 score data 결합
    price_data = pd.merge(price_data, score, how ="left",left_on='Date', right_on = "Date")[["Close","Open","Score"]]

    #뉴스가 없는 날은 즉, score가 없는 날은 중립의 의미로 0으로 처리
    price_data.Score[price_data.Score.isnull()]=0

    #전날 종가의 영향을 받으므로 전날 종가 변수를 생성
    price_data["before_close"] = 0
    price_data = price_data.reset_index(drop=True)
    for i in range(len(price_data)-1):
        price_data.before_close[i+1] = price_data.Close[i]
    
    price_data.before_close[0] = first_data["Close"][0]

    # minmaxscaler 사용
    price_data.columns = ["Close","Open","Score","before_close"]
    
    x = price_data[variable]
    y = price_data[["Close"]]
    scaler_x = MinMaxScaler()
    scaler_y = MinMaxScaler()

    x = pd.DataFrame(scaler_x.fit_transform(x))
    y = pd.DataFrame(scaler_y.fit_transform(y))
    
    x.columns = variable
    y.columns = ["Close"]

    train_index = int(len(x)*0.7)

    train_x = x.iloc[0:train_index]
    test_x = x.iloc[train_index:len(x)]

    train_y = y.iloc[0:train_index]
    test_y = y.iloc[train_index:len(y)]

    train_x = train_x.to_numpy().reshape(train_x.shape[0],1,train_x.shape[1])
    train_y = train_y.to_numpy().reshape(train_y.shape[0],train_y.shape[1])
    test_x = test_x.to_numpy().reshape(test_x.shape[0],1,test_x.shape[1])
    test_y = test_y.to_numpy().reshape(test_y.shape[0],test_y.shape[1])
    
    #window size에 맞게 데이터 설정
    x = np.zeros(shape=(train_x.shape[0]-window_size+1,window_size,x.shape[1]))
    for i in range(train_x.shape[0]-window_size+1):
        x[i]=np.vstack((train_x[i:i+window_size]))

    y = train_y[window_size-1:train_x.shape[0]]

    x_t = np.zeros(shape=(test_x.shape[0]-window_size+1,window_size,x.shape[2]))
    for i in range(test_x.shape[0]-window_size+1):
        x_t[i]=np.vstack((test_x[i:i+window_size]))
    
    y_t = test_y[window_size-1:test_x.shape[0]]
    
    return scaler_x, scaler_y, x, y, x_t, y_t

# %%
# %%time
dir = "/home/whfhrs3260/csv_data/price_data_score_10years.csv"
stock = "^DJI"
variable = ["before_close","Score"]
window_size = 1

scaler_x, scaler_y, x, y, x_t, y_t = train_test_result(dir, stock, variable, window_size)


lstm_2_pred = []
model_input = 0
len_x = x.shape[0]
len_y = y.shape[0]


for i in range(len(x_t)):
    lstm_2_model = Sequential()
    lstm_2_model.add(LSTM(50, input_shape = (x.shape[1],x.shape[2]),return_sequences=True))
    lstm_2_model.add((LSTM(50)))
    lstm_2_model.add(Dense(1,activation="tanh"))
    def root_mean_squared_error(y_true, y_pred):
            return K.sqrt(K.mean(K.square(y_pred - y_true))) 
    lstm_2_model.compile(optimizer="adam", loss = root_mean_squared_error, metrics=['mse',"mae"])
    lstm_2_model.fit(x, y, epochs=40, batch_size=128, validation_split=0.2)
    
    model_input = x_t[i].reshape(1, window_size, len(variable))
    lstm_2_pred = np.append(lstm_2_pred,lstm_2_model.predict(model_input)[0])

    x = np.append(x,x_t[i])
    y = np.append(y,y_t[i])
    len_x += 1
    len_y += 1
    x = x.reshape(len_x,window_size,len(variable))
    y = y.reshape(len_y,1)
    print(i)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f82b332dee0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f82b332dee0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 290ms/step - loss: 0.4747 - mse: 0.2255 - mae: 0.4591 - val_loss: 0.5928 - val_mse: 0.3515 - val_mae: 0.5905
# Epoch 2/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4585 - mse: 0.2103 - mae: 0.4424 - val_loss: 0.5756 - val_mse: 0.3313 - val_mae: 0.5733
# Epoch 3/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4417 - mse: 0.1952 - mae: 0.4252 - val_loss: 0.5576 - val_mse: 0.3109 - val_mae: 0.5552
# Epoch 4/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4242 - mse: 0.1801 - mae: 0.4071 - val_loss: 0.5384 - val_mse: 0.2899 - val_mae: 0.5359
# Epoch 5/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4055 - mse: 0.1646 - mae: 0.3878 - val_loss: 0.5176 - val_mse: 0.2679 - val_mae: 0.5150
# Epoch 6/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3851 - mse: 0.1484 - mae: 0.3667 - val_loss: 0.4946 - val_mse: 0.2447 - val_mae: 0.4919
# Epoch 7/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3629 - mse: 0.1317 - mae: 0.3436 - val_loss: 0.4692 - val_mse: 0.2202 - val_mae: 0.4664
# Epoch 8/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3382 - mse: 0.1146 - mae: 0.3179 - val_loss: 0.4409 - val_mse: 0.1944 - val_mae: 0.4379
# Epoch 9/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3109 - mse: 0.0967 - mae: 0.2893 - val_loss: 0.4092 - val_mse: 0.1674 - val_mae: 0.4060
# Epoch 10/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2813 - mse: 0.0792 - mae: 0.2583 - val_loss: 0.3739 - val_mse: 0.1398 - val_mae: 0.3704
# Epoch 11/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2480 - mse: 0.0620 - mae: 0.2238 - val_loss: 0.3350 - val_mse: 0.1122 - val_mae: 0.3311
# Epoch 12/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2140 - mse: 0.0460 - mae: 0.1872 - val_loss: 0.2924 - val_mse: 0.0855 - val_mae: 0.2879
# Epoch 13/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1791 - mse: 0.0322 - mae: 0.1512 - val_loss: 0.2465 - val_mse: 0.0608 - val_mae: 0.2410
# Epoch 14/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1470 - mse: 0.0216 - mae: 0.1183 - val_loss: 0.1992 - val_mse: 0.0397 - val_mae: 0.1924
# Epoch 15/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1227 - mse: 0.0151 - mae: 0.0964 - val_loss: 0.1550 - val_mse: 0.0240 - val_mae: 0.1460
# Epoch 16/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1165 - mse: 0.0136 - mae: 0.0923 - val_loss: 0.1194 - val_mse: 0.0143 - val_mae: 0.1082
# Epoch 17/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1243 - mse: 0.0155 - mae: 0.0995 - val_loss: 0.0996 - val_mse: 0.0099 - val_mae: 0.0862
# Epoch 18/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1306 - mse: 0.0171 - mae: 0.1048 - val_loss: 0.0972 - val_mse: 0.0094 - val_mae: 0.0835
# Epoch 19/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1298 - mse: 0.0170 - mae: 0.1045 - val_loss: 0.1058 - val_mse: 0.0112 - val_mae: 0.0933
# Epoch 20/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1251 - mse: 0.0157 - mae: 0.1002 - val_loss: 0.1220 - val_mse: 0.0149 - val_mae: 0.1111
# Epoch 21/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1198 - mse: 0.0144 - mae: 0.0949 - val_loss: 0.1401 - val_mse: 0.0196 - val_mae: 0.1302
# Epoch 22/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1169 - mse: 0.0137 - mae: 0.0926 - val_loss: 0.1554 - val_mse: 0.0242 - val_mae: 0.1467
# Epoch 23/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1167 - mse: 0.0137 - mae: 0.0921 - val_loss: 0.1659 - val_mse: 0.0275 - val_mae: 0.1577
# Epoch 24/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1175 - mse: 0.0139 - mae: 0.0924 - val_loss: 0.1708 - val_mse: 0.0292 - val_mae: 0.1629
# Epoch 25/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.
40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1109 - mse: 0.0125 - mae: 0.0878 - val_loss: 0.1376 - val_mse: 0.0189 - val_mae: 0.1283
# Epoch 29/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1117 - mse: 0.0125 - mae: 0.0879 - val_loss: 0.1334 - val_mse: 0.0178 - val_mae: 0.1238
# Epoch 30/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1116 - mse: 0.0125 - mae: 0.0878 - val_loss: 0.1334 - val_mse: 0.0178 - val_mae: 0.1239
# Epoch 31/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1111 - mse: 0.0124 - mae: 0.0877 - val_loss: 0.1339 - val_mse: 0.0179 - val_mae: 0.1244
# Epoch 32/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1114 - mse: 0.0124 - mae: 0.0875 - val_loss: 0.1361 - val_mse: 0.0185 - val_mae: 0.1268
# Epoch 33/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1108 - mse: 0.0124 - mae: 0.0873 - val_loss: 0.1400 - val_mse: 0.0196 - val_mae: 0.1309
# Epoch 34/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1108 - mse: 0.0123 - mae: 0.0871 - val_loss: 0.1418 - val_mse: 0.0201 - val_mae: 0.1329
# Epoch 35/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1108 - mse: 0.0123 - mae: 0.0870 - val_loss: 0.1432 - val_mse: 0.0205 - val_mae: 0.1344
# Epoch 36/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1104 - mse: 0.0123 - mae: 0.0869 - val_loss: 0.1441 - val_mse: 0.0208 - val_mae: 0.1354
# Epoch 37/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1108 - mse: 0.0123 - mae: 0.0869 - val_loss: 0.1429 - val_mse: 0.0204 - val_mae: 0.1341
# Epoch 38/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1103 - mse: 0.0122 - mae: 0.0867 - val_loss: 0.1381 - val_mse: 0.0191 - val_mae: 0.1290
# Epoch 39/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1104 - mse: 0.0122 - mae: 0.0866 - val_loss: 0.1339 - val_mse: 0.0179 - val_mae: 0.1246
# Epoch 40/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1099 - mse: 0.0122 - mae: 0.0867 - val_loss: 0.1334 - val_mse: 0.0178 - val_mae: 0.1241
# 1/1 [==============================] - 1s 504ms/step
# 1
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f80eaefd1f0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f80eaefd1f0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 301ms/step - loss: 0.4766 - mse: 0.2273 - mae: 0.4612 - val_loss: 0.5896 - val_mse: 0.3476 - val_mae: 0.5870
# Epoch 2/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4578 - mse: 0.2097 - mae: 0.4418 - val_loss: 0.5695 - val_mse: 0.3244 - val_mae: 0.5669
# Epoch 3/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4383 - mse: 0.1922 - mae: 0.4218 - val_loss: 0.5485 - val_mse: 0.3008 - val_mae: 0.5457
# Epoch 4/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4177 - mse: 0.1746 - mae: 0.4007 - val_loss: 0.5260 - val_mse: 0.2766 - val_mae: 0.5231
# Epoch 5/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3961 - mse: 0.1569 - mae: 0.3781 - val_loss: 0.5016 - val_mse: 0.2516 - val_mae: 0.4987
# Epoch 6/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3725 - mse: 0.1389 - mae: 0.3537 - val_loss: 0.4751 - val_mse: 0.2258 - val_mae: 0.4720
# Epoch 7/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3470 - mse: 0.1206 - mae: 0.3273 - val_loss: 0.4461 - val_mse: 0.1990 - val_mae: 0.4428
# Epoch 8/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3193 - mse: 0.1022 - mae: 0.2984 - val_loss: 0.4142 - val_mse: 0.1716 - val_mae: 0.4107
# Epoch 9/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2891 - mse: 0.0836 - mae: 0.2668 - val_loss: 0.3791 - val_mse: 0.1437 - val_mae: 0.3753
# Epoch 10/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.
and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7f4c374c10>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 314ms/step - loss: 0.4812 - mse: 0.2317 - mae: 0.4658 - val_loss: 0.5889 - val_mse: 0.3468 - val_mae: 0.5856
# Epoch 2/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4633 - mse: 0.2146 - mae: 0.4475 - val_loss: 0.5700 - val_mse: 0.3249 - val_mae: 0.5666
# Epoch 3/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4447 - mse: 0.1980 - mae: 0.4287 - val_loss: 0.5504 - val_mse: 0.3029 - val_mae: 0.5469
# Epoch 4/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4260 - mse: 0.1817 - mae: 0.4093 - val_loss: 0.5298 - val_mse: 0.2807 - val_mae: 0.5262
# Epoch 5/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4061 - mse: 0.1650 - mae: 0.3886 - val_loss: 0.5077 - val_mse: 0.2578 - val_mae: 0.5040
# Epoch 6/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3848 - mse: 0.1482 - mae: 0.3665 - val_loss: 0.4838 - val_mse: 0.2340 - val_mae: 0.4799
# Epoch 7/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.3616 - mse: 0.1309 - mae: 0.3425 - val_loss: 0.4576 - val_mse: 0.2094 - val_mae: 0.4535
# Epoch 8/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3365 - mse: 0.1134 - mae: 0.3164 - val_loss: 0.4286 - val_mse: 0.1837 - val_mae: 0.4243
# Epoch 9/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3091 - mse: 0.0957 - mae: 0.2877 - val_loss: 0.3967 - val_mse: 0.1574 - val_mae: 0.3921
# Epoch 10/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.2789 - mse: 0.0778 - mae: 0.2566 - val_loss: 0.3615 - val_mse: 0.1307 - val_mae: 0.3564
# Epoch 11/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2467 - mse: 0.0609 - mae: 0.2226 - val_loss: 0.3229 - val_mse: 0.1042 - val_mae: 0.3172
# Epoch 12/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2126 - mse: 0.0453 - mae: 0.1866 - val_loss: 0.2809 - val_mse: 0.0789 - val_mae: 0.2745
# Epoch 13/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1778 - mse: 0.0316 - mae: 0.1505 - val_loss: 0.2364 - val_mse: 0.0559 - val_mae: 0.2287
# Epoch 14/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1458 - mse: 0.0213 - mae: 0.1179 - val_loss: 0.1906 - val_mse: 0.0363 - val_mae: 0.1812
# Epoch 15/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1230 - mse: 0.0152 - mae: 0.0965 - val_loss: 0.1480 - val_mse: 0.0219 - val_mae: 0.1364
# Epoch 16/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1152 - mse: 0.0134 - mae: 0.0913 - val_loss: 0.1158 - val_mse: 0.0134 - val_mae: 0.1031
# Epoch 17/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1186 - mse: 0.0141 - mae: 0.0947 - val_loss: 0.0992 - val_mse: 0.0098 - val_mae: 0.0862
# Epoch 18/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1242 - mse: 0.0155 - mae: 0.0990 - val_loss: 0.0955 - val_mse: 0.0091 - val_mae: 0.0824
# Epoch 19/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1247 - mse: 0.0156 - mae: 0.0995 - val_loss: 0.1019 - val_mse: 0.0104 - val_mae: 0.0891
# Epoch 20/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1209 - mse: 0.0147 - mae: 0.0962 - val_loss: 0.1147 - val_mse: 0.0132 - val_mae: 0.1021
# Epoch 21/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1164 - mse: 0.0136 - mae: 0.0922 - val_loss: 0.1300 - val_mse: 0.0169 - val_mae: 0.1178
# Epoch 22/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1146 - mse: 0.0131 - mae: 0.0909 - val_loss: 0.1441 - val_mse: 0.0208 - val_mae: 0.1326
# Epoch 23/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1136 - mse: 0.0130 - mae: 0.0898 - val_loss: 0.1516 - val_mse: 0.0230 - val_mae: 0.1404
# Epoch 24/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1142 - mse: 0.0131 - mae: 0.0902 - val_loss: 0.1553 - val_mse: 0.0241 - val_mae: 0.1443
# Epoch 25/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1149 - mse: 0.0132 - mae: 0.0904 - val_loss: 0.1547 - val_mse: 0.0239 - val_mae: 0.1437
# Epoch 26/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1139 - mse: 0.0132 - mae: 0.0901 - val_loss: 0.1508 - val_mse: 0.0228 - val_mae: 0.1396
# Epoch 27/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1140 - mse: 0.0130 - mae: 0.0899 - val_loss: 0.1453 - val_mse: 0.0211 - val_mae: 0.1339
# Epoch 28/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1133 - mse: 0.0129 - mae: 0.0895 - val_loss: 0.1417 - val_mse: 0.0201 - val_mae: 0.1302
# Epoch 29/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1131 - mse: 0.0128 - mae: 0.0894 - val_loss: 0.1395 - val_mse: 0.0195 - val_mae: 0.1280
# Epoch 30/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1125 - mse: 0.0128 - mae: 0.0893 - val_loss: 0.1385 - val_mse: 0.0192 - val_mae: 0.1270
# Epoch 31/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1129 - mse: 0.0128 - mae: 0.0892 - val_loss: 0.1368 - val_mse: 0.0187 - val_mae: 0.1252
# Epoch 32/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1128 - mse: 0.0127 - mae: 0.0891 - val_loss: 0.1341 - val_mse: 0.0180 - val_mae: 0.1224
# Epoch 33/40
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1126 - mse: 0.0127 - mae: 0.0891 - val_loss: 0.1329 - val_mse: 0.0177 - val_mae: 0.1212
# Epoch 34/40
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1125 - mse: 0.0127 - mae: 0.0890 - val_loss: 0.1335 - val_mse: 0.0178 - val_mae: 0.1218
# Epoch 35/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1124 - mse: 0.0127 - mae: 0.0888 - val_loss: 0.1360 - val_mse: 0.0185 - val_mae: 0.1245
# Epoch 36/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1121 - mse: 0.0126 - mae: 0.0886 - val_loss: 0.1383 - val_mse: 0.0191 - val_mae: 0.1269
# Epoch 37/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1119 - mse: 0.0126 - mae: 0.0884 - val_loss: 0.1373 - val_mse: 0.0189 - val_mae: 0.1259
# Epoch 38/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1118 - mse: 0.0126 - mae: 0.0883 - val_loss: 0.1355 - val_mse: 0.0184 - val_mae: 0.1241
# Epoch 39/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1119 - mse: 0.0125 - mae: 0.0882 - val_loss: 0.1366 - val_mse: 0.0187 - val_mae: 0.1253
# Epoch 40/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1116 - mse: 0.0125 - mae: 0.0880 - val_loss: 0.1393 - val_mse: 0.0194 - val_mae: 0.1281
# 1/1 [==============================] - 1s 509ms/step
# 5
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7fe134a700> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7fe134a700>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 280ms/step - loss: 0.4748 - mse: 0.2256 - mae: 0.4591 - val_loss: 0.5807 - val_mse: 0.3372 - val_mae: 0.5774
# Epoch 2/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4553 - mse: 0.2074 - mae: 0.4392 - val_loss: 0.5603 - val_mse: 0.3139 - val_mae: 0.5568
# Epoch 3/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4354 - mse: 0.1896 - mae: 0.4187 - val_loss: 0.5390 - val_mse: 0.2905 - val_mae: 0.5354
# Epoch 4/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4146 - mse: 0.1720 - mae: 0.3974 - val_loss: 0.5166 - val_mse: 0.2669 - val_mae: 0.5128
# Epoch 5/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3930 - mse: 0.1546 - mae: 0.3749 - val_loss: 0.4925 - val_mse: 0.2425 - val_mae: 0.4886
# Epoch 6/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3697 - mse: 0.1367 - mae: 0.3506 - val_loss: 0.4664 - val_mse: 0.2175 - val_mae: 0.4622
# Epoch 7/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3443 - mse: 0.1186 - mae: 0.3242 - val_loss: 0.4377 - val_mse: 0.1916 - val_mae: 0.4333
# Epoch 8/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3171 - mse: 0.1006 - mae: 0.2956 - val_loss: 0.4063 - val_mse: 0.1651 - val_mae: 0.4016
# Epoch 9/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2871 - mse: 0.0826 - mae: 0.2645 - val_loss: 0.3717 - val_mse: 0.1382 - val_mae: 0.3666
# Epoch 10/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2553 - mse: 0.0654 - mae: 0.2312 - val_loss: 0.3339 - val_mse: 0.1115 - val_mae: 0.3282
# Epoch 11/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2218 - mse: 0.0493 - mae: 0.1955 - val_loss: 0.2929 - val_mse: 0.0858 - val_mae: 0.2863
# Epoch 12/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1862 - mse: 0.0353 - mae: 0.1590 - val_loss: 0.2492 - val_mse: 0.0621 - val_mae: 0.2414
# Epoch 13/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1534 - mse: 0.0236 - mae: 0.1257 - val_loss: 0.2039 - val_mse: 0.0416 - val_mae: 0.1943
# Epoch 14/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1296 - mse: 0.0169 - mae: 0.1035 - val_loss: 0.1610 - val_mse: 0.0259 - val_mae: 0.1493
# Epoch 15/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1166 - mse: 0.0136 - mae: 0.0926 - val_loss: 0.1272 - val_mse: 0.0162 - val_mae: 0.1138
# Epoch 16/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1199 - mse: 0.0144 - mae: 0.0956 - val_loss: 0.1046 - val_mse: 0.0109 - val_mae: 0.0906
# Epoch 17/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1265 - mse: 0.0161 - mae: 0.1015 - val_loss: 0.0959 - val_mse: 0.0092 - val_mae: 0.0815
# Epoch 18/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1296 - mse: 0.0168 - mae: 0.1038 - val_loss: 0.0984 - val_mse: 0.0097 - val_mae: 0.0841
# Epoch 19/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1272 - mse: 0.0162 - mae: 0.1020 - val_loss: 0.1084 - val_mse: 0.0117 - val_mae: 0.0947
# Epoch 20/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1220 - mse: 0.0150 - mae: 0.0974 - val_loss: 0.1214 - val_mse: 0.0147 - val_mae: 0.1080
# Epoch 21/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1182 - mse: 0.0140 - mae: 0.0942 - val_loss: 0.1359 - val_mse: 0.0185 - val_mae: 0.1229
# Epoch 22/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1161 - mse: 0.0135 - mae: 0.0923 - val_loss: 0.1483 - val_mse: 0.0220 - val_mae: 0.1361
# Epoch 23/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1166 - mse: 0.0136 - mae: 0.0926 - val_loss: 0.1568 - val_mse: 0.0246 - val_mae: 0.1451
# Epoch 24/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1170 - mse: 0.0138 - mae: 0.0927 - val_loss: 0.1592 - val_mse: 0.0254 - val_mae: 0.1477
# Epoch 25/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1174 - mse: 0.0138 - mae: 0.0927 - val_loss: 0.1574 - val_mse: 0.0248 - val_mae: 0.1458
# Epoch 26/40
# ...
# Epoch 36/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1251 - mse: 0.0157 - mae: 0.1017 - val_loss: 0.2510 - val_mse: 0.0630 - val_mae: 0.2305
# Epoch 37/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1244 - mse: 0.0157 - mae: 0.1014 - val_loss: 0.2508 - val_mse: 0.0629 - val_mae: 0.2303
# Epoch 38/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1242 - mse: 0.0156 - mae: 0.1011 - val_loss: 0.2492 - val_mse: 0.0621 - val_mae: 0.2286
# Epoch 39/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1243 - mse: 0.0155 - mae: 0.1009 - val_loss: 0.2499 - val_mse: 0.0625 - val_mae: 0.2294
# Epoch 40/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1241 - mse: 0.0154 - mae: 0.1006 - val_loss: 0.2498 - val_mse: 0.0624 - val_mae: 0.2292
# 1/1 [==============================] - 1s 508ms/step
# 148
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f8311fb6790> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f8311fb6790>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4/4 [==============================] - 5s 354ms/step - loss: 0.5320 - mse: 0.2832 - mae: 0.5139 - val_loss: 0.7609 - val_mse: 0.5790 - val_mae: 0.7522
# Epoch 2/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5075 - mse: 0.2578 - mae: 0.4887 - val_loss: 0.7346 - val_mse: 0.5396 - val_mae: 0.7256
# Epoch 3/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4821 - mse: 0.2326 - mae: 0.4624 - val_loss: 0.7064 - val_mse: 0.4990 - val_mae: 0.6973
# Epoch 4/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4547 - mse: 0.2070 - mae: 0.4342 - val_loss: 0.6755 - val_mse: 0.4563 - val_mae: 0.6661
# Epoch 5/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4248 - mse: 0.1808 - mae: 0.4030 - val_loss: 0.6410 - val_mse: 0.4109 - val_mae: 0.6313
# Epoch 6/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3917 - mse: 0.1535 - mae: 0.3683 - val_loss: 0.6021 - val_mse: 0.3625 - val_mae: 0.5920
# Epoch 7/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3542 - mse: 0.1257 - mae: 0.3293 - val_loss: 0.5578 - val_mse: 0.3111 - val_mae: 0.5473
# Epoch 8/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3127 - mse: 0.0979 - mae: 0.2860 - val_loss: 0.5075 - val_mse: 0.2576 - val_mae: 0.4963
# Epoch 9/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2668 - mse: 0.0715 - mae: 0.2372 - val_loss: 0.4511 - val_mse: 0.2035 - val_mae: 0.4389
# Epoch 10/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2188 - mse: 0.0484 - mae: 0.1868 - val_loss: 0.3897 - val_mse: 0.1519 - val_mae: 0.3760
# Epoch 11/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1724 - mse: 0.0301 - mae: 0.1413 - val_loss: 0.3266 - val_mse: 0.1067 - val_mae: 0.3108
# Epoch 12/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1394 - mse: 0.0195 - mae: 0.1130 - val_loss: 0.2685 - val_mse: 0.0721 - val_mae: 0.2496
# Epoch 13/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1309 - mse: 0.0172 - mae: 0.1064 - val_loss: 0.2261 - val_mse: 0.0511 - val_mae: 0.2037
# Epoch 14/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1397 - mse: 0.0196 - mae: 0.1130 - val_loss: 0.2062 - val_mse: 0.0425 - val_mae: 0.1818
# Epoch 15/40
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1442 - mse: 0.0210 - mae: 0.1162 - val_loss: 0.2091 - val_mse: 0.0437 - val_mae: 0.1850
# Epoch 16/40
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1408 - mse: 0.0199 - mae: 0.1134 - val_loss: 0.2282 - val_mse: 0.0521 - val_mae: 0.2059
# Epoch 17/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1335 - mse: 0.0178 - mae: 0.1081 - val_loss: 0.2524 - val_mse: 0.0637 - val_mae: 0.2321
# Epoch 18/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1299 - mse: 0.0169 - mae: 0.1058 - val_loss: 0.2706 - val_mse: 0.0732 - val_mae: 0.2516
# Epoch 19/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1299 - mse: 0.0169 - mae: 0.1059 - val_loss: 0.2764 - val_mse: 0.0764 - val_mae: 0.2578
# Epoch 20/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1302 - mse: 0.0170 - mae: 0.1061 - val_loss: 0.2744 - val_mse: 0.0753 - val_mae: 0.2557
# Epoch 21/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1295 - mse: 0.0168 - mae: 0.1057 - val_loss: 0.2712 - val_mse: 0.0735 - val_mae: 0.2522
# Epoch 22/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1289 - mse: 0.0167 - mae: 0.1052 - val_loss: 0.2648 - val_mse: 0.0701 - val_mae: 0.2454
# Epoch 23/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1281 - mse: 0.0165 - mae: 0.1043 - val_loss: 0.2570 - val_mse: 0.0660 - val_mae: 0.2370
# Epoch 24/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1275 - mse: 0.0164 - mae: 0.1040 - val_loss: 0.2478 - val_mse: 0.0614 - val_mae: 0.2270
# Epoch 25/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1279 - mse: 0.0164 - mae: 0.1039 - val_loss: 0.2443 - val_mse: 0.0597 - val_mae: 0.2233
# Epoch 26/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1277 - mse: 0.0164 - mae: 0.1037 - val_loss: 0.2475 - val_mse: 0.0613 - val_mae: 0.2267
# Epoch 27/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1269 - mse: 0.0162 - mae: 0.1032 - val_loss: 0.2531 - val_mse: 0.0641 - val_mae: 0.2328
# Epoch 28/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1262 - mse: 0.0160 - mae: 0.1027 - val_loss: 0.2538 - val_mse: 0.0644 - val_mae: 0.2335
# Epoch 29/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1260 - mse: 0.0159 - mae: 0.1023 - val_loss: 0.2566 - val_mse: 0.0658 - val_mae: 0.2365
# Epoch 30/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1254 - mse: 0.0158 - mae: 0.1021 - val_loss: 0.2582 - val_mse: 0.0667 - val_mae: 0.2382
# Epoch 31/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1252 - mse: 0.0157 - mae: 0.1017 - val_loss: 0.2577 - val_mse: 0.0664 - val_mae: 0.2377
# Epoch 32/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1246 - mse: 0.0156 - mae: 0.1012 - val_loss: 0.2519 - val_mse: 0.0635 - val_mae: 0.2314
# Epoch 33/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1240 - mse: 0.0155 - mae: 0.1008 - val_loss: 0.2428 - val_mse: 0.0589 - val_mae: 0.2215
# Epoch 34/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1240 - mse: 0.0154 - mae: 0.1004 - val_loss: 0.2410 - val_mse: 0.0581 - val_mae: 0.2195
# Epoch 35/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1232 - mse: 0.0152 - mae: 0.0998 - val_loss: 0.2464 - val_mse: 0.0607 - val_mae: 0.2253
# Epoch 36/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1225 - mse: 0.0150 - mae: 0.0993 - val_loss: 0.2526 - val_mse: 0.0638 - val_mae: 0.2319
# Epoch 37/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1224 - mse: 0.0150 - mae: 0.0990 - val_loss: 0.2555 - val_mse: 0.0653 - val_mae: 0.2350
# Epoch 38/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1218 - mse: 0.0149 - mae: 0.0987 - val_loss: 0.2483 - val_mse: 0.0617 - val_mae: 0.2273
# Epoch 39/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1211 - mse: 0.0147 - mae: 0.0978 - val_loss: 0.2371 - val_mse: 0.0562 - val_mae: 0.2151
# Epoch 40/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1204 - mse: 0.0146 - mae: 0.0974 - val_loss: 0.2359 - val_mse: 0.0557 - val_mae: 0.2138
# 1/1 [==============================] - 1s 710ms/step
# 149
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7fa56e45e0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7fa56e45e0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4/4 [==============================] - 4s 273ms/step - loss: 0.5307 - mse: 0.2818 - mae: 0.5126 - val_loss: 0.7628 - val_mse: 0.5818 - val_mae: 0.7539
# Epoch 2/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5068 - mse: 0.2570 - mae: 0.4881 - val_loss: 0.7369 - val_mse: 0.5431 - val_mae: 0.7279
# Epoch 3/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4819 - mse: 0.2325 - mae: 0.4624 - val_loss: 0.7092 - val_mse: 0.5030 - val_mae: 0.7000
# Epoch 4/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4549 - mse: 0.2071 - mae: 0.4345 - val_loss: 0.6787 - val_mse: 0.4607 - val_mae: 0.6692
# Epoch 5/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4252 - mse: 0.1809 - mae: 0.4035 - val_loss: 0.6444 - val_mse: 0.4152 - val_mae: 0.6346
# Epoch 6/40
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3919 - mse: 0.1536 - mae: 0.3688 - val_loss: 0.6053 - val_mse: 0.3664 - val_mae: 0.5951
# Epoch 7/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3542 - mse: 0.1255 - mae: 0.3293 - val_loss: 0.5604 - val_mse: 0.3141 - val_mae: 0.5497
# Epoch 8/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3115 - mse: 0.0971 - mae: 0.2842 - val_loss: 0.5092 - val_mse: 0.2592 - val_mae: 0.4977
# Epoch 9/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2644 - mse: 0.0701 - mae: 0.2342 - val_loss: 0.4512 - val_mse: 0.2036 - val_mae: 0.4388
# Epoch 10/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2146 - mse: 0.0462 - mae: 0.1821 - val_loss: 0.3879 - val_mse: 0.1505 - val_mae: 0.3739
# Epoch 11/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1684 - mse: 0.0287 - mae: 0.1386 - val_loss: 0.3226 - val_mse: 0.1041 - val_mae: 0.3062
# Epoch 12/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1384 - mse: 0.0192 - mae: 0.1126 - val_loss: 0.2648 - val_mse: 0.0701 - val_mae: 0.2452
# Epoch 13/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1338 - mse: 0.0179 - mae: 0.1088 - val_loss: 0.2282 - val_mse: 0.0521 - val_mae: 0.2054
# Epoch 14/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1415 - mse: 0.0201 - mae: 0.1139 - val_loss: 0.2172 - val_mse: 0.0472 - val_mae: 0.1934
# Epoch 15/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1428 - mse: 0.0204 - mae: 0.1148 - val_loss: 0.2285 - val_mse: 0.0522 - val_mae: 0.2056
# Epoch 16/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1371 - mse: 0.0189 - mae: 0.1110 - val_loss: 0.2489 - val_mse: 0.0620 - val_mae: 0.2279
# Epoch 17/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1323 - mse: 0.0176 - mae: 0.1072 - val_loss: 0.2674 - val_mse: 0.0715 - val_mae: 0.2477
# Epoch 18/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1314 - mse: 0.0173 - mae: 0.1071 - val_loss: 0.2814 - val_mse: 0.0792 - val_mae: 0.2627
# Epoch 19/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1319 - mse: 0.0174 - mae: 0.1076 - val_loss: 0.2861 - val_mse: 0.0819 - val_mae: 0.2677
# Epoch 20/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1320 - mse: 0.0174 - mae: 0.1077 - val_loss: 0.2823 - val_mse: 0.0797 - val_mae: 0.2636
# Epoch 21/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1311 - mse: 0.0172 - mae: 0.1070 - val_loss: 0.2751 - val_mse: 0.0757 - val_mae: 0.2559
# Epoch 22/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1303 - mse: 0.0170 - mae: 0.1062 - val_loss: 0.2666 - val_mse: 0.0711 - val_mae: 0.2468
# Epoch 23/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1295 - mse: 0.0169 - mae: 0.1056 - val_loss: 0.2579 - val_mse: 0.0665 - val_mae: 0.2375
# Epoch 24/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1296 - mse: 0.0169 - mae: 0.1055 - val_loss: 0.2552 - val_mse: 0.0651 - val_mae: 0.2345
# Epoch 25/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1295 - mse: 0.0168 - mae: 0.1052 - val_loss: 0.2582 - val_mse: 0.0667 - val_mae: 0.2378
# Epoch 26/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1279 - mse: 0.0167 - mae: 0.1048 - val_loss: 0.2634 - val_mse: 0.0694 - val_mae: 0.2434
# Epoch 27/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1284 - mse: 0.0166 - mae: 0.1047 - val_loss: 0.2712 - val_mse: 0.0735 - val_mae: 0.2517
# Epoch 28/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1289 - mse: 0.0166 - mae: 0.1049 - val_loss: 0.2764 - val_mse: 0.0764 - val_mae: 0.2572
# Epoch 29/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1289 - mse: 0.0167 - mae: 0.1051 - val_loss: 0.2747 - val_mse: 0.0755 - val_mae: 0.2554
# Epoch 30/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1284 - mse: 0.0165 - mae: 0.1046 - val_loss: 0.2679 - val_mse: 0.0718 - val_mae: 0.2481
# Epoch 31/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1275 - mse: 0.0163 - mae: 0.1037 - val_loss: 0.2615 - val_mse: 0.0684 - val_mae: 0.2413
# Epoch 32/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1272 - mse: 0.0162 - mae: 0.1033 - val_loss: 0.2506 - val_mse: 0.0628 - val_mae: 0.2295
# Epoch 33/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1272 - mse: 0.0162 - mae: 0.1033 - val_loss: 0.2459 - val_mse: 0.0605 - val_mae: 0.2245
# Epoch 34/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1272 - mse: 0.0162 - mae: 0.1032 - val_loss: 0.2452 - val_mse: 0.0601 - val_mae: 0.2236
# Epoch 35/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1265 - mse: 0.0161 - mae: 0.1027 - val_loss: 0.2506 - val_mse: 0.0628 - val_mae: 0.2294
# Epoch 36/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1258 - mse: 0.0158 - mae: 0.1021 - val_loss: 0.2564 - val_mse: 0.0658 - val_mae: 0.2357
# Epoch 37/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1253 - mse: 0.0157 - mae: 0.1018 - val_loss: 0.2600 - val_mse: 0.0676 - val_mae: 0.2396
# Epoch 38/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1248 - mse: 0.0157 - mae: 0.1016 - val_loss: 0.2643 - val_mse: 0.0698 - val_mae: 0.2441
# Epoch 39/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1248 - mse: 0.0157 - mae: 0.1016 - val_loss: 0.2642 - val_mse: 0.0698 - val_mae: 0.2441
# Epoch 40/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1246 - mse: 0.0156 - mae: 0.1013 - val_loss: 0.2633 - val_mse: 0.0693 - val_mae: 0.2431
# 1/1 [==============================] - 1s 645ms/step
# 150
# CPU times: user 20min 8s, sys: 54.2 s, total: 21min 2s
# Wall time: 16min 24s
# <ipython-input-1-7688e5d525d5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
# <ipython-input-1-7688e5d525d5>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_data.before_close[i+1] = price_data.Close[i]

# %%
lstm_2_pred = scaler_y.inverse_transform(lstm_2_pred.reshape(len(x_t),1))

# %%
import pickle
with open(file='/home/whfhrs3260/deeplearning_result_data/lstm_2_pred_2018_2019.pkl', mode='wb') as f:
    pickle.dump(lstm_2_pred, f)
