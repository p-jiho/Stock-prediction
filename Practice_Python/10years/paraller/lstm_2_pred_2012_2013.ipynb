# %%
import json
import numpy as np
import pandas as pd

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import regex as re
from nltk.corpus import stopwords

from nltk.sentiment.vader import SentimentIntensityAnalyzer
import datetime

import yfinance as yf
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.layers import Embedding, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import optimizers
from keras import backend as K
import matplotlib.pyplot as plt

import datetime
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error 
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error

from multiprocessing import Pool

# %%
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
# 데이터 생성, 처리
def time_conversion(time):
    time = pd.Timestamp(time)
    return time

def date_cut_day(dataframe_date_timestamp):
    dataframe_date_timestamp = datetime.datetime.strftime(dataframe_date_timestamp, "%Y-%m-%d")
    return dataframe_date_timestamp

def train_test_result(dir, stock, variable, window_size):
    #score data 뽑기
    score = pd.read_csv(dir)
    score.columns = ["Date", "Score"]
    
    #price data 뽑기
    price_data = yf.download([stock],start = '2012-01-01', end = "2022-05-01")
    
    opening = price_data.index.copy()
    opening = pd.DataFrame(opening)
    opening["opening_date"] = 1
    opening.Date = opening.Date.apply(lambda x: date_cut_day(x))
    
    Date = pd.date_range(start='20111230', end='20220430')
    Date = pd.DataFrame({"Date" : Date.values})
    Date.Date = Date.Date.apply(lambda x: date_cut_day(x))

    
    set_news_data_date = pd.merge(Date, opening, how ="left",left_on='Date', right_on = "Date") 
    set_news_data_date = set_news_data_date.where(pd.notnull(set_news_data_date), 0) 
    set_news_data_date.Date = set_news_data_date.Date.apply(lambda x: pd.to_datetime(x, errors="ignore"))

    standard=set_news_data_date.Date.iloc[len(set_news_data_date)-1] + datetime.timedelta(days=1)
    set_news_data_date["price_date"]=0
    for i in range(len(set_news_data_date)-1,-1,-1):
        if i==(len(set_news_data_date)-1):
            standard = set_news_data_date.Date[i]
            set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
        elif (set_news_data_date.opening_date[i]==1)&(set_news_data_date.opening_date[i+1]==1):
            standard = set_news_data_date.Date[i]
            set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
        elif (i!=0):
            if((set_news_data_date.opening_date[i]==1)&(set_news_data_date.opening_date[i+1]==0)&(set_news_data_date.opening_date[i-1]==0)):
                set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
                standard = set_news_data_date.Date[i]
            else:
                set_news_data_date.price_date[i]=standard
        else:
            set_news_data_date.price_date[i]=standard
    
    set_news_data_date.Date = set_news_data_date.Date.apply(lambda x: date_cut_day(x))
    
    score = pd.merge(set_news_data_date,score, how ="left",on = "Date")
    
    score = score[['Date','Score', "price_date"]]
    score = score.groupby('price_date').mean({"Score"})
    score = score[score.index<="2022-04-29"]

    first_data = yf.download([stock],start = '2011-12-30', end = '2012-01-01')
    
    price_data = price_data.reset_index()
    score = score.reset_index()
    score.columns = ["Date", "Score"]
    
    price_data = price_data[(price_data["Date"]<"2014-01-01")&("2012-01-01"<=price_data["Date"])]
    
    #price data와 score data 결합
    price_data = pd.merge(price_data, score, how ="left",left_on='Date', right_on = "Date")[["Close","Open","Score"]]

    #뉴스가 없는 날은 즉, score가 없는 날은 중립의 의미로 0으로 처리
    price_data.Score[price_data.Score.isnull()]=0

    #전날 종가의 영향을 받으므로 전날 종가 변수를 생성
    price_data["before_close"] = 0
    price_data = price_data.reset_index(drop=True)
    for i in range(len(price_data)-1):
        price_data.before_close[i+1] = price_data.Close[i]
    
    price_data.before_close[0] = first_data["Close"][0]

    # minmaxscaler 사용
    price_data.columns = ["Close","Open","Score","before_close"]
    
    x = price_data[variable]
    y = price_data[["Close"]]
    scaler_x = MinMaxScaler()
    scaler_y = MinMaxScaler()

    x = pd.DataFrame(scaler_x.fit_transform(x))
    y = pd.DataFrame(scaler_y.fit_transform(y))
    
    x.columns = variable
    y.columns = ["Close"]

    train_index = int(len(x)*0.7)

    train_x = x.iloc[0:train_index]
    test_x = x.iloc[train_index:len(x)]

    train_y = y.iloc[0:train_index]
    test_y = y.iloc[train_index:len(y)]

    train_x = train_x.to_numpy().reshape(train_x.shape[0],1,train_x.shape[1])
    train_y = train_y.to_numpy().reshape(train_y.shape[0],train_y.shape[1])
    test_x = test_x.to_numpy().reshape(test_x.shape[0],1,test_x.shape[1])
    test_y = test_y.to_numpy().reshape(test_y.shape[0],test_y.shape[1])
    
    #window size에 맞게 데이터 설정
    x = np.zeros(shape=(train_x.shape[0]-window_size+1,window_size,x.shape[1]))
    for i in range(train_x.shape[0]-window_size+1):
        x[i]=np.vstack((train_x[i:i+window_size]))

    y = train_y[window_size-1:train_x.shape[0]]

    x_t = np.zeros(shape=(test_x.shape[0]-window_size+1,window_size,x.shape[2]))
    for i in range(test_x.shape[0]-window_size+1):
        x_t[i]=np.vstack((test_x[i:i+window_size]))
    
    y_t = test_y[window_size-1:test_x.shape[0]]
    
    return scaler_x, scaler_y, x, y, x_t, y_t

# %%
# %%time
dir = "/home/whfhrs3260/csv_data/price_data_score_10years.csv"
stock = "^DJI"
variable = ["before_close","Score"]
window_size = 1

scaler_x, scaler_y, x, y, x_t, y_t = train_test_result(dir, stock, variable, window_size)


lstm_2_pred = []
model_input = 0
len_x = x.shape[0]
len_y = y.shape[0]


for i in range(len(x_t)):
    lstm_2_model = Sequential()
    lstm_2_model.add(LSTM(50, input_shape = (x.shape[1],x.shape[2]),return_sequences=True))
    lstm_2_model.add((LSTM(50)))
    lstm_2_model.add(Dense(1,activation="tanh"))
    def root_mean_squared_error(y_true, y_pred):
            return K.sqrt(K.mean(K.square(y_pred - y_true))) 
    lstm_2_model.compile(optimizer="adam", loss = root_mean_squared_error, metrics=['mse',"mae"])
    lstm_2_model.fit(x, y, epochs=40, batch_size=128, validation_split=0.2)
    
    model_input = x_t[i].reshape(1, window_size, len(variable))
    lstm_2_pred = np.append(lstm_2_pred,lstm_2_model.predict(model_input)[0])

    x = np.append(x,x_t[i])
    y = np.append(y,y_t[i])
    len_x += 1
    len_y += 1
    x = x.reshape(len_x,window_size,len(variable))
    y = y.reshape(len_y,1)
    print(i)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f81aaab6790> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f81aaab6790>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 309ms/step - loss: 0.2239 - mse: 0.0502 - mae: 0.2060 - val_loss: 0.5591 - val_mse: 0.3126 - val_mae: 0.5512
# Epoch 2/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2086 - mse: 0.0436 - mae: 0.1896 - val_loss: 0.5423 - val_mse: 0.2941 - val_mae: 0.5341
# Epoch 3/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1933 - mse: 0.0374 - mae: 0.1731 - val_loss: 0.5248 - val_mse: 0.2755 - val_mae: 0.5164
# Epoch 4/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1777 - mse: 0.0316 - mae: 0.1557 - val_loss: 0.5063 - val_mse: 0.2563 - val_mae: 0.4975
# Epoch 5/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1615 - mse: 0.0261 - mae: 0.1381 - val_loss: 0.4863 - val_mse: 0.2365 - val_mae: 0.4771
# Epoch 6/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1446 - mse: 0.0209 - mae: 0.1205 - val_loss: 0.4646 - val_mse: 0.2159 - val_mae: 0.4549
# Epoch 7/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1281 - mse: 0.0164 - mae: 0.1049 - val_loss: 0.4411 - val_mse: 0.1946 - val_mae: 0.4308
# Epoch 8/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1118 - mse: 0.0125 - mae: 0.0902 - val_loss: 0.4160 - val_mse: 0.1730 - val_mae: 0.4049
# Epoch 9/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0981 - mse: 0.0098 - mae: 0.0785 - val_loss: 0.3898 - val_mse: 0.1519 - val_mae: 0.3779
# Epoch 10/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0896 - mse: 0.0080 - mae: 0.0710 - val_loss: 0.3645 - val_mse: 0.1328 - val_mae: 0.3517
# Epoch 11/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0885 - mse: 0.0079 - mae: 0.0690 - val_loss: 0.3438 - val_mse: 0.1182 - val_mae: 0.3302
# Epoch 12/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0906 - mse: 0.0082 - mae: 0.0712 - val_loss: 0.3330 - val_mse: 0.1109 - val_mae: 0.3192
# Epoch 13/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0922 - mse: 0.0085 - mae: 0.0728 - val_loss: 0.3315 - val_mse: 0.1099 - val_mae: 0.3178
# Epoch 14/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0910 - mse: 0.0083 - mae: 0.0716 - val_loss: 0.3371 - val_mse: 0.1136 - val_mae: 0.3238
# Epoch 15/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0882 - mse: 0.0078 - mae: 0.0691 - val_loss: 0.3456 - val_mse: 0.1194 - val_mae: 0.3328
# Epoch 16/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0861 - mse: 0.0074 - mae: 0.0671 - val_loss: 0.3536 - val_mse: 0.1250 - val_mae: 0.3413
# Epoch 17/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0852 - mse: 0.0073 - mae: 0.0664 - val_loss: 0.3593 - val_mse: 0.1291 - val_mae: 0.3474
# Epoch 18/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0847 - mse: 0.0072 - mae: 0.0666 - val_loss: 0.3607 - val_mse: 0.1301 - val_mae: 0.3491
# Epoch 19/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0844 - mse: 0.0072 - mae: 0.0665 - val_loss: 0.3583 - val_mse: 0.1284 - val_mae: 0.3467
# Epoch 20/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0840 - mse: 0.0071 - mae: 0.0659 - val_loss: 0.3537 - val_mse: 0.1251 - val_mae: 0.3421
# Epoch 21/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0832 - mse: 0.0069 - mae: 0.0651 - val_loss: 0.3469 - val_mse: 0.1203 - val_mae: 0.3352
# Epoch 22/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0822 - mse: 0.0068 - mae: 0.0644 - val_loss: 0.3397 - val_mse: 0.1154 - val_mae: 0.3280
# Epoch 23/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0815 - mse: 0.0067 - mae: 0.0637 - val_loss: 0.3333 - val_mse: 0.1111 - val_mae: 0.3215
# Epoch 24/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0810 - mse: 0.0066 - mae: 0.0632 - val_loss: 0.3292 - val_mse: 0.1084 - val_mae: 0.3175
# Epoch 25/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.
40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1365 - mse: 0.0187 - mae: 0.1131 - val_loss: 0.4492 - val_mse: 0.2018 - val_mae: 0.4397
# Epoch 8/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1208 - mse: 0.0147 - mae: 0.0985 - val_loss: 0.4254 - val_mse: 0.1809 - val_mae: 0.4154
# Epoch 9/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1056 - mse: 0.0112 - mae: 0.0849 - val_loss: 0.4000 - val_mse: 0.1600 - val_mae: 0.3893
# Epoch 10/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0935 - mse: 0.0087 - mae: 0.0740 - val_loss: 0.3738 - val_mse: 0.1397 - val_mae: 0.3624
# Epoch 11/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0866 - mse: 0.0075 - mae: 0.0683 - val_loss: 0.3485 - val_mse: 0.1214 - val_mae: 0.3363
# Epoch 12/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0855 - mse: 0.0073 - mae: 0.0668 - val_loss: 0.3282 - val_mse: 0.1077 - val_mae: 0.3154
# Epoch 13/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0884 - mse: 0.0078 - mae: 0.0697 - val_loss: 0.3169 - val_mse: 0.1004 - val_mae: 0.3039
# Epoch 14/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0897 - mse: 0.0081 - mae: 0.0715 - val_loss: 0.3151 - val_mse: 0.0993 - val_mae: 0.3022
# Epoch 15/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0883 - mse: 0.0078 - mae: 0.0702 - val_loss: 0.3196 - val_mse: 0.1022 - val_mae: 0.3072
# Epoch 16/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0854 - mse: 0.0073 - mae: 0.0674 - val_loss: 0.3269 - val_mse: 0.1069 - val_mae: 0.3149
# Epoch 17/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0828 - mse: 0.0069 - mae: 0.0647 - val_loss: 0.3351 - val_mse: 0.1123 - val_mae: 0.3236
# Epoch 18/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0810 - mse: 0.0066 - mae: 0.0631 - val_loss: 0.3405 - val_mse: 0.1159 - val_mae: 0.3294
# Epoch 19/40
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0808 - mse: 0.0065 - mae: 0.0631 - val_loss: 0.3426 - val_mse: 0.1174 - val_mae: 0.3319
# Epoch 20/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0804 - mse: 0.0065 - mae: 0.0630 - val_loss: 0.3412 - val_mse: 0.1164 - val_mae: 0.3306
# Epoch 21/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0796 - mse: 0.0064 - mae: 0.0625 - val_loss: 0.3364 - val_mse: 0.1132 - val_mae: 0.3259
# Epoch 22/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0787 - mse: 0.0062 - mae: 0.0616 - val_loss: 0.3282 - val_mse: 0.1077 - val_mae: 0.3177
# Epoch 23/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0773 - mse: 0.0060 - mae: 0.0605 - val_loss: 0.3185 - val_mse: 0.1014 - val_mae: 0.3079
# Epoch 24/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0761 - mse: 0.0058 - mae: 0.0595 - val_loss: 0.3083 - val_mse: 0.0951 - val_mae: 0.2977
# Epoch 25/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0757 - mse: 0.0057 - mae: 0.0593 - val_loss: 0.2993 - val_mse: 0.0896 - val_mae: 0.2887
# Epoch 26/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0749 - mse: 0.0056 - mae: 0.0589 - val_loss: 0.2948 - val_mse: 0.0869 - val_mae: 0.2844
# Epoch 27/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0741 - mse: 0.0055 - mae: 0.0582 - val_loss: 0.2920 - val_mse: 0.0852 - val_mae: 0.2817
# Epoch 28/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0728 - mse: 0.0053 - mae: 0.0571 - val_loss: 0.2916 - val_mse: 0.0851 - val_mae: 0.2817
# Epoch 29/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.
40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0891 - mse: 0.0080 - mae: 0.0696 - val_loss: 0.3588 - val_mse: 0.1287 - val_mae: 0.3466
# Epoch 12/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0885 - mse: 0.0078 - mae: 0.0690 - val_loss: 0.3391 - val_mse: 0.1150 - val_mae: 0.3263
# Epoch 13/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0906 - mse: 0.0082 - mae: 0.0715 - val_loss: 0.3295 - val_mse: 0.1086 - val_mae: 0.3165
# Epoch 14/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0912 - mse: 0.0084 - mae: 0.0726 - val_loss: 0.3283 - val_mse: 0.1078 - val_mae: 0.3155
# Epoch 15/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0897 - mse: 0.0081 - mae: 0.0711 - val_loss: 0.3325 - val_mse: 0.1105 - val_mae: 0.3201
# Epoch 16/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0871 - mse: 0.0076 - mae: 0.0687 - val_loss: 0.3382 - val_mse: 0.1144 - val_mae: 0.3262
# Epoch 17/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0850 - mse: 0.0072 - mae: 0.0663 - val_loss: 0.3432 - val_mse: 0.1178 - val_mae: 0.3317
# Epoch 18/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0831 - mse: 0.0070 - mae: 0.0652 - val_loss: 0.3468 - val_mse: 0.1203 - val_mae: 0.3356
# Epoch 19/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0825 - mse: 0.0069 - mae: 0.0645 - val_loss: 0.3490 - val_mse: 0.1218 - val_mae: 0.3382
# Epoch 20/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0821 - mse: 0.0068 - mae: 0.0642 - val_loss: 0.3478 - val_mse: 0.1210 - val_mae: 0.3371
# Epoch 21/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0816 - mse: 0.0067 - mae: 0.0637 - val_loss: 0.3432 - val_mse: 0.1178 - val_mae: 0.3326
# Epoch 22/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0805 - mse: 0.0065 - mae: 0.0628 - val_loss: 0.3345 - val_mse: 0.1119 - val_mae: 0.3239
# Epoch 23/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0794 - mse: 0.0063 - mae: 0.0617 - val_loss: 0.3245 - val_mse: 0.1053 - val_mae: 0.3139
# Epoch 24/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0783 - mse: 0.0062 - mae: 0.0612 - val_loss: 0.3149 - val_mse: 0.0992 - val_mae: 0.3043
# Epoch 25/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0775 - mse: 0.0061 - mae: 0.0609 - val_loss: 0.3084 - val_mse: 0.0951 - val_mae: 0.2978
# Epoch 26/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0769 - mse: 0.0059 - mae: 0.0603 - val_loss: 0.3062 - val_mse: 0.0937 - val_mae: 0.2958
# Epoch 27/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0756 - mse: 0.0057 - mae: 0.0593 - val_loss: 0.3046 - val_mse: 0.0928 - val_mae: 0.2946
# Epoch 28/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0744 - mse: 0.0055 - mae: 0.0582 - val_loss: 0.3031 - val_mse: 0.0919 - val_mae: 0.2933
# Epoch 29/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0731 - mse: 0.0054 - mae: 0.0573 - val_loss: 0.3003 - val_mse: 0.0902 - val_mae: 0.2907
# Epoch 30/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0717 - mse: 0.0052 - mae: 0.0563 - val_loss: 0.2942 - val_mse: 0.0866 - val_mae: 0.2849
# Epoch 31/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0705 - mse: 0.0050 - mae: 0.0553 - val_loss: 0.2871 - val_mse: 0.0824 - val_mae: 0.2780
# Epoch 32/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0692 - mse: 0.0048 - mae: 0.0543 - val_loss: 0.2810 - val_mse: 0.0790 - val_mae: 0.2721
# Epoch 33/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0678 - mse: 0.0046 - mae: 0.0532 - val_loss: 0.2749 - val_mse: 0.0756 - val_mae: 0.2662
# Epoch 34/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0661 - mse: 0.0044 - mae: 0.0521 - val_loss: 0.2677 - val_mse: 0.0717 - val_mae: 0.2593
# Epoch 35/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0645 - mse: 0.0042 - mae: 0.0508 - val_loss: 0.2599 - val_mse: 0.0675 - val_mae: 0.2517
# Epoch 36/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0627 - mse: 0.0040 - mae: 0.0495 - val_loss: 0.2489 - val_mse: 0.0620 - val_mae: 0.2409
# Epoch 37/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0611 - mse: 0.0037 - mae: 0.0482 - val_loss: 0.2399 - val_mse: 0.0575 - val_mae: 0.2321
# Epoch 38/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0592 - mse: 0.0035 - mae: 0.0467 - val_loss: 0.2302 - val_mse: 0.0530 - val_mae: 0.2227
# Epoch 39/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0571 - mse: 0.0033 - mae: 0.0451 - val_loss: 0.2206 - val_mse: 0.0487 - val_mae: 0.2135
# Epoch 40/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0550 - mse: 0.0030 - mae: 0.0435 - val_loss: 0.2095 - val_mse: 0.0439 - val_mae: 0.2027
# 1/1 [==============================] - 1s 777ms/step
# 2
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f825ab05af0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f825ab05af0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 5s 436ms/step - loss: 0.2223 - mse: 0.0495 - mae: 0.2037 - val_loss: 0.5617 - val_mse: 0.3155 - val_mae: 0.5542
# Epoch 2/40
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2072 - mse: 0.0431 - mae: 0.1877 - val_loss: 0.5447 - val_mse: 0.2967 - val_mae: 0.5370
# Epoch 3/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1921 - mse: 0.0370 - mae: 0.1710 - val_loss: 0.5267 - val_mse: 0.2774 - val_mae: 0.5187
# Epoch 4/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1763 - mse: 0.0311 - mae: 0.1535 - val_loss: 0.5073 - val_mse: 0.2574 - val_mae: 0.4990
# Epoch 5/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1600 - mse: 0.0256 - mae: 0.1359 - val_loss: 0.4863 - val_mse: 0.2365 - val_mae: 0.4776
# Epoch 6/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1431 - mse: 0.0206 - mae: 0.1189 - val_loss: 0.4634 - val_mse: 0.2147 - val_mae: 0.4542
# Epoch 7/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1259 - mse: 0.0159 - mae: 0.1026 - val_loss: 0.4385 - val_mse: 0.1923 - val_mae: 0.4288
# Epoch 8/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1101 - mse: 0.0121 - mae: 0.0880 - val_loss: 0.4119 - val_mse: 0.1697 - val_mae: 0.4016
# Epoch 9/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0973 - mse: 0.0095 - mae: 0.0772 - val_loss: 0.3848 - val_mse: 0.1481 - val_mae: 0.3738
# Epoch 10/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0894 - mse: 0.0080 - mae: 0.0701 - val_loss: 0.3592 - val_mse: 0.1290 - val_mae: 0.3474
# Epoch 11/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0885 - mse: 0.0079 - mae: 0.0692 - val_loss: 0.3378 - val_mse: 0.1141 - val_mae: 0.3253
# Epoch 12/40
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0909 - mse: 0.0083 - mae: 0.0719 - val_loss: 0.3255 - val_mse: 0.1060 - val_mae: 0.3129
# Epoch 13/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0923 - mse: 0.0085 - mae: 0.0736 - val_loss: 0.3242 - val_mse: 0.1051 - val_mae: 0.3117
# Epoch 14/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0904 - mse: 0.0082 - mae: 0.0719 - val_loss: 0.3300 - val_mse: 0.1089 - val_mae: 0.3180
# Epoch 15/40
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0873 - mse: 0.0076 - mae: 0.0688 - val_loss: 0.3387 - val_mse: 0.1147 - val_mae: 0.3272
# Epoch 16/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0845 - mse: 0.0072 - mae: 0.0657 - val_loss: 0.3459 - val_mse: 0.1197 - val_mae: 0.3349
# Epoch 17/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0831 - mse: 0.0070 - mae: 0.0648 - val_loss: 0.3502 - val_mse: 0.1226 - val_mae: 0.3395
# Epoch 18/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0828 - mse: 0.0069 - mae: 0.0647 - val_loss: 0.3506 - val_mse: 0.1230 - val_mae: 0.3402
# Epoch 19/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0825 - mse: 0.0068 - mae: 0.0643 - val_loss: 0.3465 - val_mse: 0.1200 - val_mae: 0.3362
# Epoch 20/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0815 - mse: 0.0066 - mae: 0.0634 - val_loss: 0.3389 - val_mse: 0.1149 - val_mae: 0.3286
# Epoch 21/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0801 - mse: 0.0064 - mae: 0.0624 - val_loss: 0.3299 - val_mse: 0.1088 - val_mae: 0.3196
# Epoch 22/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0789 - mse: 0.0063 - mae: 0.0614 - val_loss: 0.3212 - val_mse: 0.1031 - val_mae: 0.3109
# Epoch 23/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0780 - mse: 0.0061 - mae: 0.0607 - val_loss: 0.3142 - val_mse: 0.0987 - val_mae: 0.3040
# Epoch 24/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0769 - mse: 0.0059 - mae: 0.0602 - val_loss: 0.3081 - val_mse: 0.0949 - val_mae: 0.2980
# Epoch 25/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0759 - mse: 0.0058 - mae: 0.0595 - val_loss: 0.3048 - val_mse: 0.0929 - val_mae: 0.2949
# Epoch 26/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0746 - mse: 0.0056 - mae: 0.0585 - val_loss: 0.3029 - val_mse: 0.0918 - val_mae: 0.2933
# Epoch 27/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0733 - mse: 0.0054 - mae: 0.0574 - val_loss: 0.2999 - val_mse: 0.0899 - val_mae: 0.2905
# Epoch 28/40
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0722 - mse: 0.0052 - mae: 0.0564 - val_loss: 0.2959 - val_mse: 0.0876 - val_mae: 0.2868
# Epoch 29/40
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0709 - mse: 0.0050 - mae: 0.0553 - val_loss: 0.2899 - val_mse: 0.0840 - val_mae: 0.2809
# Epoch 30/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0694 - mse: 0.0048 - mae: 0.0543 - val_loss: 0.2818 - val_mse: 0.0794 - val_mae: 0.2731
# Epoch 31/40
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0677 - mse: 0.0046 - mae: 0.0532 - val_loss: 0.2728 - val_mse: 0.0744 - val_mae: 0.2642
# Epoch 32/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0662 - mse: 0.0044 - mae: 0.0520 - val_loss: 0.2672 - val_mse: 0.0714 - val_mae: 0.2589
# Epoch 33/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0646 - mse: 0.0042 - mae: 0.0507 - val_loss: 0.2600 - val_mse: 0.0676 - val_mae: 0.2519
# Epoch 34/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0625 - mse: 0.0040 - mae: 0.0494 - val_loss: 0.2516 - val_mse: 0.0633 - val_mae: 0.2438
# Epoch 35/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0610 - mse: 0.0037 - mae: 0.0479 - val_loss: 0.2438 - val_mse: 0.0594 - val_mae: 0.2363
# Epoch 36/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0589 - mse: 0.0035 - mae: 0.0465 - val_loss: 0.2355 - val_mse: 0.0555 - val_mae: 0.2283
# Epoch 37/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0568 - mse: 0.0032 - mae: 0.0448 - val_loss: 0.2247 - val_mse: 0.0505 - val_mae: 0.2178
# Epoch 38/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0545 - mse: 0.0030 - mae: 0.0430 - val_loss: 0.2111 - val_mse: 0.0445 - val_mae: 0.2043
# Epoch 39/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0521 - mse: 0.0027 - mae: 0.0412 - val_loss: 0.1963 - val_mse: 0.0385 - val_mae: 0.1897
# Epoch 40/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0495 - mse: 0.0025 - mae: 0.0392 - val_loss: 0.1858 - val_mse: 0.0345 - val_mae: 0.1796
# 1/1 [==============================] - 1s 697ms/step
# 3
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7fc7566940> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7fc7566940>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 4s 396ms/step - loss: 0.2332 - mse: 0.0544 - mae: 0.2153 - val_loss: 0.5812 - val_mse: 0.3378 - val_mae: 0.5741
# Epoch 2/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2214 - mse: 0.0492 - mae: 0.2028 - val_loss: 0.5686 - val_mse: 0.3234 - val_mae: 0.5614
# Epoch 3/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2102 - mse: 0.0442 - mae: 0.1904 - val_loss: 0.5556 - val_mse: 0.3087 - val_mae: 0.5481
# Epoch 4/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1984 - mse: 0.0394 - mae: 0.1776 - val_loss: 0.5416 - val_mse: 0.2934 - val_mae: 0.5340
# Epoch 5/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1859 - mse: 0.0347 - mae: 0.1641 - val_loss: 0.5265 - val_mse: 0.2772 - val_mae: 0.5187
# Epoch 6/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1732 - mse: 0.0300 - mae: 0.1497 - val_loss: 0.5100 - val_mse: 0.2601 - val_mae: 0.5019
# Epoch 7/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1597 - mse: 0.0256 - mae: 0.1352 - val_loss: 0.4918 - val_mse: 0.2419 - val_mae: 0.4835
# Epoch 8/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1454 - mse: 0.0212 - mae: 0.1207 - val_loss: 0.4717 - val_mse: 0.2225 - val_mae: 0.4630
# Epoch 9/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1300 - mse: 0.0171 - mae: 0.1061 - val_loss: 0.4492 - val_mse: 0.2018 - val_mae: 0.4401
# Epoch 10/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1158 - mse: 0.0134 - mae: 0.0928 - val_loss: 0.4246 - val_mse: 0.1803 - val_mae: 0.4150
# Epoch 11/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1023 - mse: 0.0105 - mae: 0.0808 - val_loss: 0.3983 - val_mse: 0.1586 - val_mae: 0.3882
# Epoch 12/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0915 - mse: 0.0084 - mae: 0.0721 - val_loss: 0.3721 - val_mse: 0.1385 - val_mae: 0.3614
# Epoch 13/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0867 - mse: 0.0075 - mae: 0.0677 - val_loss: 0.3483 - val_mse: 0.1213 - val_mae: 0.3370
# Epoch 14/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0879 - mse: 0.0077 - mae: 0.0688 - val_loss: 0.3302 - val_mse: 0.1090 - val_mae: 0.3184
# Epoch 15/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0901 - mse: 0.0081 - mae: 0.0717 - val_loss: 0.3224 - val_mse: 0.1040 - val_mae: 0.3106
# Epoch 16/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0904 - mse: 0.0082 - mae: 0.0723 - val_loss: 0.3225 - val_mse: 0.1040 - val_mae: 0.3109
# Epoch 17/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0885 - mse: 0.0078 - mae: 0.0705 - val_loss: 0.3277 - val_mse: 0.1074 - val_mae: 0.3165
# Epoch 18/40
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0856 - mse: 0.0073 - mae: 0.0677 - val_loss: 0.3342 - val_mse: 0.1117 - val_mae: 0.3234
# Epoch 19/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.
40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0771 - mse: 0.0060 - mae: 0.0601 - val_loss: 0.3184 - val_mse: 0.1014 - val_mae: 0.3090
# Epoch 25/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0762 - mse: 0.0058 - mae: 0.0593 - val_loss: 0.3109 - val_mse: 0.0966 - val_mae: 0.3015
# Epoch 26/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0751 - mse: 0.0057 - mae: 0.0586 - val_loss: 0.3031 - val_mse: 0.0918 - val_mae: 0.2938
# Epoch 27/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0741 - mse: 0.0055 - mae: 0.0579 - val_loss: 0.2961 - val_mse: 0.0877 - val_mae: 0.2869
# Epoch 28/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0730 - mse: 0.0053 - mae: 0.0572 - val_loss: 0.2906 - val_mse: 0.0845 - val_mae: 0.2816
# Epoch 29/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0715 - mse: 0.0052 - mae: 0.0562 - val_loss: 0.2890 - val_mse: 0.0835 - val_mae: 0.2803
# Epoch 30/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0705 - mse: 0.0050 - mae: 0.0551 - val_loss: 0.2865 - val_mse: 0.0821 - val_mae: 0.2780
# Epoch 31/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0692 - mse: 0.0048 - mae: 0.0540 - val_loss: 0.2809 - val_mse: 0.0789 - val_mae: 0.2727
# Epoch 32/40
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0678 - mse: 0.0046 - mae: 0.0530 - val_loss: 0.2729 - val_mse: 0.0745 - val_mae: 0.2648
# Epoch 33/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0662 - mse: 0.0044 - mae: 0.0519 - val_loss: 0.2624 - val_mse: 0.0689 - val_mae: 0.2545
# Epoch 34/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0646 - mse: 0.0042 - mae: 0.0507 - val_loss: 0.2519 - val_mse: 0.0634 - val_mae: 0.2441
# Epoch 35/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0629 - mse: 0.0040 - mae: 0.0497 - val_loss: 0.2426 - val_mse: 0.0589 - val_mae: 0.2350
# Epoch 36/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0611 - mse: 0.0037 - mae: 0.0483 - val_loss: 0.2358 - val_mse: 0.0556 - val_mae: 0.2285
# Epoch 37/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0591 - mse: 0.0035 - mae: 0.0467 - val_loss: 0.2316 - val_mse: 0.0536 - val_mae: 0.2248
# Epoch 38/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0568 - mse: 0.0033 - mae: 0.0449 - val_loss: 0.2230 - val_mse: 0.0497 - val_mae: 0.2165
# Epoch 39/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0546 - mse: 0.0030 - mae: 0.0431 - val_loss: 0.2105 - val_mse: 0.0443 - val_mae: 0.2042
# Epoch 40/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0523 - mse: 0.0027 - mae: 0.0413 - val_loss: 0.1979 - val_mse: 0.0392 - val_mae: 0.1920
# 1/1 [==============================] - 1s 563ms/step
# 5
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f7e88677dc0> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f7e88677dc0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 3s 333ms/step - loss: 0.2312 - mse: 0.0535 - mae: 0.2131 - val_loss: 0.5752 - val_mse: 0.3309 - val_mae: 0.5686
# Epoch 2/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2159 - mse: 0.0466 - mae: 0.1967 - val_loss: 0.5576 - val_mse: 0.3109 - val_mae: 0.5507
# Epoch 3/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2004 - mse: 0.0402 - mae: 0.1801 - val_loss: 0.5391 - val_mse: 0.2907 - val_mae: 0.5321
# Epoch 4/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1845 - mse: 0.0341 - mae: 0.1626 - val_loss: 0.5196 - val_mse: 0.2700 - val_mae: 0.5123
# Epoch 5/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1681 - mse: 0.0285 - mae: 0.1448 - val_loss: 0.4986 - val_mse: 0.2486 - val_mae: 0.4910
# Epoch 6/40
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1516 - mse: 0.0230 - mae: 0.1273 - val_loss: 0.4760 - val_mse: 0.2266 - val_mae: 0.4681
# Epoch 7/40
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1344 - mse: 0.0181 - mae: 0.1099 - val_loss: 0.4516 - val_mse: 0.2039 - val_mae: 0.4433
# Epoch 8/40
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1178 - mse: 0.0140 - mae: 0.0950 - val_loss: 0.4252 - val_mse: 0.1808 - val_mae: 0.4164
# Epoch 9/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1029 - mse: 0.0106 - mae: 0.0817 - val_loss: 0.3973 - val_mse: 0.1579 - val_mae: 0.3880
# Epoch 10/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0926 - mse: 0.0086 - mae: 0.0729 - val_loss: 0.3696 - val_mse: 0.1366 - val_mae: 0.3596
# Epoch 11/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0874 - mse: 0.0076 - mae: 0.0681 - val_loss: 0.3457 - val_mse: 0.1195 - val_mae: 0.3352
# Epoch 12/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0879 - mse: 0.0077 - mae: 0.0689 - val_loss: 0.3291 - val_mse: 0.1083 - val_mae: 0.3181
# Epoch 13/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0903 - mse: 0.0082 - mae: 0.0718 - val_loss: 0.3210 - val_mse: 0.1030 - val_mae: 0.3099
# Epoch 14/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0911 - mse: 0.0083 - mae: 0.0729 - val_loss: 0.3212 - val_mse: 0.1032 - val_mae: 0.3103
# Epoch 15/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0894 - mse: 0.0080 - mae: 0.0710 - val_loss: 0.3272 - val_mse: 0.1070 - val_mae: 0.3166
# Epoch 16/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0865 - mse: 0.0075 - mae: 0.0682 - val_loss: 0.3349 - val_mse: 0.1122 - val_mae: 0.3248
# Epoch 17/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0841 - mse: 0.0071 - mae: 0.0657 - val_loss: 0.3426 - val_mse: 0.1174 - val_mae: 0.3328
# Epoch 18/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0831 - mse: 0.0069 - mae: 0.0646 - val_loss: 0.3490 - val_mse: 0.1218 - val_mae: 0.3396
# Epoch 19/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0829 - mse: 0.0069 - mae: 0.0646 - val_loss: 0.3520 - val_mse: 0.1239 - val_mae: 0.3427
# Epoch 20/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0826 - mse: 0.0069 - mae: 0.0646 - val_loss: 0.3510 - val_mse: 0.1232 - val_mae: 0.3418
# Epoch 21/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0821 - mse: 0.0068 - mae: 0.0641 - val_loss: 0.3463 - val_mse: 0.1199 - val_mae: 0.3372
# Epoch 22/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0809 - mse: 0.0066 - mae: 0.0633 - val_loss: 0.3381 - val_mse: 0.1143 - val_mae: 0.3290
# Epoch 23/40
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0800 - mse: 0.0064 - mae: 0.0623 - val_loss: 0.3295 - val_mse: 0.1085 - val_mae: 0.3203
# Epoch 24/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0789 - mse: 0.0062 - mae: 0.0614 - val_loss: 0.3215 - val_mse: 0.1034 - val_mae: 0.3124
# Epoch 25/40
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0780 - mse: 0.0061 - mae: 0.0607 - val_loss: 0.3138 - val_mse: 0.0985 - val_mae: 0.3047
# Epoch 26/40
# ...
# Epoch 37/40
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0233 - mse: 5.4387e-04 - mae: 0.0182 - val_loss: 0.0483 - val_mse: 0.0023 - val_mae: 0.0386
# Epoch 38/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0231 - mse: 5.3778e-04 - mae: 0.0182 - val_loss: 0.0473 - val_mse: 0.0022 - val_mae: 0.0377
# Epoch 39/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0228 - mse: 5.2597e-04 - mae: 0.0179 - val_loss: 0.0480 - val_mse: 0.0023 - val_mae: 0.0385
# Epoch 40/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0229 - mse: 5.2367e-04 - mae: 0.0177 - val_loss: 0.0462 - val_mse: 0.0021 - val_mae: 0.0368
# 1/1 [==============================] - 1s 540ms/step
# 148
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f80082b6310> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f80082b6310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4/4 [==============================] - 3s 213ms/step - loss: 0.3935 - mse: 0.1551 - mae: 0.3334 - val_loss: 0.7474 - val_mse: 0.5586 - val_mae: 0.7413
# Epoch 2/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3740 - mse: 0.1400 - mae: 0.3114 - val_loss: 0.7213 - val_mse: 0.5203 - val_mae: 0.7151
# Epoch 3/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3545 - mse: 0.1257 - mae: 0.2888 - val_loss: 0.6938 - val_mse: 0.4814 - val_mae: 0.6875
# Epoch 4/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3333 - mse: 0.1118 - mae: 0.2652 - val_loss: 0.6641 - val_mse: 0.4410 - val_mae: 0.6576
# Epoch 5/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3124 - mse: 0.0979 - mae: 0.2406 - val_loss: 0.6313 - val_mse: 0.3986 - val_mae: 0.6246
# Epoch 6/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2897 - mse: 0.0840 - mae: 0.2162 - val_loss: 0.5944 - val_mse: 0.3534 - val_mae: 0.5875
# Epoch 7/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2656 - mse: 0.0706 - mae: 0.1926 - val_loss: 0.5528 - val_mse: 0.3056 - val_mae: 0.5455
# Epoch 8/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2405 - mse: 0.0580 - mae: 0.1709 - val_loss: 0.5062 - val_mse: 0.2563 - val_mae: 0.4986
# Epoch 9/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2160 - mse: 0.0468 - mae: 0.1531 - val_loss: 0.4557 - val_mse: 0.2076 - val_mae: 0.4475
# Epoch 10/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1957 - mse: 0.0385 - mae: 0.1485 - val_loss: 0.4041 - val_mse: 0.1633 - val_mae: 0.3952
# Epoch 11/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1830 - mse: 0.0336 - mae: 0.1510 - val_loss: 0.3577 - val_mse: 0.1279 - val_mae: 0.3480
# Epoch 12/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1803 - mse: 0.0326 - mae: 0.1575 - val_loss: 0.3246 - val_mse: 0.1053 - val_mae: 0.3142
# Epoch 13/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1790 - mse: 0.0321 - mae: 0.1595 - val_loss: 0.3129 - val_mse: 0.0979 - val_mae: 0.3025
# Epoch 14/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1759 - mse: 0.0310 - mae: 0.1570 - val_loss: 0.3126 - val_mse: 0.0977 - val_mae: 0.3027
# Epoch 15/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1710 - mse: 0.0293 - mae: 0.1517 - val_loss: 0.3160 - val_mse: 0.0998 - val_mae: 0.3065
# Epoch 16/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1659 - mse: 0.0276 - mae: 0.1455 - val_loss: 0.3214 - val_mse: 0.1033 - val_mae: 0.3124
# Epoch 17/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1613 - mse: 0.0260 - mae: 0.1393 - val_loss: 0.3204 - val_mse: 0.1026 - val_mae: 0.3118
# Epoch 18/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1569 - mse: 0.0247 - mae: 0.1339 - val_loss: 0.3169 - val_mse: 0.1004 - val_mae: 0.3087
# Epoch 19/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1522 - mse: 0.0232 - mae: 0.1284 - val_loss: 0.3074 - val_mse: 0.0945 - val_mae: 0.2994
# Epoch 20/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1466 - mse: 0.0215 - mae: 0.1242 - val_loss: 0.2867 - val_mse: 0.0822 - val_mae: 0.2787
# Epoch 21/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1400 - mse: 0.0196 - mae: 0.1206 - val_loss: 0.2650 - val_mse: 0.0702 - val_mae: 0.2570
# Epoch 22/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1334 - mse: 0.0178 - mae: 0.1168 - val_loss: 0.2424 - val_mse: 0.0587 - val_mae: 0.2343
# Epoch 23/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1267 - mse: 0.0161 - mae: 0.1121 - val_loss: 0.2216 - val_mse: 0.0491 - val_mae: 0.2136
# Epoch 24/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1190 - mse: 0.0142 - mae: 0.1058 - val_loss: 0.2136 - val_mse: 0.0456 - val_mae: 0.2061
# Epoch 25/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1096 - mse: 0.0120 - mae: 0.0955 - val_loss: 0.2155 - val_mse: 0.0465 - val_mae: 0.2088
# Epoch 26/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1012 - mse: 0.0102 - mae: 0.0846 - val_loss: 0.2044 - val_mse: 0.0418 - val_mae: 0.1981
# Epoch 27/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0914 - mse: 0.0084 - mae: 0.0751 - val_loss: 0.1808 - val_mse: 0.0327 - val_mae: 0.1745
# Epoch 28/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0802 - mse: 0.0065 - mae: 0.0667 - val_loss: 0.1500 - val_mse: 0.0225 - val_mae: 0.1433
# Epoch 29/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0683 - mse: 0.0047 - mae: 0.0578 - val_loss: 0.1248 - val_mse: 0.0156 - val_mae: 0.1176
# Epoch 30/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0558 - mse: 0.0031 - mae: 0.0466 - val_loss: 0.1058 - val_mse: 0.0112 - val_mae: 0.0983
# Epoch 31/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0435 - mse: 0.0019 - mae: 0.0344 - val_loss: 0.0824 - val_mse: 0.0068 - val_mae: 0.0735
# Epoch 32/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0327 - mse: 0.0011 - mae: 0.0257 - val_loss: 0.0585 - val_mse: 0.0034 - val_mae: 0.0482
# Epoch 33/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0265 - mse: 7.0402e-04 - mae: 0.0210 - val_loss: 0.0450 - val_mse: 0.0020 - val_mae: 0.0352
# Epoch 34/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0261 - mse: 6.8143e-04 - mae: 0.0206 - val_loss: 0.0371 - val_mse: 0.0014 - val_mae: 0.0291
# Epoch 35/40
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0275 - mse: 7.6510e-04 - mae: 0.0217 - val_loss: 0.0366 - val_mse: 0.0013 - val_mae: 0.0287
# Epoch 36/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0266 - mse: 7.1410e-04 - mae: 0.0208 - val_loss: 0.0380 - val_mse: 0.0014 - val_mae: 0.0297
# Epoch 37/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0246 - mse: 6.0716e-04 - mae: 0.0192 - val_loss: 0.0416 - val_mse: 0.0017 - val_mae: 0.0325
# Epoch 38/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0230 - mse: 5.3262e-04 - mae: 0.0180 - val_loss: 0.0469 - val_mse: 0.0022 - val_mae: 0.0371
# Epoch 39/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0228 - mse: 5.1867e-04 - mae: 0.0178 - val_loss: 0.0489 - val_mse: 0.0024 - val_mae: 0.0389
# Epoch 40/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0230 - mse: 5.3265e-04 - mae: 0.0181 - val_loss: 0.0496 - val_mse: 0.0025 - val_mae: 0.0396
# 1/1 [==============================] - 1s 550ms/step
# 149
# Epoch 1/40
# WARNING: AutoGraph could not transform <function root_mean_squared_error at 0x7f8170fb9d30> and will run it as-is.
# Cause: Unable to locate the source code of <function root_mean_squared_error at 0x7f8170fb9d30>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4/4 [==============================] - 3s 195ms/step - loss: 0.3888 - mse: 0.1519 - mae: 0.3282 - val_loss: 0.7478 - val_mse: 0.5592 - val_mae: 0.7414
# Epoch 2/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3715 - mse: 0.1387 - mae: 0.3091 - val_loss: 0.7248 - val_mse: 0.5254 - val_mae: 0.7183
# Epoch 3/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3545 - mse: 0.1260 - mae: 0.2891 - val_loss: 0.6997 - val_mse: 0.4896 - val_mae: 0.6931
# Epoch 4/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3359 - mse: 0.1132 - mae: 0.2673 - val_loss: 0.6717 - val_mse: 0.4512 - val_mae: 0.6649
# Epoch 5/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3157 - mse: 0.0999 - mae: 0.2444 - val_loss: 0.6401 - val_mse: 0.4097 - val_mae: 0.6331
# Epoch 6/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2935 - mse: 0.0863 - mae: 0.2205 - val_loss: 0.6042 - val_mse: 0.3650 - val_mae: 0.5970
# Epoch 7/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2697 - mse: 0.0728 - mae: 0.1960 - val_loss: 0.5630 - val_mse: 0.3170 - val_mae: 0.5555
# Epoch 8/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2437 - mse: 0.0596 - mae: 0.1730 - val_loss: 0.5162 - val_mse: 0.2665 - val_mae: 0.5083
# Epoch 9/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2194 - mse: 0.0484 - mae: 0.1554 - val_loss: 0.4645 - val_mse: 0.2158 - val_mae: 0.4560
# Epoch 10/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1981 - mse: 0.0394 - mae: 0.1487 - val_loss: 0.4122 - val_mse: 0.1699 - val_mae: 0.4029
# Epoch 11/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1850 - mse: 0.0342 - mae: 0.1507 - val_loss: 0.3673 - val_mse: 0.1349 - val_mae: 0.3573
# Epoch 12/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1793 - mse: 0.0322 - mae: 0.1551 - val_loss: 0.3347 - val_mse: 0.1121 - val_mae: 0.3242
# Epoch 13/40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1775 - mse: 0.0315 - mae: 0.1573 - val_loss: 0.3171 - val_mse: 0.1006 - val_mae: 0.3064
# Epoch 14/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1741 - mse: 0.0304 - mae: 0.1556 - val_loss: 0.3108 - val_mse: 0.0966 - val_mae: 0.3004
# Epoch 15/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1694 - mse: 0.0287 - mae: 0.1508 - val_loss: 0.3116 - val_mse: 0.0971 - val_mae: 0.3016
# Epoch 16/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1639 - mse: 0.0269 - mae: 0.1442 - val_loss: 0.3171 - val_mse: 0.1005 - val_mae: 0.3077
# Epoch 17/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1583 - mse: 0.0251 - mae: 0.1369 - val_loss: 0.3175 - val_mse: 0.1008 - val_mae: 0.3087
# Epoch 18/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1528 - mse: 0.0234 - mae: 0.1301 - val_loss: 0.3109 - val_mse: 0.0967 - val_mae: 0.3025
# Epoch 19/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1470 - mse: 0.0216 - mae: 0.1240 - val_loss: 0.2970 - val_mse: 0.0882 - val_mae: 0.2889
# Epoch 20/40
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1398 - mse: 0.0195 - mae: 0.1186 - val_loss: 0.2732 - val_mse: 0.0746 - val_mae: 0.2650
# Epoch 21/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1323 - mse: 0.0175 - mae: 0.1150 - val_loss: 0.2460 - val_mse: 0.0605 - val_mae: 0.2377
# Epoch 22/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1243 - mse: 0.0155 - mae: 0.1099 - val_loss: 0.2284 - val_mse: 0.0522 - val_mae: 0.2203
# Epoch 23/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1151 - mse: 0.0133 - mae: 0.1012 - val_loss: 0.2193 - val_mse: 0.0481 - val_mae: 0.2118
# Epoch 24/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1051 - mse: 0.0110 - mae: 0.0901 - val_loss: 0.2101 - val_mse: 0.0442 - val_mae: 0.2032
# Epoch 25/40
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0945 - mse: 0.0089 - mae: 0.0783 - val_loss: 0.1897 - val_mse: 0.0360 - val_mae: 0.1830
# Epoch 26/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0823 - mse: 0.0068 - mae: 0.0680 - val_loss: 0.1583 - val_mse: 0.0251 - val_mae: 0.1512
# Epoch 27/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0693 - mse: 0.0048 - mae: 0.0582 - val_loss: 0.1282 - val_mse: 0.0164 - val_mae: 0.1205
# Epoch 28/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0559 - mse: 0.0032 - mae: 0.0465 - val_loss: 0.1053 - val_mse: 0.0111 - val_mae: 0.0969
# Epoch 29/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0431 - mse: 0.0019 - mae: 0.0339 - val_loss: 0.0831 - val_mse: 0.0069 - val_mae: 0.0735
# Epoch 30/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0341 - mse: 0.0012 - mae: 0.0267 - val_loss: 0.0602 - val_mse: 0.0036 - val_mae: 0.0491
# Epoch 31/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0291 - mse: 8.5284e-04 - mae: 0.0233 - val_loss: 0.0463 - val_mse: 0.0021 - val_mae: 0.0361
# Epoch 32/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0285 - mse: 8.2086e-04 - mae: 0.0227 - val_loss: 0.0420 - val_mse: 0.0018 - val_mae: 0.0328
# Epoch 33/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0286 - mse: 8.1787e-04 - mae: 0.0225 - val_loss: 0.0408 - val_mse: 0.0017 - val_mae: 0.0318
# Epoch 34/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0267 - mse: 7.1578e-04 - mae: 0.0211 - val_loss: 0.0443 - val_mse: 0.0020 - val_mae: 0.0344
# Epoch 35/40
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0248 - mse: 6.1453e-04 - mae: 0.0196 - val_loss: 0.0480 - val_mse: 0.0023 - val_mae: 0.0375
# Epoch 36/40
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0239 - mse: 5.7592e-04 - mae: 0.0188 - val_loss: 0.0510 - val_mse: 0.0026 - val_mae: 0.0402
# Epoch 37/40
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0234 - mse: 5.5070e-04 - mae: 0.0184 - val_loss: 0.0561 - val_mse: 0.0032 - val_mae: 0.0456
# Epoch 38/40
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0234 - mse: 5.5208e-04 - mae: 0.0183 - val_loss: 0.0515 - val_mse: 0.0026 - val_mae: 0.0407
# Epoch 39/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0233 - mse: 5.4546e-04 - mae: 0.0183 - val_loss: 0.0525 - val_mse: 0.0028 - val_mae: 0.0418
# Epoch 40/40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0229 - mse: 5.3462e-04 - mae: 0.0180 - val_loss: 0.0493 - val_mse: 0.0024 - val_mae: 0.0388
# 1/1 [==============================] - 1s 523ms/step
# 150
# CPU times: user 20min 7s, sys: 53.1 s, total: 21min
# Wall time: 16min 25s
# <ipython-input-1-44ea536bb537>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set_news_data_date.price_date[i]=standard  + datetime.timedelta(days=1)
# <ipython-input-1-44ea536bb537>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_data.before_close[i+1] = price_data.Close[i]

# %%
lstm_2_pred = scaler_y.inverse_transform(lstm_2_pred.reshape(len(x_t),1))

# %%
import pickle
with open(file='/home/whfhrs3260/deeplearning_result_data/lstm_2_pred_2012_2013.pkl', mode='wb') as f:
    pickle.dump(lstm_2_pred, f)
